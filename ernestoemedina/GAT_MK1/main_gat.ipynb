# %% [markdown]
# # Librerías

# %%
import torch
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import os
import sys
import time
import numpy as np
import random
from torch.optim.lr_scheduler import ReduceLROnPlateau
from gat_model import GAT
from torch_geometric.loader import DataLoader
from dataset_utils import generate_edge_index, build_graph_list, build_graph_from_sample
from train_eval import train, evaluate, EarlyStopping

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %%
dir_path = os.getcwd()
print(dir_path)
# Out:
# c:\Users\ramse\Escritorio\Aero Ordenador\4to Aero\2do Cuatri\ia_thermal\ernestoemedina\GAT_MK1

# %%
# Ruta del dataset completo
dataset_path = os.path.join(dir_path, "Datasets", "PCB_dataset.pth")
norm_dataset_path = os.path.join(dir_path, "Datasets", "PCB_Dataset_Norm.pth")
info_path = os.path.join(dir_path, "Datasets", "normalization_info.pth")

# Cargar dataset
dataset = torch.load(dataset_path)
norm_dataset = torch.load(norm_dataset_path)
norm_info = torch.load(info_path)
print(norm_dataset.outputs.min(), norm_dataset.outputs.max())

#Esto es para demostrar que el dataset no tiene valores cero, debido a la estandarización
#T_interfaces = dataset.T_interfaces.view(-1)

# Cuántos son exactamente 0
#num_exact_zeros = (T_interfaces == 0.0).sum().item()

# Cuántos son muy pequeños pero no exactamente 0
#num_near_zeros = ((T_interfaces != 0.0) & (T_interfaces.abs() < 1e-5)).sum().item()

# Valor mínimo no nulo
#min_nonzero = T_interfaces[T_interfaces != 0.0].min().item()

#print(f"Valores totales: {T_interfaces.numel()}")
#print(f"Exactamente cero: {num_exact_zeros}")
#print(f"Pequeños pero ≠ 0 (|x| < 1e-5): {num_near_zeros}")
#print(f"Valor mínimo no nulo: {min_nonzero}")
# Out:
# C:\Users\ramse\AppData\Local\Temp\ipykernel_7332\2813147112.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dataset = torch.load(dataset_path)
# C:\Users\ramse\AppData\Local\Temp\ipykernel_7332\2813147112.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   norm_dataset = torch.load(norm_dataset_path)
# C:\Users\ramse\AppData\Local\Temp\ipykernel_7332\2813147112.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   norm_info = torch.load(info_path)
# tensor(0.7136) tensor(1.)

# %% [markdown]
# ## Para desnormalizar

# %%
max_T_interfaces = norm_info["max_T_interfaces"]
max_Q_heaters = norm_info["max_Q_heaters"]
max_T_env = norm_info["max_T_env"]

## En ppio no debería ser necesario, ya que hemos cargado el dataset sin normalizar

def desnormalize_inputs(dataset_norm, idx):
    T_interfaces_norm = dataset_norm.T_interfaces[idx]
    Q_heaters_norm = dataset_norm.Q_heaters[idx]
    T_env_norm = dataset_norm.T_env[idx]
    
    T_interfaces_real = T_interfaces_norm * max_T_interfaces
    Q_heaters_real = Q_heaters_norm * max_Q_heaters
    T_env_real = T_env_norm * max_T_env
    
    return T_interfaces_real, Q_heaters_real, T_env_real

# %%
idx = 1
T_interfaces_real, Q_heaters_real, T_env_real = desnormalize_inputs(norm_dataset, idx)

# Por ejemplo:
print(torch.max(T_interfaces_real), "K")
print(torch.max(Q_heaters_real), "W")
print(torch.max(T_env_real), "K")
# Out:
# tensor(309.7728) K
# tensor(0.8122) W
# tensor(298.0007) K

# %%
# Seleccionar un índice para graficar
idx = 1  # Puedes cambiar este valor

# Obtener los valores reales de las CC en T, Q y T_env
T_interfaces_real = dataset.denormalize_T_interfaces(dataset.T_interfaces)
Q_heaters_real = dataset.denormalize_Q_heaters(dataset.Q_heaters)
T_env_real = dataset.denormalize_T_env(dataset.T_env)

print(T_interfaces_real.shape)
print(torch.max(T_interfaces_real[idx]), "K")
print(torch.max(Q_heaters_real[idx]), "W")
print(torch.max(T_env_real[idx]), "K")
# Out:
# torch.Size([10000, 13, 13])
# tensor(309.7728) K
# tensor(0.8122) W
# tensor(298.0007) K

# %%
idx = 10
T_interfaces_norm = norm_dataset.T_interfaces[idx]
Q_heaters_norm = norm_dataset.Q_heaters[idx]
T_env_norm = norm_dataset.T_env[idx]

# %%
# Crear figura para mostrar las 3 variables
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
im1 = axs[0].imshow(T_interfaces_norm.numpy(), cmap='hot')
axs[0].set_title("T_interfaces_norm [0–1]")
plt.colorbar(im1, ax=axs[0])

im2 = axs[1].imshow(Q_heaters_norm.numpy(), cmap='hot')
axs[1].set_title("Q_heaters_norm [0–1]")
plt.colorbar(im2, ax=axs[1])

im3 = axs[2].imshow(T_env_norm.numpy(), cmap='hot')
axs[2].set_title("T_env_norm [0–1]")
plt.colorbar(im3, ax=axs[2])

plt.suptitle(f"Entrada del dataset  idx = {idx}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## GAT

# %% [markdown]
# ### Configuración de la red

# %%
# Configuración del modelo
config = {
    "input_dim": 3,           # 3 canales: T_interfaces, Q_heaters, T_env
    "hidden_dim": 128,
    "output_dim": 1,
    "num_layers": 8,
    "use_dropout": True,
    "dropout_rate": 0.3,
    "use_batchnorm": True,
    "use_residual": True,
    "batch_size": 16,
    "heads": 4,
    "lr": 0.0001,
    "max_epochs": 10000,
    "early_stop_patience": 100,
    "error_threshold_K": 3.0,
    "use_percentage_threshold": False,
    "percentage_threshold": 1.0,  # solo si se activa la opción
    "save_model": True,
    "load_model": False, # Cargar un modelo preentrenado
    "factor" : 0.5 , # Factor de reducción del learning rate
    "patience" : 10 , # Épocas sin mejora para reducir el learning rate
    "min_lr" : 1e-9,  # evita que baje infinitamente el learning rate
    "use_physics" : True,
    "lambda_physics" : 0.0001, # Peso de la física en la función de pérdida
    "use_boundary_loss" : True,
    "lambda_boundary" : 1,
    "use_heater_loss" : True,
    "lambda_heater" : 10
}

# %%
grid_size = norm_dataset.inputs.shape[-1]
print("PCB cuadrada de", grid_size, "nodos por lado")
edge_index = generate_edge_index(grid_size=grid_size) # Matriz de adyacencia bidireccional
graphs = build_graph_list(norm_dataset, edge_index)
# Out:
# PCB cuadrada de 13 nodos por lado

# %%
# Por si en algún momento el Dataset tuviera un patrón al ser generado
random.seed(42)
random.shuffle(graphs)

# %%
# Ruta al dataset normalizado

# Extraer un tensor de salida
sample_output = norm_dataset.outputs[0]

# Imprimir estadísticas globales de outputs
all_outputs = norm_dataset.outputs.view(-1)
print(f"Mean of outputs: {all_outputs.mean().item():.4f}")
print(f"Std of outputs:  {all_outputs.std().item():.4f}")

# También desde los atributos si están disponibles
if hasattr(norm_dataset, "T_outputs_mean"):
    print(f"Atributo .T_outputs_mean: {norm_dataset.T_outputs_mean.item():.4f}")
    print(f"Atributo .T_outputs_std:  {norm_dataset.T_outputs_std.item():.4f}")
# Out:
# Mean of outputs: 0.8303
# Std of outputs:  0.0338
# Atributo .T_outputs_mean: 0.0000
# Atributo .T_outputs_std:  1.0000

# %% [markdown]
# ### División Dataset

# %%
# División del dataset
train_size = int(0.8 * len(graphs))
val_size = int(0.1 * len(graphs))
test_size = len(graphs) - train_size - val_size

train_dataset = graphs[:train_size]
val_dataset = graphs[train_size:train_size + val_size]
test_dataset = graphs[train_size + val_size:]

# Crear DataLoaders
batch_size = config["batch_size"]
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
model = GAT(
    input_dim=config["input_dim"],
    hidden_dim=config["hidden_dim"],
    output_dim=config["output_dim"],
    num_layers=config["num_layers"],
    heads=config["heads"],
    use_dropout=config["use_dropout"],
    dropout_rate=config["dropout_rate"],
    use_batchnorm=config["use_batchnorm"],
    use_residual=config["use_residual"]
).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=config["lr"])
scheduler = ReduceLROnPlateau(
    optimizer,
    mode='min',            # queremos minimizar el val_loss
    factor=config["factor"],            # reduce a la mitad el LR
    patience=config["patience"],           # espera 10 épocas sin mejora
    verbose=True,          # imprime info cuando reduce
    min_lr=config["min_lr"]            # evita que baje infinitamente
)
# Out:
# c:\Users\ramse\anaconda3\Lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
print("Forma de entrada:", norm_dataset.inputs[0].shape)
print("Forma de salida:", norm_dataset.outputs[0].shape)
# Out:
# Forma de entrada: torch.Size([3, 13, 13])
# Forma de salida: torch.Size([13, 13])

# %% [markdown]
# ### Entrenamiento

# %%
# Entrenamiento
train_losses = []
val_losses = []
epoch_times = []

early_stopper = EarlyStopping(patience=config["early_stop_patience"])
max_epochs = config["max_epochs"]
best_lr=config["lr"]

print("Iniciando entrenamiento...")
for epoch in range(config["max_epochs"]):
    start_time = time.time()
    
    # Entrenar
    train_loss = train(model, train_loader, optimizer, device, norm_info, lambda_physics=config["lambda_physics"],
                       use_physics=config["use_physics"], lambda_boundary=config["lambda_boundary"],
                       use_boundary_loss=config["use_boundary_loss"], lambda_heater=config["lambda_heater"],
                       use_heater_loss=config["use_heater_loss"])
    train_losses.append(train_loss)

    # Evaluar en validación
    val_mse, val_mae, val_r2, val_accuracy, val_physics, val_boundary, val_heaters, val_rmse, val_total_loss = evaluate(
        model, val_loader, device, norm_info, lambda_physics=config["lambda_physics"],
        use_physics=config["use_physics"], lambda_boundary=config["lambda_boundary"],
        use_boundary_loss=config["use_boundary_loss"], lambda_heater=config["lambda_heater"],
        use_heater_loss=config["use_heater_loss"],
        error_threshold=config["error_threshold_K"],
        percentage_threshold=config["percentage_threshold"] if config["use_percentage_threshold"] else None,
        plot_results=False
    )
    val_losses.append(val_mse)

    scheduler.step(val_mse)
    
    # Medir tiempo transcurrido
    epoch_duration = time.time() - start_time
    epoch_times.append(epoch_duration)

    # Formatear bien los losses opcionales
    physics_loss_str = f"{val_physics:.6f}" if config["use_physics"] else "N/A"
    boundary_loss_str = f"{val_boundary:.6f}" if config["use_boundary_loss"] else "N/A"
    heaters_loss_str = f"{val_heaters:.6f}" if config["use_heater_loss"] else "N/A"

    # Imprimir métricas
    print(f"Epoch {epoch + 1} - "
          f"Train Loss: {train_loss:.6f} | "
          f"Val MSE: {val_mse:.6f} | "
          f"Val MAE: {val_mae:.6f} | "
          f"Val R²: {val_r2:.4f} | "
          f"[Boundary loss] {boundary_loss_str} | "
          f"[Heaters loss] {heaters_loss_str} | "
          f"[Physics loss] {physics_loss_str} | "
          f"Val Accuracy: {val_accuracy:.2f}% | "
          f"LR: {optimizer.param_groups[0]['lr']:.9f} | "
          f"Time: {epoch_duration:.2f}s")

    # Guardar el mejor modelo en memoria
    if val_total_loss < early_stopper.best_loss:
        best_model_state = model.state_dict()
        final_epoch = epoch + 1
        best_lr = optimizer.param_groups[0]['lr']  # guardar lr actual

    early_stopper(val_total_loss, epoch)
    if early_stopper.early_stop:
        print(f" Early stopping triggered at epoch {epoch}")
        avg_epoch_time = np.mean(epoch_times)
        print(f"Tiempo por época        : {avg_epoch_time:.2f}")
        break
# Out:
# Iniciando entrenamiento...
# Epoch 1 - Train Loss: 20.645641 | Val MSE: 0.077845 | Val MAE: 0.208252 | Val R²: -77.5639 | [Boundary loss] 0.055127 | [Heaters loss] 0.077308 | [Physics loss] 67.570251 | Val Accuracy: 2.86% | LR: 0.000100000
# Epoch 2 - Train Loss: 7.559068 | Val MSE: 0.073314 | Val MAE: 0.206222 | Val R²: -72.9956 | [Boundary loss] 0.029636 | [Heaters loss] 0.072280 | [Physics loss] 48.310513 | Val Accuracy: 1.85% | LR: 0.000100000
# Epoch 3 - Train Loss: 4.951511 | Val MSE: 0.052912 | Val MAE: 0.174633 | Val R²: -52.1886 | [Boundary loss] 0.021623 | [Heaters loss] 0.052171 | [Physics loss] 31.380909 | Val Accuracy: 1.86% | LR: 0.000100000
# Epoch 4 - Train Loss: 3.614816 | Val MSE: 0.014188 | Val MAE: 0.093261 | Val R²: -13.3159 | [Boundary loss] 0.094644 | [Heaters loss] 0.016092 | [Physics loss] 21.723747 | Val Accuracy: 5.74% | LR: 0.000100000
# Epoch 5 - Train Loss: 2.761345 | Val MSE: 0.010144 | Val MAE: 0.078568 | Val R²: -9.3005 | [Boundary loss] 0.094793 | [Heaters loss] 0.012148 | [Physics loss] 20.393755 | Val Accuracy: 6.58% | LR: 0.000100000
# Epoch 6 - Train Loss: 2.222140 | Val MSE: 0.008598 | Val MAE: 0.072205 | Val R²: -7.7127 | [Boundary loss] 0.062774 | [Heaters loss] 0.009880 | [Physics loss] 13.244093 | Val Accuracy: 6.83% | LR: 0.000100000
# Epoch 7 - Train Loss: 1.832401 | Val MSE: 0.006456 | Val MAE: 0.061820 | Val R²: -5.4948 | [Boundary loss] 0.030403 | [Heaters loss] 0.007023 | [Physics loss] 9.227593 | Val Accuracy: 9.35% | LR: 0.000100000
# Epoch 8 - Train Loss: 1.517533 | Val MSE: 0.008466 | Val MAE: 0.070940 | Val R²: -7.4903 | [Boundary loss] 0.042524 | [Heaters loss] 0.009272 | [Physics loss] 6.682569 | Val Accuracy: 7.84% | LR: 0.000100000
# Epoch 9 - Train Loss: 1.276023 | Val MSE: 0.013770 | Val MAE: 0.108544 | Val R²: -12.9038 | [Boundary loss] 0.046133 | [Heaters loss] 0.014536 | [Physics loss] 5.132185 | Val Accuracy: 0.53% | LR: 0.000100000
# Epoch 10 - Train Loss: 1.070377 | Val MSE: 0.003247 | Val MAE: 0.044358 | Val R²: -2.2890 | [Boundary loss] 0.026144 | [Heaters loss] 0.003789 | [Physics loss] 6.567879 | Val Accuracy: 13.54% | LR: 0.000100000
# Epoch 11 - Train Loss: 0.897550 | Val MSE: 0.005774 | Val MAE: 0.056586 | Val R²: -4.8864 | [Boundary loss] 0.025560 | [Heaters loss] 0.006243 | [Physics loss] 6.260406 | Val Accuracy: 12.23% | LR: 0.000100000
# Epoch 12 - Train Loss: 0.760777 | Val MSE: 0.002561 | Val MAE: 0.034209 | Val R²: -1.6077 | [Boundary loss] 0.007395 | [Heaters loss] 0.002675 | [Physics loss] 5.517841 | Val Accuracy: 15.95% | LR: 0.000100000
# Epoch 13 - Train Loss: 0.647717 | Val MSE: 0.002527 | Val MAE: 0.035716 | Val R²: -1.5668 | [Boundary loss] 0.007415 | [Heaters loss] 0.002643 | [Physics loss] 4.241452 | Val Accuracy: 17.75% | LR: 0.000100000
# Epoch 14 - Train Loss: 0.547280 | Val MSE: 0.001426 | Val MAE: 0.028072 | Val R²: -0.4487 | [Boundary loss] 0.004737 | [Heaters loss] 0.001505 | [Physics loss] 4.436706 | Val Accuracy: 20.63% | LR: 0.000100000
# Epoch 15 - Train Loss: 0.463935 | Val MSE: 0.003690 | Val MAE: 0.040030 | Val R²: -2.7381 | [Boundary loss] 0.003760 | [Heaters loss] 0.003691 | [Physics loss] 3.641084 | Val Accuracy: 13.91% | LR: 0.000100000
# Epoch 16 - Train Loss: 0.398683 | Val MSE: 0.002103 | Val MAE: 0.028842 | Val R²: -1.1391 | [Boundary loss] 0.002632 | [Heaters loss] 0.002116 | [Physics loss] 4.054116 | Val Accuracy: 22.23% | LR: 0.000100000
# Epoch 17 - Train Loss: 0.342233 | Val MSE: 0.001713 | Val MAE: 0.029694 | Val R²: -0.7444 | [Boundary loss] 0.010103 | [Heaters loss] 0.001911 | [Physics loss] 3.400387 | Val Accuracy: 21.68% | LR: 0.000100000
# Epoch 18 - Train Loss: 0.293856 | Val MSE: 0.001969 | Val MAE: 0.026925 | Val R²: -0.9997 | [Boundary loss] 0.002256 | [Heaters loss] 0.001976 | [Physics loss] 2.897111 | Val Accuracy: 21.93% | LR: 0.000100000
# Epoch 19 - Train Loss: 0.248543 | Val MSE: 0.001727 | Val MAE: 0.026384 | Val R²: -0.7563 | [Boundary loss] 0.004440 | [Heaters loss] 0.001791 | [Physics loss] 3.093440 | Val Accuracy: 26.67% | LR: 0.000100000
# Epoch 20 - Train Loss: 0.214707 | Val MSE: 0.004076 | Val MAE: 0.030777 | Val R²: -3.1561 | [Boundary loss] 0.000545 | [Heaters loss] 0.003992 | [Physics loss] 3.050470 | Val Accuracy: 28.85% | LR: 0.000100000
# Epoch 21 - Train Loss: 0.185546 | Val MSE: 0.000926 | Val MAE: 0.022993 | Val R²: 0.0645 | [Boundary loss] 0.006873 | [Heaters loss] 0.001067 | [Physics loss] 2.518557 | Val Accuracy: 24.91% | LR: 0.000100000
# Epoch 22 - Train Loss: 0.163716 | Val MSE: 0.000845 | Val MAE: 0.022188 | Val R²: 0.1425 | [Boundary loss] 0.003150 | [Heaters loss] 0.000900 | [Physics loss] 2.972749 | Val Accuracy: 23.99% | LR: 0.000100000
# Epoch 23 - Train Loss: 0.142461 | Val MSE: 0.000653 | Val MAE: 0.020542 | Val R²: 0.3397 | [Boundary loss] 0.003954 | [Heaters loss] 0.000732 | [Physics loss] 2.054840 | Val Accuracy: 23.62% | LR: 0.000100000
# Epoch 24 - Train Loss: 0.130567 | Val MSE: 0.002043 | Val MAE: 0.028338 | Val R²: -1.0763 | [Boundary loss] 0.004002 | [Heaters loss] 0.002089 | [Physics loss] 3.270817 | Val Accuracy: 24.24% | LR: 0.000100000
# Epoch 25 - Train Loss: 0.115058 | Val MSE: 0.001617 | Val MAE: 0.026415 | Val R²: -0.6410 | [Boundary loss] 0.003568 | [Heaters loss] 0.001663 | [Physics loss] 2.066256 | Val Accuracy: 20.30% | LR: 0.000100000
# Epoch 26 - Train Loss: 0.104354 | Val MSE: 0.001190 | Val MAE: 0.020280 | Val R²: -0.2104 | [Boundary loss] 0.005214 | [Heaters loss] 0.001285 | [Physics loss] 2.583066 | Val Accuracy: 32.99% | LR: 0.000100000
# Epoch 27 - Train Loss: 0.091256 | Val MSE: 0.006072 | Val MAE: 0.039858 | Val R²: -5.1890 | [Boundary loss] 0.007589 | [Heaters loss] 0.006108 | [Physics loss] 2.392319 | Val Accuracy: 22.38% | LR: 0.000100000
# Epoch 28 - Train Loss: 0.084246 | Val MSE: 0.000574 | Val MAE: 0.017964 | Val R²: 0.4158 | [Boundary loss] 0.006258 | [Heaters loss] 0.000708 | [Physics loss] 1.731170 | Val Accuracy: 30.95% | LR: 0.000100000
# Epoch 29 - Train Loss: 0.080788 | Val MSE: 0.001734 | Val MAE: 0.025227 | Val R²: -0.7616 | [Boundary loss] 0.003912 | [Heaters loss] 0.001785 | [Physics loss] 2.066204 | Val Accuracy: 27.54% | LR: 0.000100000
# Epoch 30 - Train Loss: 0.074645 | Val MSE: 0.003081 | Val MAE: 0.034179 | Val R²: -2.1447 | [Boundary loss] 0.007241 | [Heaters loss] 0.003179 | [Physics loss] 2.120771 | Val Accuracy: 15.81% | LR: 0.000100000
# Epoch 31 - Train Loss: 0.066038 | Val MSE: 0.001043 | Val MAE: 0.025093 | Val R²: -0.0541 | [Boundary loss] 0.006717 | [Heaters loss] 0.001177 | [Physics loss] 1.696753 | Val Accuracy: 20.92% | LR: 0.000100000
# Epoch 32 - Train Loss: 0.061159 | Val MSE: 0.001272 | Val MAE: 0.020308 | Val R²: -0.2946 | [Boundary loss] 0.004266 | [Heaters loss] 0.001343 | [Physics loss] 2.630321 | Val Accuracy: 36.90% | LR: 0.000100000
# Epoch 33 - Train Loss: 0.055127 | Val MSE: 0.000337 | Val MAE: 0.013495 | Val R²: 0.6601 | [Boundary loss] 0.002144 | [Heaters loss] 0.000379 | [Physics loss] 1.983695 | Val Accuracy: 40.09% | LR: 0.000100000
# Epoch 34 - Train Loss: 0.053435 | Val MSE: 0.000535 | Val MAE: 0.016300 | Val R²: 0.4569 | [Boundary loss] 0.003189 | [Heaters loss] 0.000597 | [Physics loss] 1.871725 | Val Accuracy: 36.13% | LR: 0.000100000
# Epoch 35 - Train Loss: 0.047907 | Val MSE: 0.000447 | Val MAE: 0.015798 | Val R²: 0.5486 | [Boundary loss] 0.002008 | [Heaters loss] 0.000484 | [Physics loss] 2.204352 | Val Accuracy: 34.51% | LR: 0.000100000
# Epoch 36 - Train Loss: 0.046156 | Val MSE: 0.000566 | Val MAE: 0.016644 | Val R²: 0.4273 | [Boundary loss] 0.002308 | [Heaters loss] 0.000607 | [Physics loss] 1.806299 | Val Accuracy: 34.34% | LR: 0.000100000
# Epoch 37 - Train Loss: 0.041723 | Val MSE: 0.000771 | Val MAE: 0.020346 | Val R²: 0.2194 | [Boundary loss] 0.004853 | [Heaters loss] 0.000868 | [Physics loss] 1.839674 | Val Accuracy: 28.35% | LR: 0.000100000
# Epoch 38 - Train Loss: 0.040366 | Val MSE: 0.000533 | Val MAE: 0.017255 | Val R²: 0.4596 | [Boundary loss] 0.002001 | [Heaters loss] 0.000568 | [Physics loss] 2.239199 | Val Accuracy: 29.02% | LR: 0.000100000
# Epoch 39 - Train Loss: 0.036682 | Val MSE: 0.000982 | Val MAE: 0.019604 | Val R²: 0.0030 | [Boundary loss] 0.005599 | [Heaters loss] 0.001091 | [Physics loss] 1.692232 | Val Accuracy: 34.06% | LR: 0.000100000
# Epoch 40 - Train Loss: 0.034127 | Val MSE: 0.000256 | Val MAE: 0.012358 | Val R²: 0.7404 | [Boundary loss] 0.002263 | [Heaters loss] 0.000303 | [Physics loss] 1.655727 | Val Accuracy: 42.46% | LR: 0.000100000
# Epoch 41 - Train Loss: 0.032843 | Val MSE: 0.000310 | Val MAE: 0.013239 | Val R²: 0.6860 | [Boundary loss] 0.003256 | [Heaters loss] 0.000379 | [Physics loss] 1.807806 | Val Accuracy: 41.62% | LR: 0.000100000
# Epoch 42 - Train Loss: 0.029650 | Val MSE: 0.000285 | Val MAE: 0.012782 | Val R²: 0.7136 | [Boundary loss] 0.004252 | [Heaters loss] 0.000379 | [Physics loss] 1.622792 | Val Accuracy: 42.64% | LR: 0.000100000
# Epoch 43 - Train Loss: 0.029602 | Val MSE: 0.000610 | Val MAE: 0.018476 | Val R²: 0.3817 | [Boundary loss] 0.002730 | [Heaters loss] 0.000660 | [Physics loss] 1.552422 | Val Accuracy: 29.85% | LR: 0.000100000
# Epoch 44 - Train Loss: 0.026562 | Val MSE: 0.000532 | Val MAE: 0.014421 | Val R²: 0.4613 | [Boundary loss] 0.002090 | [Heaters loss] 0.000569 | [Physics loss] 1.951880 | Val Accuracy: 42.47% | LR: 0.000100000
# Epoch 45 - Train Loss: 0.026550 | Val MSE: 0.000614 | Val MAE: 0.018695 | Val R²: 0.3795 | [Boundary loss] 0.001260 | [Heaters loss] 0.000630 | [Physics loss] 1.700214 | Val Accuracy: 28.59% | LR: 0.000100000
# Epoch 46 - Train Loss: 0.024286 | Val MSE: 0.001053 | Val MAE: 0.019155 | Val R²: -0.0726 | [Boundary loss] 0.002237 | [Heaters loss] 0.001081 | [Physics loss] 1.701696 | Val Accuracy: 36.15% | LR: 0.000100000
# Epoch 47 - Train Loss: 0.023861 | Val MSE: 0.000471 | Val MAE: 0.017400 | Val R²: 0.5203 | [Boundary loss] 0.003979 | [Heaters loss] 0.000554 | [Physics loss] 1.552636 | Val Accuracy: 27.86% | LR: 0.000100000
# Epoch 48 - Train Loss: 0.021393 | Val MSE: 0.001136 | Val MAE: 0.019493 | Val R²: -0.1589 | [Boundary loss] 0.002442 | [Heaters loss] 0.001167 | [Physics loss] 1.596788 | Val Accuracy: 35.84% | LR: 0.000100000
# Epoch 49 - Train Loss: 0.021657 | Val MSE: 0.000476 | Val MAE: 0.016662 | Val R²: 0.5165 | [Boundary loss] 0.003121 | [Heaters loss] 0.000538 | [Physics loss] 1.620059 | Val Accuracy: 31.66% | LR: 0.000100000
# Epoch 50 - Train Loss: 0.021313 | Val MSE: 0.000304 | Val MAE: 0.013240 | Val R²: 0.6923 | [Boundary loss] 0.002947 | [Heaters loss] 0.000366 | [Physics loss] 1.688952 | Val Accuracy: 41.39% | LR: 0.000100000
# Epoch 51 - Train Loss: 0.020357 | Val MSE: 0.000558 | Val MAE: 0.015293 | Val R²: 0.4321 | [Boundary loss] 0.001188 | [Heaters loss] 0.000573 | [Physics loss] 1.734870 | Val Accuracy: 38.27% | LR: 0.000050000
# Epoch 52 - Train Loss: 0.015815 | Val MSE: 0.000258 | Val MAE: 0.012693 | Val R²: 0.7378 | [Boundary loss] 0.002344 | [Heaters loss] 0.000307 | [Physics loss] 1.644237 | Val Accuracy: 40.50% | LR: 0.000050000
# Epoch 53 - Train Loss: 0.014646 | Val MSE: 0.000517 | Val MAE: 0.015527 | Val R²: 0.4740 | [Boundary loss] 0.002359 | [Heaters loss] 0.000560 | [Physics loss] 1.655613 | Val Accuracy: 37.45% | LR: 0.000050000
# Epoch 54 - Train Loss: 0.014508 | Val MSE: 0.000300 | Val MAE: 0.012529 | Val R²: 0.6966 | [Boundary loss] 0.003026 | [Heaters loss] 0.000365 | [Physics loss] 1.553089 | Val Accuracy: 44.89% | LR: 0.000050000
# Epoch 55 - Train Loss: 0.014009 | Val MSE: 0.000458 | Val MAE: 0.015597 | Val R²: 0.5359 | [Boundary loss] 0.004533 | [Heaters loss] 0.000554 | [Physics loss] 1.730603 | Val Accuracy: 36.06% | LR: 0.000050000
# Epoch 56 - Train Loss: 0.013764 | Val MSE: 0.000457 | Val MAE: 0.014071 | Val R²: 0.5343 | [Boundary loss] 0.003103 | [Heaters loss] 0.000520 | [Physics loss] 1.575606 | Val Accuracy: 43.95% | LR: 0.000050000
# Epoch 57 - Train Loss: 0.013260 | Val MSE: 0.000344 | Val MAE: 0.013498 | Val R²: 0.6512 | [Boundary loss] 0.002117 | [Heaters loss] 0.000386 | [Physics loss] 1.670907 | Val Accuracy: 41.82% | LR: 0.000050000
# Epoch 58 - Train Loss: 0.013424 | Val MSE: 0.000226 | Val MAE: 0.011605 | Val R²: 0.7711 | [Boundary loss] 0.002264 | [Heaters loss] 0.000274 | [Physics loss] 1.683678 | Val Accuracy: 44.64% | LR: 0.000050000
# Epoch 59 - Train Loss: 0.012943 | Val MSE: 0.000173 | Val MAE: 0.010293 | Val R²: 0.8245 | [Boundary loss] 0.001709 | [Heaters loss] 0.000209 | [Physics loss] 1.545018 | Val Accuracy: 49.10% | LR: 0.000050000
# Epoch 60 - Train Loss: 0.012149 | Val MSE: 0.000361 | Val MAE: 0.013142 | Val R²: 0.6327 | [Boundary loss] 0.002283 | [Heaters loss] 0.000406 | [Physics loss] 1.572425 | Val Accuracy: 43.93% | LR: 0.000050000
# Epoch 61 - Train Loss: 0.012409 | Val MSE: 0.000173 | Val MAE: 0.010238 | Val R²: 0.8244 | [Boundary loss] 0.001729 | [Heaters loss] 0.000210 | [Physics loss] 1.568855 | Val Accuracy: 49.36% | LR: 0.000050000
# Epoch 62 - Train Loss: 0.011996 | Val MSE: 0.000308 | Val MAE: 0.012756 | Val R²: 0.6862 | [Boundary loss] 0.002975 | [Heaters loss] 0.000371 | [Physics loss] 1.560373 | Val Accuracy: 44.39% | LR: 0.000050000
# Epoch 63 - Train Loss: 0.011528 | Val MSE: 0.000446 | Val MAE: 0.013161 | Val R²: 0.5468 | [Boundary loss] 0.003800 | [Heaters loss] 0.000525 | [Physics loss] 1.593508 | Val Accuracy: 47.14% | LR: 0.000050000
# Epoch 64 - Train Loss: 0.011166 | Val MSE: 0.000394 | Val MAE: 0.013431 | Val R²: 0.5999 | [Boundary loss] 0.001001 | [Heaters loss] 0.000409 | [Physics loss] 1.804275 | Val Accuracy: 42.93% | LR: 0.000050000
# Epoch 65 - Train Loss: 0.010994 | Val MSE: 0.000233 | Val MAE: 0.011500 | Val R²: 0.7635 | [Boundary loss] 0.003467 | [Heaters loss] 0.000310 | [Physics loss] 1.584337 | Val Accuracy: 47.65% | LR: 0.000050000
# Epoch 66 - Train Loss: 0.010909 | Val MSE: 0.000325 | Val MAE: 0.013567 | Val R²: 0.6702 | [Boundary loss] 0.003921 | [Heaters loss] 0.000410 | [Physics loss] 1.696861 | Val Accuracy: 41.28% | LR: 0.000050000
# Epoch 67 - Train Loss: 0.010206 | Val MSE: 0.000472 | Val MAE: 0.016194 | Val R²: 0.5203 | [Boundary loss] 0.004759 | [Heaters loss] 0.000573 | [Physics loss] 1.704477 | Val Accuracy: 35.11% | LR: 0.000050000
# Epoch 68 - Train Loss: 0.010062 | Val MSE: 0.000829 | Val MAE: 0.019491 | Val R²: 0.1552 | [Boundary loss] 0.004440 | [Heaters loss] 0.000915 | [Physics loss] 1.574936 | Val Accuracy: 31.53% | LR: 0.000050000
# Epoch 69 - Train Loss: 0.010095 | Val MSE: 0.002207 | Val MAE: 0.029349 | Val R²: -1.2507 | [Boundary loss] 0.004543 | [Heaters loss] 0.002262 | [Physics loss] 1.695935 | Val Accuracy: 15.95% | LR: 0.000050000
# Epoch 70 - Train Loss: 0.010024 | Val MSE: 0.000217 | Val MAE: 0.011653 | Val R²: 0.7791 | [Boundary loss] 0.001944 | [Heaters loss] 0.000258 | [Physics loss] 1.584942 | Val Accuracy: 43.54% | LR: 0.000025000
# Epoch 71 - Train Loss: 0.008587 | Val MSE: 0.000216 | Val MAE: 0.011147 | Val R²: 0.7806 | [Boundary loss] 0.002616 | [Heaters loss] 0.000273 | [Physics loss] 1.558367 | Val Accuracy: 47.85% | LR: 0.000025000
# Epoch 72 - Train Loss: 0.008630 | Val MSE: 0.000442 | Val MAE: 0.015012 | Val R²: 0.5505 | [Boundary loss] 0.003948 | [Heaters loss] 0.000525 | [Physics loss] 1.560777 | Val Accuracy: 37.27% | LR: 0.000025000
# Epoch 73 - Train Loss: 0.008599 | Val MSE: 0.000337 | Val MAE: 0.013254 | Val R²: 0.6568 | [Boundary loss] 0.003568 | [Heaters loss] 0.000414 | [Physics loss] 1.701250 | Val Accuracy: 43.25% | LR: 0.000025000
# Epoch 74 - Train Loss: 0.008519 | Val MSE: 0.000346 | Val MAE: 0.013820 | Val R²: 0.6478 | [Boundary loss] 0.004014 | [Heaters loss] 0.000433 | [Physics loss] 1.573256 | Val Accuracy: 41.31% | LR: 0.000025000
# Epoch 75 - Train Loss: 0.008293 | Val MSE: 0.000281 | Val MAE: 0.011926 | Val R²: 0.7147 | [Boundary loss] 0.003956 | [Heaters loss] 0.000368 | [Physics loss] 1.534797 | Val Accuracy: 48.68% | LR: 0.000025000
# Epoch 76 - Train Loss: 0.008203 | Val MSE: 0.000288 | Val MAE: 0.012525 | Val R²: 0.7064 | [Boundary loss] 0.003574 | [Heaters loss] 0.000366 | [Physics loss] 1.565028 | Val Accuracy: 45.41% | LR: 0.000025000
# Epoch 77 - Train Loss: 0.008129 | Val MSE: 0.000301 | Val MAE: 0.012717 | Val R²: 0.6944 | [Boundary loss] 0.004002 | [Heaters loss] 0.000389 | [Physics loss] 1.581853 | Val Accuracy: 45.12% | LR: 0.000025000
# Epoch 78 - Train Loss: 0.007980 | Val MSE: 0.000381 | Val MAE: 0.014137 | Val R²: 0.6122 | [Boundary loss] 0.004407 | [Heaters loss] 0.000476 | [Physics loss] 1.538795 | Val Accuracy: 41.22% | LR: 0.000025000
# Epoch 79 - Train Loss: 0.007740 | Val MSE: 0.000543 | Val MAE: 0.017000 | Val R²: 0.4471 | [Boundary loss] 0.004858 | [Heaters loss] 0.000645 | [Physics loss] 1.572369 | Val Accuracy: 33.29% | LR: 0.000025000
# Epoch 80 - Train Loss: 0.007715 | Val MSE: 0.000418 | Val MAE: 0.015550 | Val R²: 0.5749 | [Boundary loss] 0.004592 | [Heaters loss] 0.000517 | [Physics loss] 1.544428 | Val Accuracy: 35.12% | LR: 0.000025000
# Epoch 81 - Train Loss: 0.007557 | Val MSE: 0.000384 | Val MAE: 0.014075 | Val R²: 0.6089 | [Boundary loss] 0.004252 | [Heaters loss] 0.000476 | [Physics loss] 1.564786 | Val Accuracy: 41.81% | LR: 0.000012500
# Epoch 82 - Train Loss: 0.007213 | Val MSE: 0.000276 | Val MAE: 0.012495 | Val R²: 0.7195 | [Boundary loss] 0.003687 | [Heaters loss] 0.000357 | [Physics loss] 1.549492 | Val Accuracy: 44.46% | LR: 0.000012500
# Epoch 83 - Train Loss: 0.007131 | Val MSE: 0.000331 | Val MAE: 0.013770 | Val R²: 0.6641 | [Boundary loss] 0.003803 | [Heaters loss] 0.000413 | [Physics loss] 1.539700 | Val Accuracy: 39.86% | LR: 0.000012500
# Epoch 84 - Train Loss: 0.006975 | Val MSE: 0.000320 | Val MAE: 0.013014 | Val R²: 0.6750 | [Boundary loss] 0.004214 | [Heaters loss] 0.000412 | [Physics loss] 1.585420 | Val Accuracy: 44.62% | LR: 0.000012500
# Epoch 85 - Train Loss: 0.006946 | Val MSE: 0.000343 | Val MAE: 0.014147 | Val R²: 0.6516 | [Boundary loss] 0.003689 | [Heaters loss] 0.000422 | [Physics loss] 1.578463 | Val Accuracy: 38.31% | LR: 0.000012500
# Epoch 86 - Train Loss: 0.006931 | Val MSE: 0.000445 | Val MAE: 0.014776 | Val R²: 0.5467 | [Boundary loss] 0.004803 | [Heaters loss] 0.000548 | [Physics loss] 1.546518 | Val Accuracy: 41.38% | LR: 0.000012500
# Epoch 87 - Train Loss: 0.006870 | Val MSE: 0.000365 | Val MAE: 0.013958 | Val R²: 0.6283 | [Boundary loss] 0.003852 | [Heaters loss] 0.000448 | [Physics loss] 1.539278 | Val Accuracy: 41.09% | LR: 0.000012500
# Epoch 88 - Train Loss: 0.006842 | Val MSE: 0.000320 | Val MAE: 0.013650 | Val R²: 0.6753 | [Boundary loss] 0.003724 | [Heaters loss] 0.000400 | [Physics loss] 1.571824 | Val Accuracy: 40.22% | LR: 0.000012500
# Epoch 89 - Train Loss: 0.006733 | Val MSE: 0.000328 | Val MAE: 0.013665 | Val R²: 0.6674 | [Boundary loss] 0.004144 | [Heaters loss] 0.000418 | [Physics loss] 1.556309 | Val Accuracy: 40.80% | LR: 0.000012500
# Epoch 90 - Train Loss: 0.006613 | Val MSE: 0.000382 | Val MAE: 0.015108 | Val R²: 0.6119 | [Boundary loss] 0.003835 | [Heaters loss] 0.000464 | [Physics loss] 1.549765 | Val Accuracy: 35.42% | LR: 0.000012500
# Epoch 91 - Train Loss: 0.006669 | Val MSE: 0.000572 | Val MAE: 0.017320 | Val R²: 0.4178 | [Boundary loss] 0.004075 | [Heaters loss] 0.000655 | [Physics loss] 1.599403 | Val Accuracy: 31.95% | LR: 0.000012500
# Epoch 92 - Train Loss: 0.006761 | Val MSE: 0.000248 | Val MAE: 0.011651 | Val R²: 0.7478 | [Boundary loss] 0.003693 | [Heaters loss] 0.000330 | [Physics loss] 1.566535 | Val Accuracy: 48.10% | LR: 0.000006250
# Epoch 93 - Train Loss: 0.006421 | Val MSE: 0.000309 | Val MAE: 0.013241 | Val R²: 0.6860 | [Boundary loss] 0.003324 | [Heaters loss] 0.000380 | [Physics loss] 1.553517 | Val Accuracy: 41.80% | LR: 0.000006250
# Epoch 94 - Train Loss: 0.006315 | Val MSE: 0.000298 | Val MAE: 0.013135 | Val R²: 0.6970 | [Boundary loss] 0.003312 | [Heaters loss] 0.000370 | [Physics loss] 1.568510 | Val Accuracy: 41.53% | LR: 0.000006250
# Epoch 95 - Train Loss: 0.006319 | Val MSE: 0.000390 | Val MAE: 0.015084 | Val R²: 0.6033 | [Boundary loss] 0.004186 | [Heaters loss] 0.000480 | [Physics loss] 1.541753 | Val Accuracy: 36.01% | LR: 0.000006250
# Epoch 96 - Train Loss: 0.006245 | Val MSE: 0.000363 | Val MAE: 0.014187 | Val R²: 0.6311 | [Boundary loss] 0.004225 | [Heaters loss] 0.000454 | [Physics loss] 1.538435 | Val Accuracy: 39.81% | LR: 0.000006250
# Epoch 97 - Train Loss: 0.006277 | Val MSE: 0.000332 | Val MAE: 0.013500 | Val R²: 0.6628 | [Boundary loss] 0.004489 | [Heaters loss] 0.000430 | [Physics loss] 1.547309 | Val Accuracy: 42.59% | LR: 0.000006250
# Epoch 98 - Train Loss: 0.006363 | Val MSE: 0.000329 | Val MAE: 0.013588 | Val R²: 0.6663 | [Boundary loss] 0.004114 | [Heaters loss] 0.000419 | [Physics loss] 1.600654 | Val Accuracy: 41.72% | LR: 0.000006250
# Epoch 99 - Train Loss: 0.006352 | Val MSE: 0.000317 | Val MAE: 0.013505 | Val R²: 0.6777 | [Boundary loss] 0.003637 | [Heaters loss] 0.000396 | [Physics loss] 1.570935 | Val Accuracy: 41.05% | LR: 0.000006250
# Epoch 100 - Train Loss: 0.006249 | Val MSE: 0.000289 | Val MAE: 0.012691 | Val R²: 0.7061 | [Boundary loss] 0.003570 | [Heaters loss] 0.000367 | [Physics loss] 1.536781 | Val Accuracy: 44.05% | LR: 0.000006250
# Epoch 101 - Train Loss: 0.006181 | Val MSE: 0.000423 | Val MAE: 0.015572 | Val R²: 0.5703 | [Boundary loss] 0.004253 | [Heaters loss] 0.000514 | [Physics loss] 1.562623 | Val Accuracy: 34.45% | LR: 0.000006250
# Epoch 102 - Train Loss: 0.006168 | Val MSE: 0.000315 | Val MAE: 0.013522 | Val R²: 0.6805 | [Boundary loss] 0.003572 | [Heaters loss] 0.000392 | [Physics loss] 1.543005 | Val Accuracy: 40.56% | LR: 0.000006250
# Epoch 103 - Train Loss: 0.006171 | Val MSE: 0.000362 | Val MAE: 0.014030 | Val R²: 0.6324 | [Boundary loss] 0.004241 | [Heaters loss] 0.000453 | [Physics loss] 1.539935 | Val Accuracy: 41.11% | LR: 0.000003125
# Epoch 104 - Train Loss: 0.006069 | Val MSE: 0.000317 | Val MAE: 0.013245 | Val R²: 0.6778 | [Boundary loss] 0.003935 | [Heaters loss] 0.000403 | [Physics loss] 1.551936 | Val Accuracy: 42.86% | LR: 0.000003125
# Epoch 105 - Train Loss: 0.005954 | Val MSE: 0.000302 | Val MAE: 0.013083 | Val R²: 0.6926 | [Boundary loss] 0.003693 | [Heaters loss] 0.000383 | [Physics loss] 1.552289 | Val Accuracy: 42.53% | LR: 0.000003125
# Epoch 106 - Train Loss: 0.005998 | Val MSE: 0.000357 | Val MAE: 0.014054 | Val R²: 0.6377 | [Boundary loss] 0.004849 | [Heaters loss] 0.000463 | [Physics loss] 1.576390 | Val Accuracy: 40.59% | LR: 0.000003125
# Epoch 107 - Train Loss: 0.005980 | Val MSE: 0.000324 | Val MAE: 0.013407 | Val R²: 0.6711 | [Boundary loss] 0.004049 | [Heaters loss] 0.000412 | [Physics loss] 1.576117 | Val Accuracy: 42.36% | LR: 0.000003125
# Epoch 108 - Train Loss: 0.006034 | Val MSE: 0.000339 | Val MAE: 0.013438 | Val R²: 0.6558 | [Boundary loss] 0.004779 | [Heaters loss] 0.000444 | [Physics loss] 1.546424 | Val Accuracy: 43.40% | LR: 0.000003125
# Epoch 109 - Train Loss: 0.005913 | Val MSE: 0.000344 | Val MAE: 0.013757 | Val R²: 0.6501 | [Boundary loss] 0.004190 | [Heaters loss] 0.000435 | [Physics loss] 1.534750 | Val Accuracy: 41.01% | LR: 0.000003125
# Epoch 110 - Train Loss: 0.005928 | Val MSE: 0.000346 | Val MAE: 0.013861 | Val R²: 0.6489 | [Boundary loss] 0.004187 | [Heaters loss] 0.000437 | [Physics loss] 1.569315 | Val Accuracy: 41.01% | LR: 0.000003125
# Epoch 111 - Train Loss: 0.005862 | Val MSE: 0.000331 | Val MAE: 0.013685 | Val R²: 0.6640 | [Boundary loss] 0.003926 | [Heaters loss] 0.000416 | [Physics loss] 1.551862 | Val Accuracy: 40.78% | LR: 0.000003125
# Epoch 112 - Train Loss: 0.005887 | Val MSE: 0.000311 | Val MAE: 0.013301 | Val R²: 0.6845 | [Boundary loss] 0.003818 | [Heaters loss] 0.000394 | [Physics loss] 1.577874 | Val Accuracy: 41.76% | LR: 0.000003125
# Epoch 113 - Train Loss: 0.005896 | Val MSE: 0.000394 | Val MAE: 0.014790 | Val R²: 0.5996 | [Boundary loss] 0.004356 | [Heaters loss] 0.000488 | [Physics loss] 1.541322 | Val Accuracy: 38.11% | LR: 0.000003125
# Epoch 114 - Train Loss: 0.005876 | Val MSE: 0.000344 | Val MAE: 0.013791 | Val R²: 0.6503 | [Boundary loss] 0.004485 | [Heaters loss] 0.000442 | [Physics loss] 1.547748 | Val Accuracy: 41.41% | LR: 0.000001563
# Epoch 115 - Train Loss: 0.005789 | Val MSE: 0.000304 | Val MAE: 0.013087 | Val R²: 0.6914 | [Boundary loss] 0.003245 | [Heaters loss] 0.000373 | [Physics loss] 1.547112 | Val Accuracy: 42.21% | LR: 0.000001563
# Epoch 116 - Train Loss: 0.005762 | Val MSE: 0.000325 | Val MAE: 0.013475 | Val R²: 0.6700 | [Boundary loss] 0.003949 | [Heaters loss] 0.000411 | [Physics loss] 1.554788 | Val Accuracy: 41.77% | LR: 0.000001563
# Epoch 117 - Train Loss: 0.005786 | Val MSE: 0.000327 | Val MAE: 0.013163 | Val R²: 0.6681 | [Boundary loss] 0.004790 | [Heaters loss] 0.000433 | [Physics loss] 1.545272 | Val Accuracy: 44.35% | LR: 0.000001563
# Epoch 118 - Train Loss: 0.005796 | Val MSE: 0.000345 | Val MAE: 0.013986 | Val R²: 0.6491 | [Boundary loss] 0.003835 | [Heaters loss] 0.000428 | [Physics loss] 1.536271 | Val Accuracy: 39.73% | LR: 0.000001563
# Epoch 119 - Train Loss: 0.005831 | Val MSE: 0.000329 | Val MAE: 0.013530 | Val R²: 0.6656 | [Boundary loss] 0.003921 | [Heaters loss] 0.000414 | [Physics loss] 1.535170 | Val Accuracy: 41.49% | LR: 0.000001563
# Epoch 120 - Train Loss: 0.005786 | Val MSE: 0.000300 | Val MAE: 0.012826 | Val R²: 0.6957 | [Boundary loss] 0.003770 | [Heaters loss] 0.000382 | [Physics loss] 1.541841 | Val Accuracy: 44.01% | LR: 0.000001563
# Epoch 121 - Train Loss: 0.005811 | Val MSE: 0.000329 | Val MAE: 0.013631 | Val R²: 0.6655 | [Boundary loss] 0.003402 | [Heaters loss] 0.000402 | [Physics loss] 1.552404 | Val Accuracy: 40.67% | LR: 0.000001563
# Epoch 122 - Train Loss: 0.005808 | Val MSE: 0.000363 | Val MAE: 0.014257 | Val R²: 0.6310 | [Boundary loss] 0.003937 | [Heaters loss] 0.000447 | [Physics loss] 1.535739 | Val Accuracy: 39.07% | LR: 0.000001563
# Epoch 123 - Train Loss: 0.005821 | Val MSE: 0.000323 | Val MAE: 0.013200 | Val R²: 0.6725 | [Boundary loss] 0.004419 | [Heaters loss] 0.000420 | [Physics loss] 1.553460 | Val Accuracy: 43.67% | LR: 0.000001563
# Epoch 124 - Train Loss: 0.005838 | Val MSE: 0.000296 | Val MAE: 0.012725 | Val R²: 0.6999 | [Boundary loss] 0.003786 | [Heaters loss] 0.000378 | [Physics loss] 1.562358 | Val Accuracy: 44.59% | LR: 0.000001563
# Epoch 125 - Train Loss: 0.005788 | Val MSE: 0.000359 | Val MAE: 0.014353 | Val R²: 0.6350 | [Boundary loss] 0.004031 | [Heaters loss] 0.000446 | [Physics loss] 1.533131 | Val Accuracy: 38.38% | LR: 0.000000781
# Epoch 126 - Train Loss: 0.005725 | Val MSE: 0.000311 | Val MAE: 0.012950 | Val R²: 0.6843 | [Boundary loss] 0.004261 | [Heaters loss] 0.000404 | [Physics loss] 1.552873 | Val Accuracy: 44.56% | LR: 0.000000781
# Epoch 127 - Train Loss: 0.005731 | Val MSE: 0.000340 | Val MAE: 0.013727 | Val R²: 0.6549 | [Boundary loss] 0.003735 | [Heaters loss] 0.000420 | [Physics loss] 1.547338 | Val Accuracy: 41.02% | LR: 0.000000781
# Epoch 128 - Train Loss: 0.005800 | Val MSE: 0.000362 | Val MAE: 0.014195 | Val R²: 0.6323 | [Boundary loss] 0.004043 | [Heaters loss] 0.000449 | [Physics loss] 1.544113 | Val Accuracy: 39.93% | LR: 0.000000781
# Epoch 129 - Train Loss: 0.005743 | Val MSE: 0.000377 | Val MAE: 0.014688 | Val R²: 0.6171 | [Boundary loss] 0.003972 | [Heaters loss] 0.000462 | [Physics loss] 1.540697 | Val Accuracy: 37.44% | LR: 0.000000781
# Epoch 130 - Train Loss: 0.005697 | Val MSE: 0.000305 | Val MAE: 0.012920 | Val R²: 0.6900 | [Boundary loss] 0.003971 | [Heaters loss] 0.000392 | [Physics loss] 1.551130 | Val Accuracy: 44.07% | LR: 0.000000781
# Epoch 131 - Train Loss: 0.005735 | Val MSE: 0.000282 | Val MAE: 0.012303 | Val R²: 0.7139 | [Boundary loss] 0.003543 | [Heaters loss] 0.000359 | [Physics loss] 1.546647 | Val Accuracy: 46.19% | LR: 0.000000781
# Epoch 132 - Train Loss: 0.005743 | Val MSE: 0.000339 | Val MAE: 0.014249 | Val R²: 0.6550 | [Boundary loss] 0.003083 | [Heaters loss] 0.000404 | [Physics loss] 1.532152 | Val Accuracy: 36.82% | LR: 0.000000781
# Epoch 133 - Train Loss: 0.005732 | Val MSE: 0.000295 | Val MAE: 0.012584 | Val R²: 0.7005 | [Boundary loss] 0.003515 | [Heaters loss] 0.000371 | [Physics loss] 1.543538 | Val Accuracy: 45.19% | LR: 0.000000781
# Epoch 134 - Train Loss: 0.005659 | Val MSE: 0.000255 | Val MAE: 0.011952 | Val R²: 0.7407 | [Boundary loss] 0.002766 | [Heaters loss] 0.000315 | [Physics loss] 1.554001 | Val Accuracy: 46.02% | LR: 0.000000781
# Epoch 135 - Train Loss: 0.005639 | Val MSE: 0.000405 | Val MAE: 0.015270 | Val R²: 0.5880 | [Boundary loss] 0.004268 | [Heaters loss] 0.000497 | [Physics loss] 1.544829 | Val Accuracy: 36.04% | LR: 0.000000781
# Epoch 136 - Train Loss: 0.005739 | Val MSE: 0.000355 | Val MAE: 0.014108 | Val R²: 0.6398 | [Boundary loss] 0.004145 | [Heaters loss] 0.000444 | [Physics loss] 1.557722 | Val Accuracy: 39.93% | LR: 0.000000391
# Epoch 137 - Train Loss: 0.005684 | Val MSE: 0.000347 | Val MAE: 0.014106 | Val R²: 0.6473 | [Boundary loss] 0.003863 | [Heaters loss] 0.000430 | [Physics loss] 1.553365 | Val Accuracy: 39.22% | LR: 0.000000391
# Epoch 138 - Train Loss: 0.005694 | Val MSE: 0.000413 | Val MAE: 0.015499 | Val R²: 0.5804 | [Boundary loss] 0.004454 | [Heaters loss] 0.000508 | [Physics loss] 1.547491 | Val Accuracy: 35.24% | LR: 0.000000391
# Epoch 139 - Train Loss: 0.005723 | Val MSE: 0.000364 | Val MAE: 0.014099 | Val R²: 0.6302 | [Boundary loss] 0.004666 | [Heaters loss] 0.000466 | [Physics loss] 1.543766 | Val Accuracy: 40.99% | LR: 0.000000391
# Epoch 140 - Train Loss: 0.005611 | Val MSE: 0.000353 | Val MAE: 0.014020 | Val R²: 0.6415 | [Boundary loss] 0.004185 | [Heaters loss] 0.000444 | [Physics loss] 1.548371 | Val Accuracy: 40.36% | LR: 0.000000391
# Epoch 141 - Train Loss: 0.005690 | Val MSE: 0.000397 | Val MAE: 0.015208 | Val R²: 0.5964 | [Boundary loss] 0.004463 | [Heaters loss] 0.000494 | [Physics loss] 1.543112 | Val Accuracy: 35.85% | LR: 0.000000391
# Epoch 142 - Train Loss: 0.005694 | Val MSE: 0.000322 | Val MAE: 0.013468 | Val R²: 0.6730 | [Boundary loss] 0.003506 | [Heaters loss] 0.000397 | [Physics loss] 1.553579 | Val Accuracy: 41.42% | LR: 0.000000391
# Epoch 143 - Train Loss: 0.005734 | Val MSE: 0.000320 | Val MAE: 0.013479 | Val R²: 0.6749 | [Boundary loss] 0.003657 | [Heaters loss] 0.000399 | [Physics loss] 1.543564 | Val Accuracy: 41.25% | LR: 0.000000391
# Epoch 144 - Train Loss: 0.005708 | Val MSE: 0.000275 | Val MAE: 0.012295 | Val R²: 0.7203 | [Boundary loss] 0.003501 | [Heaters loss] 0.000352 | [Physics loss] 1.547628 | Val Accuracy: 45.69% | LR: 0.000000391
# Epoch 145 - Train Loss: 0.005694 | Val MSE: 0.000323 | Val MAE: 0.013212 | Val R²: 0.6720 | [Boundary loss] 0.004295 | [Heaters loss] 0.000417 | [Physics loss] 1.554380 | Val Accuracy: 43.69% | LR: 0.000000391
# Epoch 146 - Train Loss: 0.005609 | Val MSE: 0.000398 | Val MAE: 0.014972 | Val R²: 0.5957 | [Boundary loss] 0.004540 | [Heaters loss] 0.000496 | [Physics loss] 1.542809 | Val Accuracy: 37.55% | LR: 0.000000391
# Epoch 147 - Train Loss: 0.005727 | Val MSE: 0.000318 | Val MAE: 0.013179 | Val R²: 0.6768 | [Boundary loss] 0.004056 | [Heaters loss] 0.000407 | [Physics loss] 1.547312 | Val Accuracy: 43.31% | LR: 0.000000195
# Epoch 148 - Train Loss: 0.005631 | Val MSE: 0.000315 | Val MAE: 0.013155 | Val R²: 0.6799 | [Boundary loss] 0.003785 | [Heaters loss] 0.000397 | [Physics loss] 1.547153 | Val Accuracy: 43.25% | LR: 0.000000195
# Epoch 149 - Train Loss: 0.005694 | Val MSE: 0.000326 | Val MAE: 0.013367 | Val R²: 0.6692 | [Boundary loss] 0.003894 | [Heaters loss] 0.000410 | [Physics loss] 1.555129 | Val Accuracy: 42.65% | LR: 0.000000195
# Epoch 150 - Train Loss: 0.005710 | Val MSE: 0.000343 | Val MAE: 0.013732 | Val R²: 0.6513 | [Boundary loss] 0.004445 | [Heaters loss] 0.000440 | [Physics loss] 1.546251 | Val Accuracy: 41.88% | LR: 0.000000195
# Epoch 151 - Train Loss: 0.005754 | Val MSE: 0.000314 | Val MAE: 0.013123 | Val R²: 0.6807 | [Boundary loss] 0.003982 | [Heaters loss] 0.000401 | [Physics loss] 1.549822 | Val Accuracy: 43.47% | LR: 0.000000195
# Epoch 152 - Train Loss: 0.005710 | Val MSE: 0.000319 | Val MAE: 0.013190 | Val R²: 0.6753 | [Boundary loss] 0.003887 | [Heaters loss] 0.000404 | [Physics loss] 1.544395 | Val Accuracy: 43.32% | LR: 0.000000195
# Epoch 153 - Train Loss: 0.005618 | Val MSE: 0.000335 | Val MAE: 0.013755 | Val R²: 0.6597 | [Boundary loss] 0.003900 | [Heaters loss] 0.000419 | [Physics loss] 1.543878 | Val Accuracy: 40.54% | LR: 0.000000195
# Epoch 154 - Train Loss: 0.005688 | Val MSE: 0.000348 | Val MAE: 0.013974 | Val R²: 0.6464 | [Boundary loss] 0.004041 | [Heaters loss] 0.000435 | [Physics loss] 1.544242 | Val Accuracy: 40.10% | LR: 0.000000195
# Epoch 155 - Train Loss: 0.005620 | Val MSE: 0.000325 | Val MAE: 0.013790 | Val R²: 0.6697 | [Boundary loss] 0.003503 | [Heaters loss] 0.000400 | [Physics loss] 1.543321 | Val Accuracy: 39.11% | LR: 0.000000195
# Epoch 156 - Train Loss: 0.005642 | Val MSE: 0.000366 | Val MAE: 0.014541 | Val R²: 0.6285 | [Boundary loss] 0.003982 | [Heaters loss] 0.000451 | [Physics loss] 1.539454 | Val Accuracy: 37.61% | LR: 0.000000195
# Epoch 157 - Train Loss: 0.005676 | Val MSE: 0.000322 | Val MAE: 0.013305 | Val R²: 0.6726 | [Boundary loss] 0.003880 | [Heaters loss] 0.000406 | [Physics loss] 1.545227 | Val Accuracy: 42.68% | LR: 0.000000195
# Epoch 158 - Train Loss: 0.005659 | Val MSE: 0.000389 | Val MAE: 0.015032 | Val R²: 0.6045 | [Boundary loss] 0.004289 | [Heaters loss] 0.000481 | [Physics loss] 1.548068 | Val Accuracy: 36.54% | LR: 0.000000098
# Epoch 159 - Train Loss: 0.005584 | Val MSE: 0.000358 | Val MAE: 0.014486 | Val R²: 0.6360 | [Boundary loss] 0.003715 | [Heaters loss] 0.000438 | [Physics loss] 1.545622 | Val Accuracy: 37.10% | LR: 0.000000098
#  Early stopping triggered at epoch 158

# %%
# Cargar el mejor modelo antes de guardar
if best_model_state is not None:
    model.load_state_dict(best_model_state)
else:
    print("Advertencia: No se ha encontrado un modelo mejor durante el entrenamiento.")

# Crear nombre de archivo con los hiperparámetros clave
model_name = (
    f"GAT_Layers_{config['num_layers']}_"
    f"HDim_{config['hidden_dim']}_"
    f"Epochs_{final_epoch}_"
    f"Heads_{config['heads']}_"
    f"Lr_{best_lr:.9f}_"
    f"B_LOSS_{config['use_boundary_loss']}_"
    f"Lambda_{config['lambda_boundary']}_"
    f"H_LOSS_{config['use_heater_loss']}_"
    f"Lambda_{config['lambda_heater']}_"
    f"PI_{config['use_physics']}_"
    f"Lambda_{config['lambda_physics']}_"
    f"Batch_{config['batch_size']}.pth"
)
print("Nombre del modelo:", model_name)
# Out:
# Nombre del modelo: GAT_Layers_8_HDim_128_Epochs_59_Heads_4_Lr_0.000050000_B_LOSS_True_Lambda_1_H_LOSS_True_Lambda_10_PI_True_Lambda_0.0001_Batch_16.pth

# %%
# GRAFICAR MSE
# Crear carpeta si no existe
os.makedirs("LOSS_IMG", exist_ok=True)
loss_img_filename = model_name.replace(".pth", ".svg")
loss_img_path = os.path.join("LOSS_IMG", loss_img_filename)

plt.figure(figsize=(8, 5))
plt.plot(train_losses, label='Train Loss', linewidth=2)
plt.plot(val_losses, label='Val Loss (MSE)', linewidth=2)

# Escala logarítmica en y (opcional)
plt.yscale("log")

plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Evolución del Loss por Época')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Eje X con enteros
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

plt.savefig(loss_img_path, format="svg") 
plt.show()

# %% [markdown]
# ### Carga de modelos ya entrenados

# %%
if config["load_model"]:
    from dataset_utils import load_model_by_name


    # Definir el modelo a cargar, los modelos guardados no guardan la arquitectura de la red
    model = GAT(
        input_dim=config["input_dim"],
        hidden_dim= 64,
        output_dim=config["output_dim"],
        num_layers= 10,
        heads= 8,
        use_dropout=config["use_dropout"],
        dropout_rate=config["dropout_rate"],
        use_batchnorm=config["use_batchnorm"],
        use_residual=config["use_residual"]
    ).to(device)

    # Nombre exacto del archivo que quieres cargar, cambiar solo los números
    model_filename = "GAT_Layers_10_HDim_64_Epochs_1000_Heads_8_Lr_0.001_Batch_32.pth"

    # Cargar modelo concreto
    model = load_model_by_name(model, model_filename)
    print("Modelo cargado:", model_filename)

# %% [markdown]
# ### Evaluación

# %%
# Evaluar en test y graficar un ejemplo
print("Evaluando en test set con visualización de un ejemplo:")
test_mse, test_mae, test_r2, test_accuracy, test_physics, test_boundary, test_heater, test_rmse, test_total_loss = evaluate(
    model, test_loader, device, norm_info, lambda_physics=config["lambda_physics"],
    use_physics=config["use_physics"], lambda_boundary=config["lambda_boundary"],
    use_boundary_loss=config["use_boundary_loss"], lambda_heater=config["lambda_heater"],
    use_heater_loss=config["use_heater_loss"],
    error_threshold=config["error_threshold_K"],
    percentage_threshold=config["percentage_threshold"] if config["use_percentage_threshold"] else None,
    plot_results=True
)

physics_loss_str = f"{test_physics:.6f}" if test_physics is not None else "N/A"

max_T_outputs = norm_info["max_T_outputs"].to(device)
mae_K = test_mae * max_T_outputs
rmse_K = test_rmse * (max_T_outputs)
mse_K = test_mse * (max_T_outputs ** 2)
print(f"MAE en Kelvin     : {mae_K:.3f} K")
print(f"RMSE en Kelvin    : {rmse_K:.3f} K")
print(f"MSE en Kelvin²    : {mse_K:.3f} K²")


print("Resultados del test:")
print(f"MSE       : {test_mse:.6f}")
print(f"MAE       : {test_mae:.6f}")
print(f"R²        : {test_r2:.4f}")
print(f"Accuracy  : {test_accuracy:.2f}%")
print(f"Boundary Loss  : {test_boundary:.6f}")
print(f"Heaters Loss  : {test_heater:.6f}")
print(f"Physics Loss  : {physics_loss_str}")
# Out:
# Evaluando en test set con visualización de un ejemplo:
# Resultados del test:
# MSE       : 0.000362
# MAE       : 0.014619
# R²        : 0.6166
# Accuracy  : 36.67%
# Boundary Loss  : 0.003719
# Heaters Loss  : 0.000442
# Physics Loss  : 1.523571

# %% [markdown]
# ### GNNExplainer

# %%
from torch_geometric.explain import Explainer, GNNExplainer, ModelConfig

# Poner el modelo en modo evaluación
model.eval()

# Crear el explainer solo una vez
explainer = Explainer(
    model=model,
    algorithm=GNNExplainer(epochs=200),
    explanation_type='model',
    edge_mask_type='object',
    node_mask_type='attributes',
    model_config=ModelConfig(
        mode='regression',
        task_level='node',
        return_type='raw'
    )
)

# ---------------- CONFIGURACIÓN ----------------
graph_idx = 3      # <- Cambia este valor para elegir el grafo del test set
node_idx = 69     # <- Cambia este valor para elegir el nodo a explicar
# ------------------------------------------------

# Obtener el grafo y pasarlo a GPU si es necesario
graph = test_dataset[graph_idx].to(device)

# Predecir con el modelo
with torch.no_grad():
    pred = model(graph.x, graph.edge_index).squeeze()
true = graph.y.squeeze()
error = torch.abs(pred - true)

# Obtener explicación
explanation = explainer(
    x=graph.x,
    edge_index=graph.edge_index,
    index=node_idx
)

# Obtener importancia del explainer y agrupar por nodo
importance = explanation.node_mask.squeeze().cpu()      # Así obtenemos las features por nodo
importance = importance.view(-1, 3)                     # Cambiamos a un tensor que pueda ser interpretado como [num_nodes, num_features]
importance_per_node = importance.mean(dim=1)            # [num_nodes] Hacemos la media de la importancia de las 3 características en la predicción

# Obtener tamaño cuadrícula real del dataset
num_nodes = graph.y.numel()
print("Número de nodos:", num_nodes)
grid_size = int(num_nodes ** 0.5)
assert grid_size ** 2 == num_nodes, f"El número de nodos ({num_nodes}) no coincide con cuadrícula {grid_size}x{grid_size}"

# Convertir vectores a cuadrícula
importance_grid = importance_per_node.view(grid_size, grid_size)
error_grid = error.view(grid_size, grid_size).cpu()

# Visualización
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

im1 = axs[0].imshow(importance_grid, cmap='hot')
# Coordenadas del nodo que estás explicando
row = node_idx // grid_size
col = node_idx % grid_size

# Dibujar un punto rojo en la celda correspondiente
axs[0].plot(col, row, 'o', markersize=10, markeredgecolor='black', markerfacecolor='cyan', label='Nodo explicado')
axs[0].legend(loc='upper right')

axs[0].set_title(f"Importancia (nodo {node_idx})")
plt.colorbar(im1, ax=axs[0])

im2 = axs[1].imshow(error_grid, cmap='Blues')
# Número de nodos a etiquetar
top_n = 5  # "n" nodos de mayor error a mostrar

# Obtener los índices de los nodos con mayor error
top_error_nodes = torch.topk(error, top_n).indices.cpu()

for idx in top_error_nodes:
    idx = idx.item()
    row = idx // grid_size
    col = idx % grid_size
    axs[1].text(
        col, row, str(idx),
        ha='center', va='center',
        fontsize=8, fontweight='bold',
        color='black', bbox=dict(boxstyle='round,pad=0.2', facecolor='white', edgecolor='none', alpha=0.7)
    )
axs[1].set_title("Error absoluto por nodo")
plt.colorbar(im2, ax=axs[1])

plt.suptitle(f"Grafo {graph_idx} | Nodo {node_idx} explicado")
plt.tight_layout()
plt.show()
# Out:
# Número de nodos: 169

# %% [markdown]
# ### Guardado del modelo ya entrenado

# %%
# Crear carpeta si no existe
save_dir = "saved_models"
os.makedirs(save_dir, exist_ok=True)

# Guardar el modelo
model_path = os.path.join(save_dir, model_name)
if config["save_model"]:
    # Guardar el modelo entrenado
    torch.save(model.state_dict(), model_path)

    print(f" Modelo guardado en: {model_path}")
# Out:
#  Modelo guardado en: saved_models\GAT_Layers_8_HDim_128_Epochs_59_Heads_4_Lr_0.000050000_B_LOSS_True_Lambda_1_H_LOSS_True_Lambda_10_PI_True_Lambda_0.0001_Batch_16.pth

# %% [markdown]
# ### Predicción

# %%
fr train_eval import predict
from dataset_utils import load_latest_model
# Cargar el modelo más reciente
model = GAT(
    input_dim=config["input_dim"],
    hidden_dim=config["hidden_dim"],
    output_dim=config["output_dim"],
    num_layers=config["num_layers"],
    heads=config["heads"],
    use_dropout=config["use_dropout"],
    dropout_rate=config["dropout_rate"],
    use_batchnorm=config["use_batchnorm"],
    use_residual=config["use_residual"]
)

model = load_latest_model(model)

# Predecir sobre test
predicciones = predict(model, test_loader)

print("Predicciones shape:", predicciones.shape)
# Out:
#   Cell In[24], line 1
#     fr train_eval import predict
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Librerías

# %%
import torch
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import os
import sys
import time
import numpy as np
import random
from torch.optim.lr_scheduler import ReduceLROnPlateau
from gat_model import GAT
from torch_geometric.loader import DataLoader
from dataset_utils import generate_edge_index, build_graph_list, build_graph_from_sample
from train_eval import train, evaluate, EarlyStopping

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %%
dir_path = os.getcwd()
print(dir_path)
# Out:
# c:\Users\ramse\Escritorio\Aero Ordenador\4to Aero\2do Cuatri\ia_thermal\ernestoemedina\GAT_MK1

# %%
# Ruta del dataset completo
dataset_path = os.path.join(dir_path, "Datasets", "PCB_dataset.pth")
norm_dataset_path = os.path.join(dir_path, "Datasets", "PCB_Dataset_Norm.pth")
info_path = os.path.join(dir_path, "Datasets", "normalization_info.pth")

# Cargar dataset
dataset = torch.load(dataset_path)
norm_dataset = torch.load(norm_dataset_path)
norm_info = torch.load(info_path)
print(norm_dataset.outputs.min(), norm_dataset.outputs.max())

#Esto es para demostrar que el dataset no tiene valores cero, debido a la estandarización
#T_interfaces = dataset.T_interfaces.view(-1)

# Cuántos son exactamente 0
#num_exact_zeros = (T_interfaces == 0.0).sum().item()

# Cuántos son muy pequeños pero no exactamente 0
#num_near_zeros = ((T_interfaces != 0.0) & (T_interfaces.abs() < 1e-5)).sum().item()

# Valor mínimo no nulo
#min_nonzero = T_interfaces[T_interfaces != 0.0].min().item()

#print(f"Valores totales: {T_interfaces.numel()}")
#print(f"Exactamente cero: {num_exact_zeros}")
#print(f"Pequeños pero ≠ 0 (|x| < 1e-5): {num_near_zeros}")
#print(f"Valor mínimo no nulo: {min_nonzero}")
# Out:
# C:\Users\ramse\AppData\Local\Temp\ipykernel_17892\2813147112.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dataset = torch.load(dataset_path)
# C:\Users\ramse\AppData\Local\Temp\ipykernel_17892\2813147112.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   norm_dataset = torch.load(norm_dataset_path)
# C:\Users\ramse\AppData\Local\Temp\ipykernel_17892\2813147112.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   norm_info = torch.load(info_path)
# tensor(0.7124) tensor(1.)

# %% [markdown]
# ## Para desnormalizar

# %%
max_T_interfaces = norm_info["max_T_interfaces"]
max_Q_heaters = norm_info["max_Q_heaters"]
max_T_env = norm_info["max_T_env"]

## En ppio no debería ser necesario, ya que hemos cargado el dataset sin normalizar

def desnormalize_inputs(dataset_norm, idx):
    T_interfaces_norm = dataset_norm.T_interfaces[idx]
    Q_heaters_norm = dataset_norm.Q_heaters[idx]
    T_env_norm = dataset_norm.T_env[idx]
    
    T_interfaces_real = T_interfaces_norm * max_T_interfaces
    Q_heaters_real = Q_heaters_norm * max_Q_heaters
    T_env_real = T_env_norm * max_T_env
    
    return T_interfaces_real, Q_heaters_real, T_env_real

# %%
idx = 1
T_interfaces_real, Q_heaters_real, T_env_real = desnormalize_inputs(norm_dataset, idx)

# Por ejemplo:
print(torch.max(T_interfaces_real), "K")
print(torch.max(Q_heaters_real), "W")
print(torch.max(T_env_real), "K")
# Out:
# tensor(307.6863) K
# tensor(0.8122) W
# tensor(276.9086) K

# %%
# Seleccionar un índice para graficar
idx = 1  # Puedes cambiar este valor

# Obtener los valores reales de las CC en T, Q y T_env
T_interfaces_real = dataset.denormalize_T_interfaces(dataset.T_interfaces)
Q_heaters_real = dataset.denormalize_Q_heaters(dataset.Q_heaters)
T_env_real = dataset.denormalize_T_env(dataset.T_env)

print(T_interfaces_real.shape)
print(torch.max(T_interfaces_real[idx]), "K")
print(torch.max(Q_heaters_real[idx]), "W")
print(torch.max(T_env_real[idx]), "K")
# Out:
# torch.Size([30000, 13, 13])
# tensor(307.6863) K
# tensor(0.8122) W
# tensor(276.9086) K

# %%
idx = 10
T_interfaces_norm = norm_dataset.T_interfaces[idx]
Q_heaters_norm = norm_dataset.Q_heaters[idx]
T_env_norm = norm_dataset.T_env[idx]

# %%
# Crear figura para mostrar las 3 variables
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
im1 = axs[0].imshow(T_interfaces_norm.numpy(), cmap='hot')
axs[0].set_title("T_interfaces_norm [0–1]")
plt.colorbar(im1, ax=axs[0])

im2 = axs[1].imshow(Q_heaters_norm.numpy(), cmap='hot')
axs[1].set_title("Q_heaters_norm [0–1]")
plt.colorbar(im2, ax=axs[1])

im3 = axs[2].imshow(T_env_norm.numpy(), cmap='hot')
axs[2].set_title("T_env_norm [0–1]")
plt.colorbar(im3, ax=axs[2])

plt.suptitle(f"Entrada del dataset  idx = {idx}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## GAT

# %% [markdown]
# ### Configuración de la red

# %%
# Configuración del modelo
config = {
    "input_dim": 3,           # 3 canales: T_interfaces, Q_heaters, T_env
    "hidden_dim": 32,
    "output_dim": 1,
    "num_layers": 5,
    "use_dropout": True,
    "dropout_rate": 0.020421614575021965,
    "use_batchnorm": True,
    "use_residual": True,
    "batch_size": 32,
    "heads": 8,
    "lr": 0.0004911346333635377,
    "max_epochs": 10000,
    "early_stop_patience": 100,
    "error_threshold_K": 3.0,
    "use_percentage_threshold": False,
    "percentage_threshold": 1.0,  # solo si se activa la opción
    "save_model": True,
    "load_model": False, # Cargar un modelo preentrenado
    "factor" : 0.5 , # Factor de reducción del learning rate
    "patience" : 10 , # Épocas sin mejora para reducir el learning rate
    "min_lr" : 1e-9,  # evita que baje infinitamente el learning rate
    "use_physics" : True,
    "lambda_physics" : 0.0001, # Peso de la física en la función de pérdida
    "use_boundary_loss" : True,
    "lambda_boundary" : 1,
    "use_heater_loss" : True,
    "lambda_heater" : 10
}

# %%
grid_size = norm_dataset.inputs.shape[-1]
print("PCB cuadrada de", grid_size, "nodos por lado")
edge_index = generate_edge_index(grid_size=grid_size) # Matriz de adyacencia bidireccional
graphs = build_graph_list(norm_dataset, edge_index)
# Out:
# PCB cuadrada de 13 nodos por lado

# %%
# Por si en algún momento el Dataset tuviera un patrón al ser generado
random.seed(42)
random.shuffle(graphs)

# %%
# Ruta al dataset normalizado

# Extraer un tensor de salida
sample_output = norm_dataset.outputs[0]

# Imprimir estadísticas globales de outputs
all_outputs = norm_dataset.outputs.view(-1)
print(f"Mean of outputs: {all_outputs.mean().item():.4f}")
print(f"Std of outputs:  {all_outputs.std().item():.4f}")

# También desde los atributos si están disponibles
if hasattr(norm_dataset, "T_outputs_mean"):
    print(f"Atributo .T_outputs_mean: {norm_dataset.T_outputs_mean.item():.4f}")
    print(f"Atributo .T_outputs_std:  {norm_dataset.T_outputs_std.item():.4f}")
# Out:
# Mean of outputs: 0.8287
# Std of outputs:  0.0338
# Atributo .T_outputs_mean: 0.0000
# Atributo .T_outputs_std:  1.0000

# %% [markdown]
# ### División Dataset

# %%
# División del dataset
train_size = int(0.8 * len(graphs))
val_size = int(0.1 * len(graphs))
test_size = len(graphs) - train_size - val_size

train_dataset = graphs[:train_size]
val_dataset = graphs[train_size:train_size + val_size]
test_dataset = graphs[train_size + val_size:]

# Crear DataLoaders
batch_size = config["batch_size"]
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
model = GAT(
    input_dim=config["input_dim"],
    hidden_dim=config["hidden_dim"],
    output_dim=config["output_dim"],
    num_layers=config["num_layers"],
    heads=config["heads"],
    use_dropout=config["use_dropout"],
    dropout_rate=config["dropout_rate"],
    use_batchnorm=config["use_batchnorm"],
    use_residual=config["use_residual"]
).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=config["lr"])
scheduler = ReduceLROnPlateau(
    optimizer,
    mode='min',            # queremos minimizar el val_loss
    factor=config["factor"],            # reduce a la mitad el LR
    patience=config["patience"],           # espera 10 épocas sin mejora
    verbose=True,          # imprime info cuando reduce
    min_lr=config["min_lr"]            # evita que baje infinitamente
)
# Out:
# c:\Users\ramse\anaconda3\Lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
print("Forma de entrada:", norm_dataset.inputs[0].shape)
print("Forma de salida:", norm_dataset.outputs[0].shape)
# Out:
# Forma de entrada: torch.Size([3, 13, 13])
# Forma de salida: torch.Size([13, 13])

# %% [markdown]
# ### Entrenamiento

# %%
# Entrenamiento
train_losses = []
val_losses = []
epoch_times = []

early_stopper = EarlyStopping(patience=config["early_stop_patience"])
max_epochs = config["max_epochs"]
best_lr=config["lr"]

print("Iniciando entrenamiento...")
for epoch in range(config["max_epochs"]):
    start_time = time.time()
    
    # Entrenar
    train_loss = train(model, train_loader, optimizer, device, norm_info, lambda_physics=config["lambda_physics"],
                       use_physics=config["use_physics"], lambda_boundary=config["lambda_boundary"],
                       use_boundary_loss=config["use_boundary_loss"], lambda_heater=config["lambda_heater"],
                       use_heater_loss=config["use_heater_loss"])
    train_losses.append(train_loss)

    # Evaluar en validación
    val_mse, val_mae, val_r2, val_accuracy, val_physics, val_boundary, val_heaters, val_rmse, val_total_loss = evaluate(
        model, val_loader, device, norm_info, lambda_physics=config["lambda_physics"],
        use_physics=config["use_physics"], lambda_boundary=config["lambda_boundary"],
        use_boundary_loss=config["use_boundary_loss"], lambda_heater=config["lambda_heater"],
        use_heater_loss=config["use_heater_loss"],
        error_threshold=config["error_threshold_K"],
        percentage_threshold=config["percentage_threshold"] if config["use_percentage_threshold"] else None,
        plot_results=False
    )
    val_losses.append(val_mse)

    scheduler.step(val_mse)
    
    # Medir tiempo transcurrido
    epoch_duration = time.time() - start_time
    epoch_times.append(epoch_duration)

    # Formatear bien los losses opcionales
    physics_loss_str = f"{val_physics:.6f}" if config["use_physics"] else "N/A"
    boundary_loss_str = f"{val_boundary:.6f}" if config["use_boundary_loss"] else "N/A"
    heaters_loss_str = f"{val_heaters:.6f}" if config["use_heater_loss"] else "N/A"

    # Imprimir métricas
    print(f"Epoch {epoch + 1} - "
          f"Train Loss: {train_loss:.6f} | "
          f"Val MSE: {val_mse:.6f} | "
          f"Val MAE: {val_mae:.6f} | "
          f"Val R²: {val_r2:.4f} | "
          f"[Boundary loss] {boundary_loss_str} | "
          f"[Heaters loss] {heaters_loss_str} | "
          f"[Physics loss] {physics_loss_str} | "
          f"Val Accuracy: {val_accuracy:.2f}% | "
          f"LR: {optimizer.param_groups[0]['lr']:.9f} | "
          f"Time: {epoch_duration:.2f}s")

    # Guardar el mejor modelo en memoria
    if val_total_loss < early_stopper.best_loss:
        best_model_state = model.state_dict()
        final_epoch = epoch + 1
        best_lr = optimizer.param_groups[0]['lr']  # guardar lr actual

    early_stopper(val_total_loss, epoch)
    if early_stopper.early_stop:
        print(f" Early stopping triggered at epoch {epoch}")
        avg_epoch_time = np.mean(epoch_times)
        print(f"Tiempo por época        : {avg_epoch_time:.2f}")
        break
# Out:
# Iniciando entrenamiento...
# Epoch 1 - Train Loss: 0.871340 | Val MSE: 0.001231 | Val MAE: 0.027828 | Val R²: -0.1650 | [Boundary loss] 0.000799 | [Heaters loss] 0.001221 | [Physics loss] 2.426956 | Val Accuracy: 18.74% | LR: 0.000491135 | Time: 30.20s
# Epoch 2 - Train Loss: 0.208296 | Val MSE: 0.000888 | Val MAE: 0.023319 | Val R²: 0.1544 | [Boundary loss] 0.003766 | [Heaters loss] 0.000956 | [Physics loss] 2.220584 | Val Accuracy: 22.65% | LR: 0.000491135 | Time: 28.17s
# Epoch 3 - Train Loss: 0.149632 | Val MSE: 0.000894 | Val MAE: 0.023496 | Val R²: 0.1560 | [Boundary loss] 0.002602 | [Heaters loss] 0.000934 | [Physics loss] 1.910697 | Val Accuracy: 23.48% | LR: 0.000491135 | Time: 28.10s
# Epoch 4 - Train Loss: 0.115287 | Val MSE: 0.000577 | Val MAE: 0.019185 | Val R²: 0.4514 | [Boundary loss] 0.001019 | [Heaters loss] 0.000587 | [Physics loss] 1.818027 | Val Accuracy: 26.80% | LR: 0.000491135 | Time: 28.27s
# Epoch 5 - Train Loss: 0.096307 | Val MSE: 0.000645 | Val MAE: 0.019575 | Val R²: 0.3865 | [Boundary loss] 0.006548 | [Heaters loss] 0.000784 | [Physics loss] 1.737865 | Val Accuracy: 27.62% | LR: 0.000491135 | Time: 28.97s
# Epoch 6 - Train Loss: 0.079779 | Val MSE: 0.000965 | Val MAE: 0.024514 | Val R²: 0.0872 | [Boundary loss] 0.002244 | [Heaters loss] 0.000995 | [Physics loss] 1.906137 | Val Accuracy: 21.62% | LR: 0.000491135 | Time: 28.44s
# Epoch 7 - Train Loss: 0.069115 | Val MSE: 0.002288 | Val MAE: 0.043409 | Val R²: -1.1772 | [Boundary loss] 0.010188 | [Heaters loss] 0.002475 | [Physics loss] 1.725674 | Val Accuracy: 2.37% | LR: 0.000491135 | Time: 28.72s
# Epoch 8 - Train Loss: 0.054577 | Val MSE: 0.005031 | Val MAE: 0.065982 | Val R²: -3.7918 | [Boundary loss] 0.034429 | [Heaters loss] 0.005727 | [Physics loss] 1.893226 | Val Accuracy: 0.53% | LR: 0.000491135 | Time: 28.76s
# Epoch 9 - Train Loss: 0.051453 | Val MSE: 0.000241 | Val MAE: 0.012401 | Val R²: 0.7697 | [Boundary loss] 0.000827 | [Heaters loss] 0.000255 | [Physics loss] 1.738767 | Val Accuracy: 40.28% | LR: 0.000491135 | Time: 30.26s
# Epoch 10 - Train Loss: 0.040963 | Val MSE: 0.000444 | Val MAE: 0.016855 | Val R²: 0.5812 | [Boundary loss] 0.001913 | [Heaters loss] 0.000478 | [Physics loss] 1.830486 | Val Accuracy: 30.37% | LR: 0.000491135 | Time: 30.14s
# Epoch 11 - Train Loss: 0.040635 | Val MSE: 0.000446 | Val MAE: 0.016590 | Val R²: 0.5735 | [Boundary loss] 0.006923 | [Heaters loss] 0.000599 | [Physics loss] 1.829846 | Val Accuracy: 31.45% | LR: 0.000491135 | Time: 29.25s
# Epoch 12 - Train Loss: 0.028969 | Val MSE: 0.000393 | Val MAE: 0.015472 | Val R²: 0.6291 | [Boundary loss] 0.000069 | [Heaters loss] 0.000385 | [Physics loss] 1.612004 | Val Accuracy: 33.74% | LR: 0.000491135 | Time: 29.34s
# Epoch 13 - Train Loss: 0.026897 | Val MSE: 0.002442 | Val MAE: 0.045367 | Val R²: -1.3317 | [Boundary loss] 0.012988 | [Heaters loss] 0.002692 | [Physics loss] 1.855502 | Val Accuracy: 1.41% | LR: 0.000491135 | Time: 29.29s
# Epoch 14 - Train Loss: 0.024612 | Val MSE: 0.000233 | Val MAE: 0.011944 | Val R²: 0.7794 | [Boundary loss] 0.000359 | [Heaters loss] 0.000236 | [Physics loss] 1.702776 | Val Accuracy: 42.36% | LR: 0.000491135 | Time: 29.21s
# Epoch 15 - Train Loss: 0.021577 | Val MSE: 0.000943 | Val MAE: 0.026851 | Val R²: 0.1033 | [Boundary loss] 0.003391 | [Heaters loss] 0.001001 | [Physics loss] 1.638861 | Val Accuracy: 10.34% | LR: 0.000491135 | Time: 29.98s
# Epoch 16 - Train Loss: 0.018934 | Val MSE: 0.000733 | Val MAE: 0.022535 | Val R²: 0.3014 | [Boundary loss] 0.008156 | [Heaters loss] 0.000908 | [Physics loss] 1.630114 | Val Accuracy: 17.79% | LR: 0.000491135 | Time: 29.53s
# Epoch 17 - Train Loss: 0.016231 | Val MSE: 0.000837 | Val MAE: 0.022976 | Val R²: 0.2001 | [Boundary loss] 0.006225 | [Heaters loss] 0.000965 | [Physics loss] 1.605192 | Val Accuracy: 23.81% | LR: 0.000491135 | Time: 29.25s
# Epoch 18 - Train Loss: 0.016834 | Val MSE: 0.000307 | Val MAE: 0.014476 | Val R²: 0.7080 | [Boundary loss] 0.000414 | [Heaters loss] 0.000309 | [Physics loss] 1.557306 | Val Accuracy: 31.41% | LR: 0.000491135 | Time: 29.51s
# Epoch 19 - Train Loss: 0.013068 | Val MSE: 0.000502 | Val MAE: 0.017513 | Val R²: 0.5217 | [Boundary loss] 0.006212 | [Heaters loss] 0.000637 | [Physics loss] 1.649986 | Val Accuracy: 33.01% | LR: 0.000491135 | Time: 29.34s
# Epoch 20 - Train Loss: 0.013934 | Val MSE: 0.000215 | Val MAE: 0.011537 | Val R²: 0.7965 | [Boundary loss] 0.000052 | [Heaters loss] 0.000211 | [Physics loss] 1.561004 | Val Accuracy: 43.85% | LR: 0.000491135 | Time: 31.03s
# Epoch 21 - Train Loss: 0.010688 | Val MSE: 0.000294 | Val MAE: 0.013142 | Val R²: 0.7200 | [Boundary loss] 0.000078 | [Heaters loss] 0.000289 | [Physics loss] 1.692670 | Val Accuracy: 40.73% | LR: 0.000491135 | Time: 32.31s
# Epoch 22 - Train Loss: 0.010492 | Val MSE: 0.000165 | Val MAE: 0.010032 | Val R²: 0.8427 | [Boundary loss] 0.000018 | [Heaters loss] 0.000162 | [Physics loss] 1.595593 | Val Accuracy: 50.41% | LR: 0.000491135 | Time: 29.49s
# Epoch 23 - Train Loss: 0.008854 | Val MSE: 0.000209 | Val MAE: 0.011030 | Val R²: 0.8017 | [Boundary loss] 0.000841 | [Heaters loss] 0.000224 | [Physics loss] 1.563563 | Val Accuracy: 46.48% | LR: 0.000491135 | Time: 29.65s
# Epoch 24 - Train Loss: 0.009319 | Val MSE: 0.000267 | Val MAE: 0.013159 | Val R²: 0.7478 | [Boundary loss] 0.001160 | [Heaters loss] 0.000288 | [Physics loss] 1.565768 | Val Accuracy: 37.39% | LR: 0.000491135 | Time: 29.36s
# Epoch 25 - Train Loss: 0.007364 | Val MSE: 0.000120 | Val MAE: 0.008670 | Val R²: 0.8851 | [Boundary loss] 0.000014 | [Heaters loss] 0.000118 | [Physics loss] 1.533154 | Val Accuracy: 55.62% | LR: 0.000491135 | Time: 29.09s
# Epoch 26 - Train Loss: 0.006783 | Val MSE: 0.000138 | Val MAE: 0.009209 | Val R²: 0.8692 | [Boundary loss] 0.000595 | [Heaters loss] 0.000149 | [Physics loss] 1.521782 | Val Accuracy: 53.06% | LR: 0.000491135 | Time: 29.37s
# Epoch 27 - Train Loss: 0.006948 | Val MSE: 0.000119 | Val MAE: 0.008802 | Val R²: 0.8865 | [Boundary loss] 0.000107 | [Heaters loss] 0.000119 | [Physics loss] 1.559265 | Val Accuracy: 53.57% | LR: 0.000491135 | Time: 29.49s
# Epoch 28 - Train Loss: 0.005804 | Val MSE: 0.000178 | Val MAE: 0.010460 | Val R²: 0.8304 | [Boundary loss] 0.000777 | [Heaters loss] 0.000192 | [Physics loss] 1.564028 | Val Accuracy: 48.30% | LR: 0.000491135 | Time: 29.56s
# Epoch 29 - Train Loss: 0.005756 | Val MSE: 0.000271 | Val MAE: 0.013676 | Val R²: 0.7431 | [Boundary loss] 0.000320 | [Heaters loss] 0.000272 | [Physics loss] 1.514045 | Val Accuracy: 32.39% | LR: 0.000491135 | Time: 30.20s
# Epoch 30 - Train Loss: 0.005042 | Val MSE: 0.000188 | Val MAE: 0.010710 | Val R²: 0.8195 | [Boundary loss] 0.000260 | [Heaters loss] 0.000190 | [Physics loss] 1.509133 | Val Accuracy: 46.50% | LR: 0.000491135 | Time: 29.70s
# Epoch 31 - Train Loss: 0.004742 | Val MSE: 0.000181 | Val MAE: 0.010560 | Val R²: 0.8283 | [Boundary loss] 0.000118 | [Heaters loss] 0.000179 | [Physics loss] 1.547748 | Val Accuracy: 47.62% | LR: 0.000491135 | Time: 29.87s
# Epoch 32 - Train Loss: 0.004152 | Val MSE: 0.000156 | Val MAE: 0.009574 | Val R²: 0.8517 | [Boundary loss] 0.000013 | [Heaters loss] 0.000152 | [Physics loss] 1.587411 | Val Accuracy: 53.44% | LR: 0.000491135 | Time: 29.12s
# Epoch 33 - Train Loss: 0.004733 | Val MSE: 0.000155 | Val MAE: 0.010027 | Val R²: 0.8522 | [Boundary loss] 0.000150 | [Heaters loss] 0.000155 | [Physics loss] 1.530315 | Val Accuracy: 47.92% | LR: 0.000491135 | Time: 29.31s
# Epoch 34 - Train Loss: 0.004024 | Val MSE: 0.000181 | Val MAE: 0.010376 | Val R²: 0.8286 | [Boundary loss] 0.000156 | [Heaters loss] 0.000181 | [Physics loss] 1.638435 | Val Accuracy: 49.06% | LR: 0.000491135 | Time: 29.12s
# Epoch 35 - Train Loss: 0.003689 | Val MSE: 0.000202 | Val MAE: 0.011839 | Val R²: 0.8080 | [Boundary loss] 0.000103 | [Heaters loss] 0.000199 | [Physics loss] 1.596244 | Val Accuracy: 37.75% | LR: 0.000491135 | Time: 29.01s
# Epoch 36 - Train Loss: 0.003715 | Val MSE: 0.000120 | Val MAE: 0.008426 | Val R²: 0.8859 | [Boundary loss] 0.000160 | [Heaters loss] 0.000121 | [Physics loss] 1.508127 | Val Accuracy: 57.74% | LR: 0.000491135 | Time: 28.89s
# Epoch 37 - Train Loss: 0.004074 | Val MSE: 0.000101 | Val MAE: 0.007984 | Val R²: 0.9042 | [Boundary loss] 0.000178 | [Heaters loss] 0.000103 | [Physics loss] 1.549024 | Val Accuracy: 59.17% | LR: 0.000491135 | Time: 29.29s
# Epoch 38 - Train Loss: 0.003093 | Val MSE: 0.000339 | Val MAE: 0.014680 | Val R²: 0.6805 | [Boundary loss] 0.000161 | [Heaters loss] 0.000335 | [Physics loss] 1.510777 | Val Accuracy: 33.14% | LR: 0.000491135 | Time: 29.02s
# Epoch 39 - Train Loss: 0.002951 | Val MSE: 0.000189 | Val MAE: 0.010931 | Val R²: 0.8199 | [Boundary loss] 0.000008 | [Heaters loss] 0.000185 | [Physics loss] 1.607086 | Val Accuracy: 45.07% | LR: 0.000491135 | Time: 29.06s
# Epoch 40 - Train Loss: 0.002973 | Val MSE: 0.000144 | Val MAE: 0.009643 | Val R²: 0.8630 | [Boundary loss] 0.000505 | [Heaters loss] 0.000152 | [Physics loss] 1.584615 | Val Accuracy: 49.48% | LR: 0.000491135 | Time: 37.30s
# Epoch 41 - Train Loss: 0.003007 | Val MSE: 0.000085 | Val MAE: 0.007333 | Val R²: 0.9198 | [Boundary loss] 0.000119 | [Heaters loss] 0.000086 | [Physics loss] 1.522942 | Val Accuracy: 63.10% | LR: 0.000491135 | Time: 37.98s
# Epoch 42 - Train Loss: 0.002781 | Val MSE: 0.000117 | Val MAE: 0.008648 | Val R²: 0.8888 | [Boundary loss] 0.000138 | [Heaters loss] 0.000117 | [Physics loss] 1.555378 | Val Accuracy: 54.85% | LR: 0.000491135 | Time: 36.56s
# Epoch 43 - Train Loss: 0.002685 | Val MSE: 0.000102 | Val MAE: 0.008085 | Val R²: 0.9032 | [Boundary loss] 0.000025 | [Heaters loss] 0.000100 | [Physics loss] 1.556624 | Val Accuracy: 58.06% | LR: 0.000491135 | Time: 33.58s
# Epoch 44 - Train Loss: 0.002510 | Val MSE: 0.000234 | Val MAE: 0.012270 | Val R²: 0.7786 | [Boundary loss] 0.000399 | [Heaters loss] 0.000238 | [Physics loss] 1.518039 | Val Accuracy: 38.96% | LR: 0.000491135 | Time: 31.06s
# Epoch 45 - Train Loss: 0.002721 | Val MSE: 0.000202 | Val MAE: 0.011865 | Val R²: 0.8073 | [Boundary loss] 0.000042 | [Heaters loss] 0.000198 | [Physics loss] 1.542081 | Val Accuracy: 37.82% | LR: 0.000491135 | Time: 32.58s
# Epoch 46 - Train Loss: 0.002662 | Val MSE: 0.000329 | Val MAE: 0.015802 | Val R²: 0.6869 | [Boundary loss] 0.000744 | [Heaters loss] 0.000339 | [Physics loss] 1.535513 | Val Accuracy: 22.62% | LR: 0.000491135 | Time: 31.87s
# Epoch 47 - Train Loss: 0.002275 | Val MSE: 0.000099 | Val MAE: 0.007929 | Val R²: 0.9067 | [Boundary loss] 0.000672 | [Heaters loss] 0.000112 | [Physics loss] 1.543293 | Val Accuracy: 59.04% | LR: 0.000491135 | Time: 31.49s
# Epoch 48 - Train Loss: 0.002352 | Val MSE: 0.000094 | Val MAE: 0.007567 | Val R²: 0.9105 | [Boundary loss] 0.000070 | [Heaters loss] 0.000094 | [Physics loss] 1.539441 | Val Accuracy: 62.65% | LR: 0.000491135 | Time: 31.25s
# Epoch 49 - Train Loss: 0.002181 | Val MSE: 0.000096 | Val MAE: 0.007786 | Val R²: 0.9086 | [Boundary loss] 0.000007 | [Heaters loss] 0.000094 | [Physics loss] 1.530708 | Val Accuracy: 60.36% | LR: 0.000491135 | Time: 32.28s
# Epoch 50 - Train Loss: 0.002224 | Val MSE: 0.000128 | Val MAE: 0.008925 | Val R²: 0.8783 | [Boundary loss] 0.001147 | [Heaters loss] 0.000152 | [Physics loss] 1.558504 | Val Accuracy: 54.82% | LR: 0.000491135 | Time: 33.33s
# Epoch 51 - Train Loss: 0.002183 | Val MSE: 0.000163 | Val MAE: 0.010205 | Val R²: 0.8447 | [Boundary loss] 0.000764 | [Heaters loss] 0.000177 | [Physics loss] 1.524089 | Val Accuracy: 47.72% | LR: 0.000491135 | Time: 31.01s
# Epoch 52 - Train Loss: 0.002263 | Val MSE: 0.000271 | Val MAE: 0.013088 | Val R²: 0.7439 | [Boundary loss] 0.000529 | [Heaters loss] 0.000277 | [Physics loss] 1.626498 | Val Accuracy: 38.17% | LR: 0.000245567 | Time: 31.03s
# Epoch 53 - Train Loss: 0.001678 | Val MSE: 0.000089 | Val MAE: 0.007537 | Val R²: 0.9159 | [Boundary loss] 0.000484 | [Heaters loss] 0.000098 | [Physics loss] 1.530888 | Val Accuracy: 61.33% | LR: 0.000245567 | Time: 31.09s
# Epoch 54 - Train Loss: 0.001678 | Val MSE: 0.000103 | Val MAE: 0.008113 | Val R²: 0.9028 | [Boundary loss] 0.000536 | [Heaters loss] 0.000113 | [Physics loss] 1.551665 | Val Accuracy: 57.84% | LR: 0.000245567 | Time: 31.29s
# Epoch 55 - Train Loss: 0.001619 | Val MSE: 0.000131 | Val MAE: 0.009284 | Val R²: 0.8756 | [Boundary loss] 0.000129 | [Heaters loss] 0.000131 | [Physics loss] 1.521979 | Val Accuracy: 50.86% | LR: 0.000245567 | Time: 31.27s
# Epoch 56 - Train Loss: 0.001566 | Val MSE: 0.000111 | Val MAE: 0.008495 | Val R²: 0.8952 | [Boundary loss] 0.000180 | [Heaters loss] 0.000112 | [Physics loss] 1.523148 | Val Accuracy: 55.07% | LR: 0.000245567 | Time: 31.45s
# Epoch 57 - Train Loss: 0.001611 | Val MSE: 0.000094 | Val MAE: 0.007661 | Val R²: 0.9107 | [Boundary loss] 0.000110 | [Heaters loss] 0.000094 | [Physics loss] 1.510613 | Val Accuracy: 61.33% | LR: 0.000245567 | Time: 30.96s
# Epoch 58 - Train Loss: 0.001660 | Val MSE: 0.000086 | Val MAE: 0.007395 | Val R²: 0.9179 | [Boundary loss] 0.000119 | [Heaters loss] 0.000087 | [Physics loss] 1.560494 | Val Accuracy: 62.83% | LR: 0.000245567 | Time: 30.84s
# Epoch 59 - Train Loss: 0.001609 | Val MSE: 0.000091 | Val MAE: 0.007492 | Val R²: 0.9143 | [Boundary loss] 0.000086 | [Heaters loss] 0.000090 | [Physics loss] 1.523593 | Val Accuracy: 62.61% | LR: 0.000245567 | Time: 31.50s
# Epoch 60 - Train Loss: 0.001548 | Val MSE: 0.000112 | Val MAE: 0.008433 | Val R²: 0.8936 | [Boundary loss] 0.000090 | [Heaters loss] 0.000112 | [Physics loss] 1.510806 | Val Accuracy: 56.48% | LR: 0.000245567 | Time: 30.58s
# Epoch 61 - Train Loss: 0.001617 | Val MSE: 0.000088 | Val MAE: 0.007510 | Val R²: 0.9169 | [Boundary loss] 0.000339 | [Heaters loss] 0.000094 | [Physics loss] 1.530157 | Val Accuracy: 61.34% | LR: 0.000245567 | Time: 29.41s
# Epoch 62 - Train Loss: 0.001599 | Val MSE: 0.000494 | Val MAE: 0.018220 | Val R²: 0.5314 | [Boundary loss] 0.000387 | [Heaters loss] 0.000492 | [Physics loss] 1.708852 | Val Accuracy: 26.64% | LR: 0.000245567 | Time: 29.25s
# Epoch 63 - Train Loss: 0.001660 | Val MSE: 0.000085 | Val MAE: 0.007256 | Val R²: 0.9193 | [Boundary loss] 0.000016 | [Heaters loss] 0.000084 | [Physics loss] 1.530921 | Val Accuracy: 64.20% | LR: 0.000122784 | Time: 29.45s
# Epoch 64 - Train Loss: 0.001353 | Val MSE: 0.000131 | Val MAE: 0.009336 | Val R²: 0.8756 | [Boundary loss] 0.000585 | [Heaters loss] 0.000142 | [Physics loss] 1.520552 | Val Accuracy: 49.90% | LR: 0.000122784 | Time: 29.45s
# Epoch 65 - Train Loss: 0.001336 | Val MSE: 0.000089 | Val MAE: 0.007464 | Val R²: 0.9159 | [Boundary loss] 0.000272 | [Heaters loss] 0.000093 | [Physics loss] 1.517267 | Val Accuracy: 62.26% | LR: 0.000122784 | Time: 29.69s
# Epoch 66 - Train Loss: 0.001409 | Val MSE: 0.000127 | Val MAE: 0.009155 | Val R²: 0.8797 | [Boundary loss] 0.000536 | [Heaters loss] 0.000137 | [Physics loss] 1.514071 | Val Accuracy: 51.06% | LR: 0.000122784 | Time: 29.53s
# Epoch 67 - Train Loss: 0.001397 | Val MSE: 0.000085 | Val MAE: 0.007343 | Val R²: 0.9198 | [Boundary loss] 0.000277 | [Heaters loss] 0.000089 | [Physics loss] 1.524078 | Val Accuracy: 62.77% | LR: 0.000122784 | Time: 29.59s
# Epoch 68 - Train Loss: 0.001378 | Val MSE: 0.000091 | Val MAE: 0.007587 | Val R²: 0.9135 | [Boundary loss] 0.000098 | [Heaters loss] 0.000091 | [Physics loss] 1.530160 | Val Accuracy: 61.54% | LR: 0.000122784 | Time: 29.62s
# Epoch 69 - Train Loss: 0.001386 | Val MSE: 0.000091 | Val MAE: 0.007613 | Val R²: 0.9140 | [Boundary loss] 0.000289 | [Heaters loss] 0.000095 | [Physics loss] 1.519968 | Val Accuracy: 60.92% | LR: 0.000122784 | Time: 29.45s
# Epoch 70 - Train Loss: 0.001353 | Val MSE: 0.000107 | Val MAE: 0.008228 | Val R²: 0.8983 | [Boundary loss] 0.000380 | [Heaters loss] 0.000114 | [Physics loss] 1.510455 | Val Accuracy: 57.45% | LR: 0.000122784 | Time: 29.51s
# Epoch 71 - Train Loss: 0.001362 | Val MSE: 0.000137 | Val MAE: 0.009130 | Val R²: 0.8702 | [Boundary loss] 0.000005 | [Heaters loss] 0.000133 | [Physics loss] 1.555915 | Val Accuracy: 54.32% | LR: 0.000122784 | Time: 29.51s
# Epoch 72 - Train Loss: 0.001343 | Val MSE: 0.000102 | Val MAE: 0.008105 | Val R²: 0.9030 | [Boundary loss] 0.000187 | [Heaters loss] 0.000104 | [Physics loss] 1.516481 | Val Accuracy: 57.85% | LR: 0.000122784 | Time: 29.54s
# Epoch 73 - Train Loss: 0.001367 | Val MSE: 0.000076 | Val MAE: 0.006939 | Val R²: 0.9276 | [Boundary loss] 0.000094 | [Heaters loss] 0.000077 | [Physics loss] 1.525527 | Val Accuracy: 65.84% | LR: 0.000122784 | Time: 29.74s
# Epoch 74 - Train Loss: 0.001357 | Val MSE: 0.000102 | Val MAE: 0.008102 | Val R²: 0.9029 | [Boundary loss] 0.000485 | [Heaters loss] 0.000111 | [Physics loss] 1.532345 | Val Accuracy: 57.71% | LR: 0.000122784 | Time: 29.44s
# Epoch 75 - Train Loss: 0.001333 | Val MSE: 0.000074 | Val MAE: 0.006732 | Val R²: 0.9303 | [Boundary loss] 0.000009 | [Heaters loss] 0.000072 | [Physics loss] 1.514127 | Val Accuracy: 67.68% | LR: 0.000122784 | Time: 29.56s
# Epoch 76 - Train Loss: 0.001388 | Val MSE: 0.000080 | Val MAE: 0.007038 | Val R²: 0.9239 | [Boundary loss] 0.000056 | [Heaters loss] 0.000080 | [Physics loss] 1.531879 | Val Accuracy: 65.53% | LR: 0.000122784 | Time: 29.67s
# Epoch 77 - Train Loss: 0.001339 | Val MSE: 0.000097 | Val MAE: 0.007953 | Val R²: 0.9078 | [Boundary loss] 0.000270 | [Heaters loss] 0.000101 | [Physics loss] 1.528459 | Val Accuracy: 58.28% | LR: 0.000122784 | Time: 29.64s
# Epoch 78 - Train Loss: 0.001320 | Val MSE: 0.000090 | Val MAE: 0.007575 | Val R²: 0.9144 | [Boundary loss] 0.000204 | [Heaters loss] 0.000093 | [Physics loss] 1.517271 | Val Accuracy: 61.37% | LR: 0.000122784 | Time: 29.51s
# Epoch 79 - Train Loss: 0.001380 | Val MSE: 0.000082 | Val MAE: 0.007160 | Val R²: 0.9223 | [Boundary loss] 0.000006 | [Heaters loss] 0.000080 | [Physics loss] 1.532026 | Val Accuracy: 64.45% | LR: 0.000122784 | Time: 29.85s
# Epoch 80 - Train Loss: 0.001338 | Val MSE: 0.000117 | Val MAE: 0.008657 | Val R²: 0.8894 | [Boundary loss] 0.000211 | [Heaters loss] 0.000119 | [Physics loss] 1.509199 | Val Accuracy: 54.52% | LR: 0.000122784 | Time: 29.72s
# Epoch 81 - Train Loss: 0.001289 | Val MSE: 0.000088 | Val MAE: 0.007458 | Val R²: 0.9173 | [Boundary loss] 0.000170 | [Heaters loss] 0.000090 | [Physics loss] 1.552197 | Val Accuracy: 62.11% | LR: 0.000122784 | Time: 29.51s
# Epoch 82 - Train Loss: 0.001304 | Val MSE: 0.000094 | Val MAE: 0.007780 | Val R²: 0.9107 | [Boundary loss] 0.000255 | [Heaters loss] 0.000098 | [Physics loss] 1.520684 | Val Accuracy: 59.80% | LR: 0.000122784 | Time: 29.57s
# Epoch 83 - Train Loss: 0.001330 | Val MSE: 0.000077 | Val MAE: 0.006917 | Val R²: 0.9268 | [Boundary loss] 0.000044 | [Heaters loss] 0.000076 | [Physics loss] 1.529274 | Val Accuracy: 66.24% | LR: 0.000122784 | Time: 29.58s
# Epoch 84 - Train Loss: 0.001320 | Val MSE: 0.000080 | Val MAE: 0.007135 | Val R²: 0.9241 | [Boundary loss] 0.000219 | [Heaters loss] 0.000083 | [Physics loss] 1.520174 | Val Accuracy: 64.25% | LR: 0.000122784 | Time: 29.59s
# Epoch 85 - Train Loss: 0.001341 | Val MSE: 0.000106 | Val MAE: 0.008340 | Val R²: 0.8994 | [Boundary loss] 0.000432 | [Heaters loss] 0.000114 | [Physics loss] 1.522928 | Val Accuracy: 55.62% | LR: 0.000122784 | Time: 29.60s
# Epoch 86 - Train Loss: 0.001292 | Val MSE: 0.000081 | Val MAE: 0.007167 | Val R²: 0.9237 | [Boundary loss] 0.000261 | [Heaters loss] 0.000085 | [Physics loss] 1.531084 | Val Accuracy: 63.97% | LR: 0.000061392 | Time: 29.51s
# Epoch 87 - Train Loss: 0.001216 | Val MSE: 0.000114 | Val MAE: 0.008677 | Val R²: 0.8918 | [Boundary loss] 0.000480 | [Heaters loss] 0.000123 | [Physics loss] 1.519041 | Val Accuracy: 53.53% | LR: 0.000061392 | Time: 29.54s
# Epoch 88 - Train Loss: 0.001195 | Val MSE: 0.000083 | Val MAE: 0.007260 | Val R²: 0.9217 | [Boundary loss] 0.000169 | [Heaters loss] 0.000085 | [Physics loss] 1.532837 | Val Accuracy: 63.40% | LR: 0.000061392 | Time: 29.59s
# Epoch 89 - Train Loss: 0.001213 | Val MSE: 0.000078 | Val MAE: 0.006975 | Val R²: 0.9258 | [Boundary loss] 0.000055 | [Heaters loss] 0.000078 | [Physics loss] 1.527905 | Val Accuracy: 65.86% | LR: 0.000061392 | Time: 29.71s
# Epoch 90 - Train Loss: 0.001227 | Val MSE: 0.000079 | Val MAE: 0.007032 | Val R²: 0.9252 | [Boundary loss] 0.000098 | [Heaters loss] 0.000079 | [Physics loss] 1.521460 | Val Accuracy: 65.27% | LR: 0.000061392 | Time: 29.95s
# Epoch 91 - Train Loss: 0.001205 | Val MSE: 0.000112 | Val MAE: 0.008568 | Val R²: 0.8942 | [Boundary loss] 0.000365 | [Heaters loss] 0.000118 | [Physics loss] 1.520938 | Val Accuracy: 54.25% | LR: 0.000061392 | Time: 30.19s
# Epoch 92 - Train Loss: 0.001200 | Val MSE: 0.000073 | Val MAE: 0.006721 | Val R²: 0.9307 | [Boundary loss] 0.000026 | [Heaters loss] 0.000072 | [Physics loss] 1.515843 | Val Accuracy: 67.59% | LR: 0.000061392 | Time: 30.34s
# Epoch 93 - Train Loss: 0.001213 | Val MSE: 0.000092 | Val MAE: 0.007664 | Val R²: 0.9125 | [Boundary loss] 0.000197 | [Heaters loss] 0.000095 | [Physics loss] 1.511620 | Val Accuracy: 60.89% | LR: 0.000061392 | Time: 31.41s
# Epoch 94 - Train Loss: 0.001198 | Val MSE: 0.000080 | Val MAE: 0.007028 | Val R²: 0.9246 | [Boundary loss] 0.000055 | [Heaters loss] 0.000079 | [Physics loss] 1.533722 | Val Accuracy: 65.49% | LR: 0.000061392 | Time: 30.68s
# Epoch 95 - Train Loss: 0.001191 | Val MSE: 0.000088 | Val MAE: 0.007500 | Val R²: 0.9162 | [Boundary loss] 0.000173 | [Heaters loss] 0.000090 | [Physics loss] 1.517867 | Val Accuracy: 61.93% | LR: 0.000061392 | Time: 30.51s
# Epoch 96 - Train Loss: 0.001200 | Val MSE: 0.000103 | Val MAE: 0.008243 | Val R²: 0.9021 | [Boundary loss] 0.000289 | [Heaters loss] 0.000108 | [Physics loss] 1.519474 | Val Accuracy: 56.22% | LR: 0.000061392 | Time: 29.47s
# Epoch 97 - Train Loss: 0.001191 | Val MSE: 0.000095 | Val MAE: 0.007803 | Val R²: 0.9097 | [Boundary loss] 0.000282 | [Heaters loss] 0.000100 | [Physics loss] 1.520915 | Val Accuracy: 59.79% | LR: 0.000061392 | Time: 29.60s
# Epoch 98 - Train Loss: 0.001199 | Val MSE: 0.000087 | Val MAE: 0.007451 | Val R²: 0.9175 | [Boundary loss] 0.000175 | [Heaters loss] 0.000089 | [Physics loss] 1.531926 | Val Accuracy: 62.07% | LR: 0.000061392 | Time: 29.48s
# Epoch 99 - Train Loss: 0.001182 | Val MSE: 0.000087 | Val MAE: 0.007307 | Val R²: 0.9170 | [Boundary loss] 0.000001 | [Heaters loss] 0.000085 | [Physics loss] 1.540963 | Val Accuracy: 64.19% | LR: 0.000061392 | Time: 30.30s
# Epoch 100 - Train Loss: 0.001198 | Val MSE: 0.000078 | Val MAE: 0.007013 | Val R²: 0.9260 | [Boundary loss] 0.000123 | [Heaters loss] 0.000079 | [Physics loss] 1.528509 | Val Accuracy: 65.33% | LR: 0.000061392 | Time: 31.80s
# Epoch 101 - Train Loss: 0.001186 | Val MSE: 0.000102 | Val MAE: 0.008129 | Val R²: 0.9030 | [Boundary loss] 0.000328 | [Heaters loss] 0.000108 | [Physics loss] 1.516467 | Val Accuracy: 57.32% | LR: 0.000061392 | Time: 30.02s
# Epoch 102 - Train Loss: 0.001190 | Val MSE: 0.000111 | Val MAE: 0.008564 | Val R²: 0.8942 | [Boundary loss] 0.000419 | [Heaters loss] 0.000119 | [Physics loss] 1.519631 | Val Accuracy: 54.19% | LR: 0.000061392 | Time: 29.58s
# Epoch 103 - Train Loss: 0.001188 | Val MSE: 0.000075 | Val MAE: 0.006810 | Val R²: 0.9290 | [Boundary loss] 0.000047 | [Heaters loss] 0.000074 | [Physics loss] 1.518075 | Val Accuracy: 66.88% | LR: 0.000030696 | Time: 29.72s
# Epoch 104 - Train Loss: 0.001146 | Val MSE: 0.000082 | Val MAE: 0.007126 | Val R²: 0.9219 | [Boundary loss] 0.000032 | [Heaters loss] 0.000081 | [Physics loss] 1.534793 | Val Accuracy: 64.91% | LR: 0.000030696 | Time: 29.65s
# Epoch 105 - Train Loss: 0.001143 | Val MSE: 0.000077 | Val MAE: 0.006926 | Val R²: 0.9269 | [Boundary loss] 0.000067 | [Heaters loss] 0.000077 | [Physics loss] 1.529542 | Val Accuracy: 66.16% | LR: 0.000030696 | Time: 29.96s
# Epoch 106 - Train Loss: 0.001150 | Val MSE: 0.000076 | Val MAE: 0.006866 | Val R²: 0.9282 | [Boundary loss] 0.000066 | [Heaters loss] 0.000075 | [Physics loss] 1.523198 | Val Accuracy: 66.51% | LR: 0.000030696 | Time: 29.06s
# Epoch 107 - Train Loss: 0.001146 | Val MSE: 0.000081 | Val MAE: 0.007155 | Val R²: 0.9234 | [Boundary loss] 0.000151 | [Heaters loss] 0.000082 | [Physics loss] 1.525779 | Val Accuracy: 64.21% | LR: 0.000030696 | Time: 28.91s
# Epoch 108 - Train Loss: 0.001135 | Val MSE: 0.000079 | Val MAE: 0.007063 | Val R²: 0.9253 | [Boundary loss] 0.000143 | [Heaters loss] 0.000080 | [Physics loss] 1.523905 | Val Accuracy: 64.97% | LR: 0.000030696 | Time: 29.10s
# Epoch 109 - Train Loss: 0.001138 | Val MSE: 0.000076 | Val MAE: 0.006923 | Val R²: 0.9275 | [Boundary loss] 0.000110 | [Heaters loss] 0.000077 | [Physics loss] 1.527993 | Val Accuracy: 66.05% | LR: 0.000030696 | Time: 30.22s
# Epoch 110 - Train Loss: 0.001145 | Val MSE: 0.000087 | Val MAE: 0.007454 | Val R²: 0.9178 | [Boundary loss] 0.000230 | [Heaters loss] 0.000090 | [Physics loss] 1.522700 | Val Accuracy: 61.91% | LR: 0.000030696 | Time: 38.60s
# Epoch 111 - Train Loss: 0.001134 | Val MSE: 0.000081 | Val MAE: 0.007190 | Val R²: 0.9228 | [Boundary loss] 0.000209 | [Heaters loss] 0.000084 | [Physics loss] 1.519625 | Val Accuracy: 63.92% | LR: 0.000030696 | Time: 39.39s
# Epoch 112 - Train Loss: 0.001134 | Val MSE: 0.000086 | Val MAE: 0.007405 | Val R²: 0.9183 | [Boundary loss] 0.000259 | [Heaters loss] 0.000090 | [Physics loss] 1.519648 | Val Accuracy: 62.41% | LR: 0.000030696 | Time: 39.93s
# Epoch 113 - Train Loss: 0.001142 | Val MSE: 0.000073 | Val MAE: 0.006717 | Val R²: 0.9308 | [Boundary loss] 0.000023 | [Heaters loss] 0.000072 | [Physics loss] 1.521823 | Val Accuracy: 67.62% | LR: 0.000030696 | Time: 41.11s
# Epoch 114 - Train Loss: 0.001143 | Val MSE: 0.000075 | Val MAE: 0.006860 | Val R²: 0.9285 | [Boundary loss] 0.000075 | [Heaters loss] 0.000075 | [Physics loss] 1.525124 | Val Accuracy: 66.52% | LR: 0.000030696 | Time: 39.86s
# Epoch 115 - Train Loss: 0.001132 | Val MSE: 0.000091 | Val MAE: 0.007618 | Val R²: 0.9144 | [Boundary loss] 0.000215 | [Heaters loss] 0.000093 | [Physics loss] 1.516345 | Val Accuracy: 60.86% | LR: 0.000030696 | Time: 40.72s
# Epoch 116 - Train Loss: 0.001128 | Val MSE: 0.000075 | Val MAE: 0.006869 | Val R²: 0.9286 | [Boundary loss] 0.000093 | [Heaters loss] 0.000076 | [Physics loss] 1.526692 | Val Accuracy: 66.46% | LR: 0.000030696 | Time: 39.82s
# Epoch 117 - Train Loss: 0.001140 | Val MSE: 0.000077 | Val MAE: 0.006974 | Val R²: 0.9269 | [Boundary loss] 0.000129 | [Heaters loss] 0.000078 | [Physics loss] 1.530462 | Val Accuracy: 65.62% | LR: 0.000030696 | Time: 40.00s
# Epoch 118 - Train Loss: 0.001143 | Val MSE: 0.000075 | Val MAE: 0.006805 | Val R²: 0.9293 | [Boundary loss] 0.000046 | [Heaters loss] 0.000074 | [Physics loss] 1.524577 | Val Accuracy: 67.03% | LR: 0.000030696 | Time: 39.78s
# Epoch 119 - Train Loss: 0.001127 | Val MSE: 0.000080 | Val MAE: 0.007110 | Val R²: 0.9240 | [Boundary loss] 0.000102 | [Heaters loss] 0.000081 | [Physics loss] 1.517471 | Val Accuracy: 64.77% | LR: 0.000030696 | Time: 39.46s
# Epoch 120 - Train Loss: 0.001136 | Val MSE: 0.000083 | Val MAE: 0.007264 | Val R²: 0.9217 | [Boundary loss] 0.000230 | [Heaters loss] 0.000086 | [Physics loss] 1.523149 | Val Accuracy: 63.22% | LR: 0.000030696 | Time: 39.75s
# Epoch 121 - Train Loss: 0.001133 | Val MSE: 0.000083 | Val MAE: 0.007278 | Val R²: 0.9214 | [Boundary loss] 0.000177 | [Heaters loss] 0.000085 | [Physics loss] 1.522134 | Val Accuracy: 63.21% | LR: 0.000030696 | Time: 39.18s
# Epoch 122 - Train Loss: 0.001130 | Val MSE: 0.000086 | Val MAE: 0.007364 | Val R²: 0.9186 | [Boundary loss] 0.000124 | [Heaters loss] 0.000087 | [Physics loss] 1.514884 | Val Accuracy: 63.01% | LR: 0.000030696 | Time: 39.08s
# Epoch 123 - Train Loss: 0.001145 | Val MSE: 0.000074 | Val MAE: 0.006755 | Val R²: 0.9299 | [Boundary loss] 0.000025 | [Heaters loss] 0.000073 | [Physics loss] 1.519914 | Val Accuracy: 67.38% | LR: 0.000030696 | Time: 39.40s
# Epoch 124 - Train Loss: 0.001112 | Val MSE: 0.000080 | Val MAE: 0.007089 | Val R²: 0.9245 | [Boundary loss] 0.000127 | [Heaters loss] 0.000081 | [Physics loss] 1.521723 | Val Accuracy: 64.85% | LR: 0.000015348 | Time: 39.78s
# Epoch 125 - Train Loss: 0.001109 | Val MSE: 0.000090 | Val MAE: 0.007627 | Val R²: 0.9145 | [Boundary loss] 0.000244 | [Heaters loss] 0.000094 | [Physics loss] 1.521305 | Val Accuracy: 60.62% | LR: 0.000015348 | Time: 39.43s
# Epoch 126 - Train Loss: 0.001110 | Val MSE: 0.000079 | Val MAE: 0.007039 | Val R²: 0.9254 | [Boundary loss] 0.000134 | [Heaters loss] 0.000080 | [Physics loss] 1.522064 | Val Accuracy: 65.20% | LR: 0.000015348 | Time: 39.70s
# Epoch 127 - Train Loss: 0.001099 | Val MSE: 0.000084 | Val MAE: 0.007283 | Val R²: 0.9208 | [Boundary loss] 0.000169 | [Heaters loss] 0.000086 | [Physics loss] 1.518331 | Val Accuracy: 63.38% | LR: 0.000015348 | Time: 40.52s
# Epoch 128 - Train Loss: 0.001104 | Val MSE: 0.000084 | Val MAE: 0.007318 | Val R²: 0.9206 | [Boundary loss] 0.000227 | [Heaters loss] 0.000087 | [Physics loss] 1.520882 | Val Accuracy: 62.97% | LR: 0.000015348 | Time: 39.94s
# Epoch 129 - Train Loss: 0.001101 | Val MSE: 0.000094 | Val MAE: 0.007801 | Val R²: 0.9103 | [Boundary loss] 0.000251 | [Heaters loss] 0.000098 | [Physics loss] 1.519100 | Val Accuracy: 59.55% | LR: 0.000015348 | Time: 39.31s
# Epoch 130 - Train Loss: 0.001103 | Val MSE: 0.000083 | Val MAE: 0.007295 | Val R²: 0.9211 | [Boundary loss] 0.000185 | [Heaters loss] 0.000086 | [Physics loss] 1.524336 | Val Accuracy: 63.14% | LR: 0.000015348 | Time: 39.51s
# Epoch 131 - Train Loss: 0.001100 | Val MSE: 0.000082 | Val MAE: 0.007226 | Val R²: 0.9221 | [Boundary loss] 0.000155 | [Heaters loss] 0.000084 | [Physics loss] 1.522528 | Val Accuracy: 63.77% | LR: 0.000015348 | Time: 40.46s
# Epoch 132 - Train Loss: 0.001102 | Val MSE: 0.000077 | Val MAE: 0.006949 | Val R²: 0.9272 | [Boundary loss] 0.000109 | [Heaters loss] 0.000078 | [Physics loss] 1.526127 | Val Accuracy: 65.86% | LR: 0.000015348 | Time: 40.13s
# Epoch 133 - Train Loss: 0.001101 | Val MSE: 0.000079 | Val MAE: 0.007060 | Val R²: 0.9252 | [Boundary loss] 0.000140 | [Heaters loss] 0.000080 | [Physics loss] 1.520285 | Val Accuracy: 64.97% | LR: 0.000015348 | Time: 39.82s
# Epoch 134 - Train Loss: 0.001097 | Val MSE: 0.000084 | Val MAE: 0.007311 | Val R²: 0.9207 | [Boundary loss] 0.000197 | [Heaters loss] 0.000086 | [Physics loss] 1.527847 | Val Accuracy: 62.95% | LR: 0.000015348 | Time: 39.68s
# Epoch 135 - Train Loss: 0.001107 | Val MSE: 0.000078 | Val MAE: 0.007002 | Val R²: 0.9263 | [Boundary loss] 0.000102 | [Heaters loss] 0.000078 | [Physics loss] 1.521166 | Val Accuracy: 65.47% | LR: 0.000007674 | Time: 39.96s
# Epoch 136 - Train Loss: 0.001082 | Val MSE: 0.000078 | Val MAE: 0.007004 | Val R²: 0.9263 | [Boundary loss] 0.000140 | [Heaters loss] 0.000079 | [Physics loss] 1.524031 | Val Accuracy: 65.41% | LR: 0.000007674 | Time: 39.62s
# Epoch 137 - Train Loss: 0.001090 | Val MSE: 0.000078 | Val MAE: 0.007039 | Val R²: 0.9257 | [Boundary loss] 0.000140 | [Heaters loss] 0.000080 | [Physics loss] 1.522629 | Val Accuracy: 65.09% | LR: 0.000007674 | Time: 39.55s
# Epoch 138 - Train Loss: 0.001094 | Val MSE: 0.000085 | Val MAE: 0.007373 | Val R²: 0.9192 | [Boundary loss] 0.000219 | [Heaters loss] 0.000088 | [Physics loss] 1.520481 | Val Accuracy: 62.59% | LR: 0.000007674 | Time: 39.00s
# Epoch 139 - Train Loss: 0.001093 | Val MSE: 0.000076 | Val MAE: 0.006927 | Val R²: 0.9275 | [Boundary loss] 0.000125 | [Heaters loss] 0.000078 | [Physics loss] 1.524037 | Val Accuracy: 66.03% | LR: 0.000007674 | Time: 39.09s
# Epoch 140 - Train Loss: 0.001088 | Val MSE: 0.000079 | Val MAE: 0.007080 | Val R²: 0.9249 | [Boundary loss] 0.000171 | [Heaters loss] 0.000081 | [Physics loss] 1.521703 | Val Accuracy: 64.75% | LR: 0.000007674 | Time: 38.94s
# Epoch 141 - Train Loss: 0.001089 | Val MSE: 0.000076 | Val MAE: 0.006902 | Val R²: 0.9281 | [Boundary loss] 0.000115 | [Heaters loss] 0.000077 | [Physics loss] 1.522633 | Val Accuracy: 66.14% | LR: 0.000007674 | Time: 39.09s
# Epoch 142 - Train Loss: 0.001088 | Val MSE: 0.000076 | Val MAE: 0.006874 | Val R²: 0.9284 | [Boundary loss] 0.000073 | [Heaters loss] 0.000076 | [Physics loss] 1.523487 | Val Accuracy: 66.40% | LR: 0.000007674 | Time: 39.75s
# Epoch 143 - Train Loss: 0.001087 | Val MSE: 0.000084 | Val MAE: 0.007315 | Val R²: 0.9204 | [Boundary loss] 0.000200 | [Heaters loss] 0.000087 | [Physics loss] 1.521539 | Val Accuracy: 63.03% | LR: 0.000007674 | Time: 39.80s
# Epoch 144 - Train Loss: 0.001088 | Val MSE: 0.000076 | Val MAE: 0.006885 | Val R²: 0.9282 | [Boundary loss] 0.000092 | [Heaters loss] 0.000076 | [Physics loss] 1.523873 | Val Accuracy: 66.32% | LR: 0.000007674 | Time: 39.82s
# Epoch 145 - Train Loss: 0.001089 | Val MSE: 0.000076 | Val MAE: 0.006884 | Val R²: 0.9283 | [Boundary loss] 0.000105 | [Heaters loss] 0.000076 | [Physics loss] 1.527034 | Val Accuracy: 66.31% | LR: 0.000007674 | Time: 39.72s
# Epoch 146 - Train Loss: 0.001093 | Val MSE: 0.000076 | Val MAE: 0.006929 | Val R²: 0.9275 | [Boundary loss] 0.000112 | [Heaters loss] 0.000077 | [Physics loss] 1.522639 | Val Accuracy: 65.99% | LR: 0.000003837 | Time: 40.35s
# Epoch 147 - Train Loss: 0.001077 | Val MSE: 0.000077 | Val MAE: 0.006968 | Val R²: 0.9268 | [Boundary loss] 0.000111 | [Heaters loss] 0.000078 | [Physics loss] 1.524537 | Val Accuracy: 65.71% | LR: 0.000003837 | Time: 41.64s
# Epoch 148 - Train Loss: 0.001075 | Val MSE: 0.000079 | Val MAE: 0.007080 | Val R²: 0.9247 | [Boundary loss] 0.000140 | [Heaters loss] 0.000081 | [Physics loss] 1.521295 | Val Accuracy: 64.90% | LR: 0.000003837 | Time: 39.99s
# Epoch 149 - Train Loss: 0.001076 | Val MSE: 0.000078 | Val MAE: 0.006994 | Val R²: 0.9265 | [Boundary loss] 0.000139 | [Heaters loss] 0.000079 | [Physics loss] 1.522537 | Val Accuracy: 65.46% | LR: 0.000003837 | Time: 40.21s
# Epoch 150 - Train Loss: 0.001080 | Val MSE: 0.000078 | Val MAE: 0.006993 | Val R²: 0.9264 | [Boundary loss] 0.000101 | [Heaters loss] 0.000078 | [Physics loss] 1.524608 | Val Accuracy: 65.54% | LR: 0.000003837 | Time: 39.52s
# Epoch 151 - Train Loss: 0.001081 | Val MSE: 0.000077 | Val MAE: 0.006944 | Val R²: 0.9273 | [Boundary loss] 0.000113 | [Heaters loss] 0.000078 | [Physics loss] 1.524136 | Val Accuracy: 65.86% | LR: 0.000003837 | Time: 38.73s
# Epoch 152 - Train Loss: 0.001076 | Val MSE: 0.000078 | Val MAE: 0.007002 | Val R²: 0.9265 | [Boundary loss] 0.000138 | [Heaters loss] 0.000079 | [Physics loss] 1.524099 | Val Accuracy: 65.36% | LR: 0.000003837 | Time: 39.63s
# Epoch 153 - Train Loss: 0.001079 | Val MSE: 0.000077 | Val MAE: 0.006964 | Val R²: 0.9269 | [Boundary loss] 0.000119 | [Heaters loss] 0.000078 | [Physics loss] 1.522640 | Val Accuracy: 65.73% | LR: 0.000003837 | Time: 39.86s
# Epoch 154 - Train Loss: 0.001078 | Val MSE: 0.000077 | Val MAE: 0.006966 | Val R²: 0.9270 | [Boundary loss] 0.000133 | [Heaters loss] 0.000078 | [Physics loss] 1.522594 | Val Accuracy: 65.68% | LR: 0.000003837 | Time: 40.26s
# Epoch 155 - Train Loss: 0.001077 | Val MSE: 0.000079 | Val MAE: 0.007067 | Val R²: 0.9251 | [Boundary loss] 0.000135 | [Heaters loss] 0.000080 | [Physics loss] 1.520492 | Val Accuracy: 64.94% | LR: 0.000003837 | Time: 39.37s
# Epoch 156 - Train Loss: 0.001079 | Val MSE: 0.000077 | Val MAE: 0.006962 | Val R²: 0.9271 | [Boundary loss] 0.000127 | [Heaters loss] 0.000078 | [Physics loss] 1.522926 | Val Accuracy: 65.66% | LR: 0.000003837 | Time: 38.87s
# Epoch 157 - Train Loss: 0.001081 | Val MSE: 0.000081 | Val MAE: 0.007160 | Val R²: 0.9232 | [Boundary loss] 0.000155 | [Heaters loss] 0.000083 | [Physics loss] 1.521171 | Val Accuracy: 64.28% | LR: 0.000001918 | Time: 38.75s
# Epoch 158 - Train Loss: 0.001075 | Val MSE: 0.000080 | Val MAE: 0.007102 | Val R²: 0.9245 | [Boundary loss] 0.000157 | [Heaters loss] 0.000082 | [Physics loss] 1.521400 | Val Accuracy: 64.67% | LR: 0.000001918 | Time: 39.65s
# Epoch 159 - Train Loss: 0.001070 | Val MSE: 0.000077 | Val MAE: 0.006964 | Val R²: 0.9271 | [Boundary loss] 0.000128 | [Heaters loss] 0.000078 | [Physics loss] 1.523207 | Val Accuracy: 65.67% | LR: 0.000001918 | Time: 40.03s
# Epoch 160 - Train Loss: 0.001078 | Val MSE: 0.000079 | Val MAE: 0.007051 | Val R²: 0.9253 | [Boundary loss] 0.000115 | [Heaters loss] 0.000080 | [Physics loss] 1.523437 | Val Accuracy: 65.13% | LR: 0.000001918 | Time: 39.56s
# Epoch 161 - Train Loss: 0.001076 | Val MSE: 0.000079 | Val MAE: 0.007064 | Val R²: 0.9251 | [Boundary loss] 0.000138 | [Heaters loss] 0.000080 | [Physics loss] 1.522522 | Val Accuracy: 64.99% | LR: 0.000001918 | Time: 40.13s
# Epoch 162 - Train Loss: 0.001075 | Val MSE: 0.000078 | Val MAE: 0.007023 | Val R²: 0.9260 | [Boundary loss] 0.000142 | [Heaters loss] 0.000080 | [Physics loss] 1.522898 | Val Accuracy: 65.24% | LR: 0.000001918 | Time: 40.13s
# Epoch 163 - Train Loss: 0.001074 | Val MSE: 0.000078 | Val MAE: 0.007036 | Val R²: 0.9257 | [Boundary loss] 0.000140 | [Heaters loss] 0.000080 | [Physics loss] 1.523407 | Val Accuracy: 65.13% | LR: 0.000001918 | Time: 39.99s
# Epoch 164 - Train Loss: 0.001075 | Val MSE: 0.000079 | Val MAE: 0.007076 | Val R²: 0.9251 | [Boundary loss] 0.000156 | [Heaters loss] 0.000081 | [Physics loss] 1.522497 | Val Accuracy: 64.81% | LR: 0.000001918 | Time: 39.73s
# Epoch 165 - Train Loss: 0.001076 | Val MSE: 0.000078 | Val MAE: 0.007041 | Val R²: 0.9256 | [Boundary loss] 0.000132 | [Heaters loss] 0.000080 | [Physics loss] 1.523073 | Val Accuracy: 65.14% | LR: 0.000001918 | Time: 39.72s
# Epoch 166 - Train Loss: 0.001070 | Val MSE: 0.000080 | Val MAE: 0.007129 | Val R²: 0.9239 | [Boundary loss] 0.000148 | [Heaters loss] 0.000082 | [Physics loss] 1.521305 | Val Accuracy: 64.48% | LR: 0.000001918 | Time: 43.10s
# Epoch 167 - Train Loss: 0.001078 | Val MSE: 0.000076 | Val MAE: 0.006925 | Val R²: 0.9277 | [Boundary loss] 0.000121 | [Heaters loss] 0.000077 | [Physics loss] 1.523149 | Val Accuracy: 66.01% | LR: 0.000001918 | Time: 39.04s
# Epoch 168 - Train Loss: 0.001075 | Val MSE: 0.000078 | Val MAE: 0.006995 | Val R²: 0.9265 | [Boundary loss] 0.000151 | [Heaters loss] 0.000079 | [Physics loss] 1.522960 | Val Accuracy: 65.40% | LR: 0.000000959 | Time: 41.83s
# Epoch 169 - Train Loss: 0.001076 | Val MSE: 0.000078 | Val MAE: 0.006998 | Val R²: 0.9265 | [Boundary loss] 0.000149 | [Heaters loss] 0.000079 | [Physics loss] 1.522423 | Val Accuracy: 65.38% | LR: 0.000000959 | Time: 40.57s
# Epoch 170 - Train Loss: 0.001070 | Val MSE: 0.000080 | Val MAE: 0.007121 | Val R²: 0.9241 | [Boundary loss] 0.000152 | [Heaters loss] 0.000082 | [Physics loss] 1.522627 | Val Accuracy: 64.49% | LR: 0.000000959 | Time: 40.34s
# Epoch 171 - Train Loss: 0.001071 | Val MSE: 0.000080 | Val MAE: 0.007137 | Val R²: 0.9237 | [Boundary loss] 0.000151 | [Heaters loss] 0.000082 | [Physics loss] 1.522194 | Val Accuracy: 64.41% | LR: 0.000000959 | Time: 39.43s
# Epoch 172 - Train Loss: 0.001076 | Val MSE: 0.000078 | Val MAE: 0.007030 | Val R²: 0.9258 | [Boundary loss] 0.000124 | [Heaters loss] 0.000079 | [Physics loss] 1.523584 | Val Accuracy: 65.23% | LR: 0.000000959 | Time: 40.36s
# Epoch 173 - Train Loss: 0.001070 | Val MSE: 0.000078 | Val MAE: 0.007001 | Val R²: 0.9263 | [Boundary loss] 0.000129 | [Heaters loss] 0.000079 | [Physics loss] 1.522678 | Val Accuracy: 65.43% | LR: 0.000000959 | Time: 39.80s
# Epoch 174 - Train Loss: 0.001073 | Val MSE: 0.000079 | Val MAE: 0.007068 | Val R²: 0.9249 | [Boundary loss] 0.000131 | [Heaters loss] 0.000080 | [Physics loss] 1.521670 | Val Accuracy: 64.97% | LR: 0.000000959 | Time: 39.39s
# Epoch 175 - Train Loss: 0.001070 | Val MSE: 0.000079 | Val MAE: 0.007046 | Val R²: 0.9254 | [Boundary loss] 0.000146 | [Heaters loss] 0.000080 | [Physics loss] 1.521811 | Val Accuracy: 65.10% | LR: 0.000000959 | Time: 39.00s
#  Early stopping triggered at epoch 174
# Tiempo por época        : 33.78

# %%
# Cargar el mejor modelo antes de guardar
if best_model_state is not None:
    model.load_state_dict(best_model_state)
else:
    print("Advertencia: No se ha encontrado un modelo mejor durante el entrenamiento.")

# Crear nombre de archivo con los hiperparámetros clave
model_name = (
    f"GAT_Layers_{config['num_layers']}_"
    f"HDim_{config['hidden_dim']}_"
    f"Epochs_{final_epoch}_"
    f"Heads_{config['heads']}_"
    f"Lr_{best_lr:.9f}_"    
    f"B_LOSS_{config['use_boundary_loss']}_"
    f"Lambda_{config['lambda_boundary']}_"
    f"H_LOSS_{config['use_heater_loss']}_"
    f"Lambda_{config['lambda_heater']}_"
    f"PI_{config['use_physics']}_"
    f"Lambda_{config['lambda_physics']}_"
    f"Batch_{config['batch_size']}.pth"
)
print("Nombre del modelo:", model_name)
# Out:
# Nombre del modelo: GAT_Layers_5_HDim_32_Epochs_75_Heads_8_Lr_0.000122784_B_LOSS_True_Lambda_1_H_LOSS_True_Lambda_10_PI_True_Lambda_0.0001_Batch_32.pth

# %%
# GRAFICAR MSE
# Crear carpeta si no existe
os.makedirs("LOSS_IMG", exist_ok=True)
loss_img_filename = model_name.replace(".pth", ".svg")
loss_img_path = os.path.join("LOSS_IMG", loss_img_filename)

plt.figure(figsize=(8, 5))
plt.plot(train_losses, label='Train Loss', linewidth=2)
plt.plot(val_losses, label='Val Loss (MSE)', linewidth=2)

# Escala logarítmica en y (opcional)
plt.yscale("log")

plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Evolución del Loss por Época')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Eje X con enteros
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

plt.savefig(loss_img_path, format="svg") 
plt.show()

# %% [markdown]
# ### Carga de modelos ya entrenados

# %%
if config["load_model"]:
    from dataset_utils import load_model_by_name


    # Definir el modelo a cargar, los modelos guardados no guardan la arquitectura de la red
    model = GAT(
        input_dim=config["input_dim"],
        hidden_dim= 64,
        output_dim=config["output_dim"],
        num_layers= 10,
        heads= 8,
        use_dropout=config["use_dropout"],
        dropout_rate=config["dropout_rate"],
        use_batchnorm=config["use_batchnorm"],
        use_residual=config["use_residual"]
    ).to(device)

    # Nombre exacto del archivo que quieres cargar, cambiar solo los números
    model_filename = "GAT_Layers_10_HDim_64_Epochs_1000_Heads_8_Lr_0.001_Batch_32.pth"

    # Cargar modelo concreto
    model = load_model_by_name(model, model_filename)
    print("Modelo cargado:", model_filename)

# %% [markdown]
# ### Evaluación

# %%
# Evaluar en test y graficar un ejemplo
print("Evaluando en test set con visualización de un ejemplo:")
test_mse, test_mae, test_r2, test_accuracy, test_physics, test_boundary, test_heater, test_rmse, test_total_loss = evaluate(
    model, test_loader, device, norm_info, lambda_physics=config["lambda_physics"],
    use_physics=config["use_physics"], lambda_boundary=config["lambda_boundary"],
    use_boundary_loss=config["use_boundary_loss"], lambda_heater=config["lambda_heater"],
    use_heater_loss=config["use_heater_loss"],
    error_threshold=config["error_threshold_K"],
    percentage_threshold=config["percentage_threshold"] if config["use_percentage_threshold"] else None,
    plot_results=True
)

physics_loss_str = f"{test_physics:.6f}" if test_physics is not None else "N/A"

max_T_outputs = norm_info["max_T_outputs"].to(device)
mae_K = test_mae * max_T_outputs
rmse_K = test_rmse * (max_T_outputs)
mse_K = test_mse * (max_T_outputs ** 2)
print(f"MAE en Kelvin     : {mae_K:.3f} K")
print(f"RMSE en Kelvin    : {rmse_K:.3f} K")
print(f"MSE en Kelvin²    : {mse_K:.3f} K²")


print("Resultados del test:")
print(f"MSE       : {test_mse:.6f}")
print(f"MAE       : {test_mae:.6f}")
print(f"R²        : {test_r2:.4f}")
print(f"Accuracy  : {test_accuracy:.2f}%")
print(f"Boundary Loss  : {test_boundary:.6f}")
print(f"Heaters Loss  : {test_heater:.6f}")
print(f"Physics Loss  : {physics_loss_str}")
# Out:
# Evaluando en test set con visualización de un ejemplo:
# MAE en Kelvin     : 2.567 K
# RMSE en Kelvin    : 3.236 K
# MSE en Kelvin²    : 10.470 K²
# Resultados del test:
# MSE       : 0.000079
# MAE       : 0.007033
# R²        : 0.9253
# Accuracy  : 65.27%
# Boundary Loss  : 0.000146
# Heaters Loss  : 0.000080
# Physics Loss  : 1.516433

# %% [markdown]
# ### GNNExplainer

# %%
from torch_geometric.explain import Explainer, GNNExplainer, ModelConfig

# Poner el modelo en modo evaluación
model.eval()

# Crear el explainer solo una vez
explainer = Explainer(
    model=model,
    algorithm=GNNExplainer(epochs=200),
    explanation_type='model',
    edge_mask_type='object',
    node_mask_type='attributes',
    model_config=ModelConfig(
        mode='regression',
        task_level='node',
        return_type='raw'
    )
)

# ---------------- CONFIGURACIÓN ----------------
graph_idx = 3      # <- Cambia este valor para elegir el grafo del test set
node_idx = 87     # <- Cambia este valor para elegir el nodo a explicar
# ------------------------------------------------

# Obtener el grafo y pasarlo a GPU si es necesario
graph = test_dataset[graph_idx].to(device)

# Predecir con el modelo
with torch.no_grad():
    pred = model(graph.x, graph.edge_index).squeeze()
true = graph.y.squeeze()
#error = torch.abs(pred - true)
pred_real = pred * max_T_interfaces
true_real = true * max_T_interfaces
error_real = torch.abs(pred_real - true_real)

# Obtener explicación
explanation = explainer(
    x=graph.x,
    edge_index=graph.edge_index,
    index=node_idx
)

# Obtener importancia del explainer y agrupar por nodo
importance = explanation.node_mask.squeeze().cpu()      # Así obtenemos las features por nodo
importance = importance.view(-1, 3)                     # Cambiamos a un tensor que pueda ser interpretado como [num_nodes, num_features]
importance_per_node = importance.mean(dim=1)            # [num_nodes] Hacemos la media de la importancia de las 3 características en la predicción

# Obtener tamaño cuadrícula real del dataset
num_nodes = graph.y.numel()
print("Número de nodos:", num_nodes)
grid_size = int(num_nodes ** 0.5)
assert grid_size ** 2 == num_nodes, f"El número de nodos ({num_nodes}) no coincide con cuadrícula {grid_size}x{grid_size}"

# Convertir vectores a cuadrícula
importance_grid = importance_per_node.view(grid_size, grid_size)
error_grid = error_real.view(grid_size, grid_size).cpu()

# Visualización
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

im1 = axs[0].imshow(importance_grid, cmap='hot')
# Coordenadas del nodo que estás explicando
row = node_idx // grid_size
col = node_idx % grid_size

# Dibujar un punto rojo en la celda correspondiente
axs[0].plot(col, row, 'o', markersize=10, markeredgecolor='black', markerfacecolor='cyan', label='Nodo explicado')
axs[0].legend(loc='upper right')

axs[0].set_title(f"Importancia (nodo {node_idx})")
plt.colorbar(im1, ax=axs[0])

im2 = axs[1].imshow(error_grid, cmap='Blues')
# Número de nodos a etiquetar
top_n = 5  # "n" nodos de mayor error a mostrar

# Obtener los índices de los nodos con mayor error
top_error_nodes = torch.topk(error_real, top_n).indices.cpu()

for idx in top_error_nodes:
    idx = idx.item()
    row = idx // grid_size
    col = idx % grid_size
    axs[1].text(
        col, row, str(idx),
        ha='center', va='center',
        fontsize=8, fontweight='bold',
        color='black', bbox=dict(boxstyle='round,pad=0.2', facecolor='white', edgecolor='none', alpha=0.7)
    )
axs[1].set_title("Error absoluto por nodo")
plt.colorbar(im2, ax=axs[1])

plt.suptitle(f"Grafo {graph_idx} | Nodo {node_idx} explicado")
plt.tight_layout()
plt.show()
# Out:
# Número de nodos: 169

# %% [markdown]
# ### Guardado del modelo ya entrenado

# %%
# Crear carpeta si no existe
save_dir = "saved_models"
os.makedirs(save_dir, exist_ok=True)

# Guardar el modelo
model_path = os.path.join(save_dir, model_name)
if config["save_model"]:
    # Guardar el modelo entrenado
    torch.save(model.state_dict(), model_path)

    print(f" Modelo guardado en: {model_path}")
# Out:
#  Modelo guardado en: saved_models\GAT_Layers_5_HDim_32_Epochs_75_Heads_8_Lr_0.000122784_B_LOSS_True_Lambda_1_H_LOSS_True_Lambda_10_PI_True_Lambda_0.0001_Batch_32.pth

# %% [markdown]
# ### Predicción

# %%
fr train_eval import predict
from dataset_utils import load_latest_model
# Cargar el modelo más reciente
model = GAT(
    input_dim=config["input_dim"],
    hidden_dim=config["hidden_dim"],
    output_dim=config["output_dim"],
    num_layers=config["num_layers"],
    heads=config["heads"],
    use_dropout=config["use_dropout"],
    dropout_rate=config["dropout_rate"],
    use_batchnorm=config["use_batchnorm"],
    use_residual=config["use_residual"]
)

model = load_latest_model(model)

# Predecir sobre test
predicciones = predict(model, test_loader)

print("Predicciones shape:", predicciones.shape)
# Out:
#   Cell In[24], line 1
#     fr train_eval import predict
#        ^
# SyntaxError: invalid syntax

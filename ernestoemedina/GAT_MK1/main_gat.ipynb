# %% [markdown]
# # Librerías

# %%
import torch
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import os
import sys
import time
import platform
import random
from torch.optim.lr_scheduler import ReduceLROnPlateau
from gat_model import GAT
from torch_geometric.loader import DataLoader
from dataset_utils import generate_edge_index, build_graph_list, build_graph_from_sample
from train_eval import train, evaluate, EarlyStopping

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %%
dir_path = os.getcwd()
print(dir_path)
# Out:
# c:\Users\ramse\Escritorio\Aero Ordenador\4to Aero\2do Cuatri\ia_thermal\ernestoemedina\GAT_MK1

# %%
# Ruta del dataset completo
dataset_path = os.path.join(dir_path, "Datasets", "PCB_dataset.pth")
norm_dataset_path = os.path.join(dir_path, "Datasets", "PCB_Dataset_Norm.pth")
info_path = os.path.join(dir_path, "Datasets", "normalization_info.pth")

# Cargar dataset
dataset = torch.load(dataset_path)
norm_dataset = torch.load(norm_dataset_path)
norm_info = torch.load(info_path)
print(norm_dataset.outputs.min(), norm_dataset.outputs.max())

#Esto es para demostrar que el dataset no tiene valores cero, debido a la estandarización
#T_interfaces = dataset.T_interfaces.view(-1)

# Cuántos son exactamente 0
#num_exact_zeros = (T_interfaces == 0.0).sum().item()

# Cuántos son muy pequeños pero no exactamente 0
#num_near_zeros = ((T_interfaces != 0.0) & (T_interfaces.abs() < 1e-5)).sum().item()

# Valor mínimo no nulo
#min_nonzero = T_interfaces[T_interfaces != 0.0].min().item()

#print(f"Valores totales: {T_interfaces.numel()}")
#print(f"Exactamente cero: {num_exact_zeros}")
#print(f"Pequeños pero ≠ 0 (|x| < 1e-5): {num_near_zeros}")
#print(f"Valor mínimo no nulo: {min_nonzero}")
# Out:
# tensor(0.7136) tensor(1.)
# C:\Users\ramse\AppData\Local\Temp\ipykernel_1824\2813147112.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dataset = torch.load(dataset_path)
# C:\Users\ramse\AppData\Local\Temp\ipykernel_1824\2813147112.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   norm_dataset = torch.load(norm_dataset_path)
# C:\Users\ramse\AppData\Local\Temp\ipykernel_1824\2813147112.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   norm_info = torch.load(info_path)

# %% [markdown]
# ## Para desnormalizar

# %%
max_T_interfaces = norm_info["max_T_interfaces"]
max_Q_heaters = norm_info["max_Q_heaters"]
max_T_env = norm_info["max_T_env"]

## En ppio no debería ser necesario, ya que hemos cargado el dataset sin normalizar

def desnormalize_inputs(dataset_norm, idx):
    T_interfaces_norm = dataset_norm.T_interfaces[idx]
    Q_heaters_norm = dataset_norm.Q_heaters[idx]
    T_env_norm = dataset_norm.T_env[idx]
    
    T_interfaces_real = T_interfaces_norm * max_T_interfaces
    Q_heaters_real = Q_heaters_norm * max_Q_heaters
    T_env_real = T_env_norm * max_T_env
    
    return T_interfaces_real, Q_heaters_real, T_env_real

# %%
idx = 1
T_interfaces_real, Q_heaters_real, T_env_real = desnormalize_inputs(norm_dataset, idx)

# Por ejemplo:
print(torch.max(T_interfaces_real), "K")
print(torch.max(Q_heaters_real), "W")
print(torch.max(T_env_real), "K")
# Out:
# tensor(309.7728) K
# tensor(0.8122) W
# tensor(298.0007) K

# %%
# Seleccionar un índice para graficar
idx = 1  # Puedes cambiar este valor

# Obtener los valores reales de las CC en T, Q y T_env
T_interfaces_real = dataset.denormalize_T_interfaces(dataset.T_interfaces)
Q_heaters_real = dataset.denormalize_Q_heaters(dataset.Q_heaters)
T_env_real = dataset.denormalize_T_env(dataset.T_env)

print(T_interfaces_real.shape)
print(torch.max(T_interfaces_real[idx]), "K")
print(torch.max(Q_heaters_real[idx]), "W")
print(torch.max(T_env_real[idx]), "K")
# Out:
# torch.Size([10000, 13, 13])
# tensor(309.7728) K
# tensor(0.8122) W
# tensor(298.0007) K

# %%
idx = 10
T_interfaces_norm = norm_dataset.T_interfaces[idx]
Q_heaters_norm = norm_dataset.Q_heaters[idx]
T_env_norm = norm_dataset.T_env[idx]

# %%
# Crear figura para mostrar las 3 variables
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
im1 = axs[0].imshow(T_interfaces_norm.numpy(), cmap='hot')
axs[0].set_title("T_interfaces_norm [0–1]")
plt.colorbar(im1, ax=axs[0])

im2 = axs[1].imshow(Q_heaters_norm.numpy(), cmap='hot')
axs[1].set_title("Q_heaters_norm [0–1]")
plt.colorbar(im2, ax=axs[1])

im3 = axs[2].imshow(T_env_norm.numpy(), cmap='hot')
axs[2].set_title("T_env_norm [0–1]")
plt.colorbar(im3, ax=axs[2])

plt.suptitle(f"Entrada del dataset  idx = {idx}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## GCN

# %% [markdown]
# ### Configuración de la red

# %%
# Configuración del modelo
config = {
    "input_dim": 3,           # 3 canales: T_interfaces, Q_heaters, T_env
    "hidden_dim": 128,
    "output_dim": 1,
    "num_layers": 3,
    "use_dropout": True,
    "dropout_rate": 0.3,
    "use_batchnorm": True,
    "use_residual": True,
    "batch_size": 16,
    "heads": 4,
    "lr": 0.0001,
    "max_epochs": 10000,
    "early_stop_patience": 100,
    "error_threshold_K": 3.0,
    "use_percentage_threshold": False,
    "percentage_threshold": 1.0,  # solo si se activa la opción
    "save_model": True,
    "load_model": False, # Cargar un modelo preentrenado
    "factor" : 0.5 , # Factor de reducción del learning rate
    "patience" : 10 , # Épocas sin mejora para reducir el learning rate
    "min_lr" : 1e-9,  # evita que baje infinitamente el learning rate
    "use_physics" : True,
    "lambda_physics" : 0.0001, # Peso de la física en la función de pérdida
    "use_boundary_loss" : True,
    "lambda_boundary" : 1,
    "use_heater_loss" : True,
    "lambda_heater" : 10
}

# %%
grid_size = norm_dataset.inputs.shape[-1]
print("PCB cuadrada de", grid_size, "nodos por lado")
edge_index = generate_edge_index(grid_size=grid_size) # Matriz de adyacencia bidireccional
graphs = build_graph_list(norm_dataset, edge_index)
# Out:
# PCB cuadrada de 13 nodos por lado

# %%
# Por si en algún momento el Dataset tuviera un patrón al ser generado
random.seed(42)
random.shuffle(graphs)

# %%
# Ruta al dataset normalizado

# Extraer un tensor de salida
sample_output = norm_dataset.outputs[0]

# Imprimir estadísticas globales de outputs
all_outputs = norm_dataset.outputs.view(-1)
print(f"Mean of outputs: {all_outputs.mean().item():.4f}")
print(f"Std of outputs:  {all_outputs.std().item():.4f}")

# También desde los atributos si están disponibles
if hasattr(norm_dataset, "T_outputs_mean"):
    print(f"Atributo .T_outputs_mean: {norm_dataset.T_outputs_mean.item():.4f}")
    print(f"Atributo .T_outputs_std:  {norm_dataset.T_outputs_std.item():.4f}")
# Out:
# Mean of outputs: 0.8303
# Std of outputs:  0.0338
# Atributo .T_outputs_mean: 0.0000
# Atributo .T_outputs_std:  1.0000

# %% [markdown]
# ### División Dataset

# %%
# División del dataset
train_size = int(0.8 * len(graphs))
val_size = int(0.1 * len(graphs))
test_size = len(graphs) - train_size - val_size

train_dataset = graphs[:train_size]
val_dataset = graphs[train_size:train_size + val_size]
test_dataset = graphs[train_size + val_size:]

# Crear DataLoaders
batch_size = config["batch_size"]
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
model = GAT(
    input_dim=config["input_dim"],
    hidden_dim=config["hidden_dim"],
    output_dim=config["output_dim"],
    num_layers=config["num_layers"],
    heads=config["heads"],
    use_dropout=config["use_dropout"],
    dropout_rate=config["dropout_rate"],
    use_batchnorm=config["use_batchnorm"],
    use_residual=config["use_residual"]
).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=config["lr"])
scheduler = ReduceLROnPlateau(
    optimizer,
    mode='min',            # queremos minimizar el val_loss
    factor=config["factor"],            # reduce a la mitad el LR
    patience=config["patience"],           # espera 10 épocas sin mejora
    verbose=True,          # imprime info cuando reduce
    min_lr=config["min_lr"]            # evita que baje infinitamente
)
# Out:
# c:\Users\ramse\anaconda3\Lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
print("Forma de entrada:", norm_dataset.inputs[0].shape)
print("Forma de salida:", norm_dataset.outputs[0].shape)
# Out:
# Forma de entrada: torch.Size([3, 13, 13])
# Forma de salida: torch.Size([13, 13])

# %% [markdown]
# ### Entrenamiento

# %%
# Entrenamiento
train_losses = []
val_losses = []

early_stopper = EarlyStopping(patience=config["early_stop_patience"])
max_epochs = config["max_epochs"]
best_lr=config["lr"]

print("Iniciando entrenamiento...")
for epoch in range(config["max_epochs"]):
    # Entrenar
    train_loss = train(model, train_loader, optimizer, device, norm_info, lambda_physics=config["lambda_physics"],
                       use_physics=config["use_physics"], lambda_boundary=config["lambda_boundary"],
                       use_boundary_loss=config["use_boundary_loss"], lambda_heater=config["lambda_heater"],
                       use_heater_loss=config["use_heater_loss"])
    train_losses.append(train_loss)

    # Evaluar en validación
    val_mse, val_mae, val_r2, val_accuracy, val_physics, val_boundary, val_heaters, val_total_loss = evaluate(
        model, val_loader, device, norm_info, lambda_physics=config["lambda_physics"],
        use_physics=config["use_physics"], lambda_boundary=config["lambda_boundary"],
        use_boundary_loss=config["use_boundary_loss"], lambda_heater=config["lambda_heater"],
        use_heater_loss=config["use_heater_loss"],
        error_threshold=config["error_threshold_K"],
        percentage_threshold=config["percentage_threshold"] if config["use_percentage_threshold"] else None,
        plot_results=False
    )
    val_losses.append(val_mse)

    scheduler.step(val_mse)

    # Formatear bien los losses opcionales
    physics_loss_str = f"{val_physics:.6f}" if config["use_physics"] else "N/A"
    boundary_loss_str = f"{val_boundary:.6f}" if config["use_boundary_loss"] else "N/A"
    heaters_loss_str = f"{val_heaters:.6f}" if config["use_heater_loss"] else "N/A"

    # Imprimir métricas
    print(f"Epoch {epoch + 1} - "
          f"Train Loss: {train_loss:.6f} | "
          f"Val MSE: {val_mse:.6f} | "
          f"Val MAE: {val_mae:.6f} | "
          f"Val R²: {val_r2:.4f} | "
          f"[Boundary loss] {boundary_loss_str} | "
          f"[Heaters loss] {heaters_loss_str} | "
          f"[Physics loss] {physics_loss_str} | "
          f"Val Accuracy: {val_accuracy:.2f}% | "
          f"LR: {optimizer.param_groups[0]['lr']:.9f}")

    # Guardar el mejor modelo en memoria
    if val_total_loss < early_stopper.best_loss:
        best_model_state = model.state_dict()
        final_epoch = epoch + 1
        best_lr = optimizer.param_groups[0]['lr']  # guardar lr actual

    early_stopper(val_total_loss, epoch)
    if early_stopper.early_stop:
        print(f" Early stopping triggered at epoch {epoch}")
        break
# Out:
# Iniciando entrenamiento...
# Epoch 1 - Train Loss: 3.915050 | Val MSE: 0.072245 | Val MAE: 0.221709 | Val R²: -71.0208 | [Boundary loss] 0.230770 | [Heaters loss] 0.075997 | [Physics loss] 30.514847 | Val Accuracy: 1.20% | LR: 0.000100000
# Epoch 2 - Train Loss: 1.600991 | Val MSE: 0.028916 | Val MAE: 0.131865 | Val R²: -27.9740 | [Boundary loss] 0.057112 | [Heaters loss] 0.029583 | [Physics loss] 32.794559 | Val Accuracy: 3.35% | LR: 0.000100000
# Epoch 3 - Train Loss: 1.027248 | Val MSE: 0.024548 | Val MAE: 0.119788 | Val R²: -23.6707 | [Boundary loss] 0.118017 | [Heaters loss] 0.026760 | [Physics loss] 31.459150 | Val Accuracy: 4.44% | LR: 0.000100000
# Epoch 4 - Train Loss: 0.735177 | Val MSE: 0.016976 | Val MAE: 0.100608 | Val R²: -16.1221 | [Boundary loss] 0.039641 | [Heaters loss] 0.017513 | [Physics loss] 34.288036 | Val Accuracy: 4.45% | LR: 0.000100000
# Epoch 5 - Train Loss: 0.554835 | Val MSE: 0.015271 | Val MAE: 0.097665 | Val R²: -14.4256 | [Boundary loss] 0.010796 | [Heaters loss] 0.015165 | [Physics loss] 36.640484 | Val Accuracy: 4.54% | LR: 0.000100000
# Epoch 6 - Train Loss: 0.429735 | Val MSE: 0.014217 | Val MAE: 0.095041 | Val R²: -13.3831 | [Boundary loss] 0.004734 | [Heaters loss] 0.013992 | [Physics loss] 35.084270 | Val Accuracy: 4.45% | LR: 0.000100000
# Epoch 7 - Train Loss: 0.347303 | Val MSE: 0.010817 | Val MAE: 0.075660 | Val R²: -9.9584 | [Boundary loss] 0.005328 | [Heaters loss] 0.010687 | [Physics loss] 26.828598 | Val Accuracy: 6.08% | LR: 0.000100000
# Epoch 8 - Train Loss: 0.287466 | Val MSE: 0.009263 | Val MAE: 0.072968 | Val R²: -8.3885 | [Boundary loss] 0.007919 | [Heaters loss] 0.009231 | [Physics loss] 21.472891 | Val Accuracy: 6.53% | LR: 0.000100000
# Epoch 9 - Train Loss: 0.245210 | Val MSE: 0.007871 | Val MAE: 0.068693 | Val R²: -6.9633 | [Boundary loss] 0.010473 | [Heaters loss] 0.007932 | [Physics loss] 15.746067 | Val Accuracy: 6.43% | LR: 0.000100000
# Epoch 10 - Train Loss: 0.188475 | Val MSE: 0.002715 | Val MAE: 0.038276 | Val R²: -1.7490 | [Boundary loss] 0.023666 | [Heaters loss] 0.003211 | [Physics loss] 6.072352 | Val Accuracy: 15.19% | LR: 0.000100000
# Epoch 11 - Train Loss: 0.131644 | Val MSE: 0.001583 | Val MAE: 0.030882 | Val R²: -0.5963 | [Boundary loss] 0.001466 | [Heaters loss] 0.001581 | [Physics loss] 3.590717 | Val Accuracy: 16.99% | LR: 0.000100000
# Epoch 12 - Train Loss: 0.105449 | Val MSE: 0.000979 | Val MAE: 0.024084 | Val R²: 0.0118 | [Boundary loss] 0.006184 | [Heaters loss] 0.001102 | [Physics loss] 2.739453 | Val Accuracy: 22.71% | LR: 0.000100000
# Epoch 13 - Train Loss: 0.086589 | Val MSE: 0.001349 | Val MAE: 0.029657 | Val R²: -0.3600 | [Boundary loss] 0.003312 | [Heaters loss] 0.001395 | [Physics loss] 2.568401 | Val Accuracy: 16.80% | LR: 0.000100000
# Epoch 14 - Train Loss: 0.073290 | Val MSE: 0.001127 | Val MAE: 0.026528 | Val R²: -0.1309 | [Boundary loss] 0.001093 | [Heaters loss] 0.001126 | [Physics loss] 2.301274 | Val Accuracy: 19.96% | LR: 0.000100000
# Epoch 15 - Train Loss: 0.062438 | Val MSE: 0.001647 | Val MAE: 0.034331 | Val R²: -0.6520 | [Boundary loss] 0.005589 | [Heaters loss] 0.001740 | [Physics loss] 2.197525 | Val Accuracy: 11.53% | LR: 0.000100000
# Epoch 16 - Train Loss: 0.053100 | Val MSE: 0.000824 | Val MAE: 0.023582 | Val R²: 0.1722 | [Boundary loss] 0.000277 | [Heaters loss] 0.000811 | [Physics loss] 1.842109 | Val Accuracy: 19.89% | LR: 0.000100000
# Epoch 17 - Train Loss: 0.045416 | Val MSE: 0.000522 | Val MAE: 0.018287 | Val R²: 0.4799 | [Boundary loss] 0.000500 | [Heaters loss] 0.000521 | [Physics loss] 1.795071 | Val Accuracy: 27.72% | LR: 0.000100000
# Epoch 18 - Train Loss: 0.039935 | Val MSE: 0.000544 | Val MAE: 0.018991 | Val R²: 0.4534 | [Boundary loss] 0.000169 | [Heaters loss] 0.000535 | [Physics loss] 1.718526 | Val Accuracy: 25.64% | LR: 0.000100000
# Epoch 19 - Train Loss: 0.033945 | Val MSE: 0.000612 | Val MAE: 0.020311 | Val R²: 0.3865 | [Boundary loss] 0.000076 | [Heaters loss] 0.000600 | [Physics loss] 1.738319 | Val Accuracy: 23.43% | LR: 0.000100000
# Epoch 20 - Train Loss: 0.030157 | Val MSE: 0.000671 | Val MAE: 0.021566 | Val R²: 0.3252 | [Boundary loss] 0.000571 | [Heaters loss] 0.000669 | [Physics loss] 1.719066 | Val Accuracy: 20.81% | LR: 0.000100000
# Epoch 21 - Train Loss: 0.026530 | Val MSE: 0.000504 | Val MAE: 0.018269 | Val R²: 0.4942 | [Boundary loss] 0.002826 | [Heaters loss] 0.000559 | [Physics loss] 1.613642 | Val Accuracy: 26.79% | LR: 0.000100000
# Epoch 22 - Train Loss: 0.023265 | Val MSE: 0.000305 | Val MAE: 0.014009 | Val R²: 0.6938 | [Boundary loss] 0.000084 | [Heaters loss] 0.000300 | [Physics loss] 1.642413 | Val Accuracy: 35.73% | LR: 0.000100000
# Epoch 23 - Train Loss: 0.021121 | Val MSE: 0.000435 | Val MAE: 0.016899 | Val R²: 0.5623 | [Boundary loss] 0.000605 | [Heaters loss] 0.000439 | [Physics loss] 1.707547 | Val Accuracy: 29.34% | LR: 0.000100000
# Epoch 24 - Train Loss: 0.018783 | Val MSE: 0.000363 | Val MAE: 0.015390 | Val R²: 0.6349 | [Boundary loss] 0.000480 | [Heaters loss] 0.000366 | [Physics loss] 1.632216 | Val Accuracy: 32.27% | LR: 0.000100000
# Epoch 25 - Train Loss: 0.016523 | Val MSE: 0.000290 | Val MAE: 0.013631 | Val R²: 0.7080 | [Boundary loss] 0.001090 | [Heaters loss] 0.000309 | [Physics loss] 1.626992 | Val Accuracy: 37.02% | LR: 0.000100000
# Epoch 26 - Train Loss: 0.015130 | Val MSE: 0.000340 | Val MAE: 0.014812 | Val R²: 0.6598 | [Boundary loss] 0.001185 | [Heaters loss] 0.000360 | [Physics loss] 1.571690 | Val Accuracy: 33.89% | LR: 0.000100000
# Epoch 27 - Train Loss: 0.013669 | Val MSE: 0.000264 | Val MAE: 0.012977 | Val R²: 0.7357 | [Boundary loss] 0.000329 | [Heaters loss] 0.000265 | [Physics loss] 1.584255 | Val Accuracy: 38.76% | LR: 0.000100000
# Epoch 28 - Train Loss: 0.012632 | Val MSE: 0.000394 | Val MAE: 0.016141 | Val R²: 0.6009 | [Boundary loss] 0.000767 | [Heaters loss] 0.000403 | [Physics loss] 1.642258 | Val Accuracy: 30.19% | LR: 0.000100000
# Epoch 29 - Train Loss: 0.011545 | Val MSE: 0.000240 | Val MAE: 0.012424 | Val R²: 0.7579 | [Boundary loss] 0.000042 | [Heaters loss] 0.000235 | [Physics loss] 1.586242 | Val Accuracy: 39.94% | LR: 0.000100000
# Epoch 30 - Train Loss: 0.010560 | Val MSE: 0.000332 | Val MAE: 0.014499 | Val R²: 0.6663 | [Boundary loss] 0.000160 | [Heaters loss] 0.000328 | [Physics loss] 1.542993 | Val Accuracy: 35.41% | LR: 0.000100000
# Epoch 31 - Train Loss: 0.009817 | Val MSE: 0.000235 | Val MAE: 0.012268 | Val R²: 0.7611 | [Boundary loss] 0.000223 | [Heaters loss] 0.000235 | [Physics loss] 1.611541 | Val Accuracy: 40.69% | LR: 0.000100000
# Epoch 32 - Train Loss: 0.009224 | Val MSE: 0.000304 | Val MAE: 0.014020 | Val R²: 0.6935 | [Boundary loss] 0.000061 | [Heaters loss] 0.000298 | [Physics loss] 1.588953 | Val Accuracy: 35.56% | LR: 0.000100000
# Epoch 33 - Train Loss: 0.008563 | Val MSE: 0.000366 | Val MAE: 0.015283 | Val R²: 0.6301 | [Boundary loss] 0.000203 | [Heaters loss] 0.000362 | [Physics loss] 1.626916 | Val Accuracy: 33.39% | LR: 0.000100000
# Epoch 34 - Train Loss: 0.008186 | Val MSE: 0.000421 | Val MAE: 0.016160 | Val R²: 0.5764 | [Boundary loss] 0.004285 | [Heaters loss] 0.000512 | [Physics loss] 1.571885 | Val Accuracy: 32.67% | LR: 0.000100000
# Epoch 35 - Train Loss: 0.007646 | Val MSE: 0.000354 | Val MAE: 0.015025 | Val R²: 0.6431 | [Boundary loss] 0.000185 | [Heaters loss] 0.000350 | [Physics loss] 1.560161 | Val Accuracy: 34.27% | LR: 0.000100000
# Epoch 36 - Train Loss: 0.007243 | Val MSE: 0.000346 | Val MAE: 0.014960 | Val R²: 0.6518 | [Boundary loss] 0.001853 | [Heaters loss] 0.000382 | [Physics loss] 1.663414 | Val Accuracy: 33.76% | LR: 0.000100000
# Epoch 37 - Train Loss: 0.006863 | Val MSE: 0.000257 | Val MAE: 0.012937 | Val R²: 0.7404 | [Boundary loss] 0.000737 | [Heaters loss] 0.000268 | [Physics loss] 1.543867 | Val Accuracy: 37.72% | LR: 0.000100000
# Epoch 38 - Train Loss: 0.006530 | Val MSE: 0.000270 | Val MAE: 0.013214 | Val R²: 0.7273 | [Boundary loss] 0.000549 | [Heaters loss] 0.000277 | [Physics loss] 1.523853 | Val Accuracy: 37.25% | LR: 0.000100000
# Epoch 39 - Train Loss: 0.006305 | Val MSE: 0.000243 | Val MAE: 0.012586 | Val R²: 0.7547 | [Boundary loss] 0.000086 | [Heaters loss] 0.000239 | [Physics loss] 1.542024 | Val Accuracy: 38.80% | LR: 0.000100000
# Epoch 40 - Train Loss: 0.006088 | Val MSE: 0.000313 | Val MAE: 0.013901 | Val R²: 0.6833 | [Boundary loss] 0.000081 | [Heaters loss] 0.000308 | [Physics loss] 1.509999 | Val Accuracy: 37.08% | LR: 0.000100000
# Epoch 41 - Train Loss: 0.005884 | Val MSE: 0.000287 | Val MAE: 0.013450 | Val R²: 0.7098 | [Boundary loss] 0.000264 | [Heaters loss] 0.000286 | [Physics loss] 1.567345 | Val Accuracy: 37.87% | LR: 0.000100000
# Epoch 42 - Train Loss: 0.005675 | Val MSE: 0.000279 | Val MAE: 0.013333 | Val R²: 0.7189 | [Boundary loss] 0.000192 | [Heaters loss] 0.000277 | [Physics loss] 1.535883 | Val Accuracy: 37.99% | LR: 0.000050000
# Epoch 43 - Train Loss: 0.005331 | Val MSE: 0.000266 | Val MAE: 0.013088 | Val R²: 0.7309 | [Boundary loss] 0.000575 | [Heaters loss] 0.000273 | [Physics loss] 1.513453 | Val Accuracy: 37.57% | LR: 0.000050000
# Epoch 44 - Train Loss: 0.005251 | Val MSE: 0.000236 | Val MAE: 0.012301 | Val R²: 0.7616 | [Boundary loss] 0.000061 | [Heaters loss] 0.000232 | [Physics loss] 1.551183 | Val Accuracy: 40.38% | LR: 0.000050000
# Epoch 45 - Train Loss: 0.005256 | Val MSE: 0.000251 | Val MAE: 0.012606 | Val R²: 0.7456 | [Boundary loss] 0.000129 | [Heaters loss] 0.000248 | [Physics loss] 1.541524 | Val Accuracy: 40.17% | LR: 0.000050000
# Epoch 46 - Train Loss: 0.005166 | Val MSE: 0.000242 | Val MAE: 0.012352 | Val R²: 0.7554 | [Boundary loss] 0.000020 | [Heaters loss] 0.000236 | [Physics loss] 1.529864 | Val Accuracy: 40.78% | LR: 0.000050000
# Epoch 47 - Train Loss: 0.005006 | Val MSE: 0.000253 | Val MAE: 0.012808 | Val R²: 0.7437 | [Boundary loss] 0.000644 | [Heaters loss] 0.000263 | [Physics loss] 1.544518 | Val Accuracy: 38.56% | LR: 0.000050000
# Epoch 48 - Train Loss: 0.004990 | Val MSE: 0.000222 | Val MAE: 0.011849 | Val R²: 0.7759 | [Boundary loss] 0.000019 | [Heaters loss] 0.000217 | [Physics loss] 1.532443 | Val Accuracy: 42.47% | LR: 0.000050000
# Epoch 49 - Train Loss: 0.004898 | Val MSE: 0.000278 | Val MAE: 0.013472 | Val R²: 0.7176 | [Boundary loss] 0.001107 | [Heaters loss] 0.000298 | [Physics loss] 1.523847 | Val Accuracy: 36.34% | LR: 0.000050000
# Epoch 50 - Train Loss: 0.004852 | Val MSE: 0.000216 | Val MAE: 0.011710 | Val R²: 0.7821 | [Boundary loss] 0.000097 | [Heaters loss] 0.000213 | [Physics loss] 1.544438 | Val Accuracy: 43.05% | LR: 0.000050000
# Epoch 51 - Train Loss: 0.004793 | Val MSE: 0.000283 | Val MAE: 0.013639 | Val R²: 0.7140 | [Boundary loss] 0.000081 | [Heaters loss] 0.000278 | [Physics loss] 1.541783 | Val Accuracy: 35.69% | LR: 0.000050000
# Epoch 52 - Train Loss: 0.004718 | Val MSE: 0.000218 | Val MAE: 0.011743 | Val R²: 0.7796 | [Boundary loss] 0.000023 | [Heaters loss] 0.000213 | [Physics loss] 1.528214 | Val Accuracy: 42.69% | LR: 0.000050000
# Epoch 53 - Train Loss: 0.004601 | Val MSE: 0.000215 | Val MAE: 0.011701 | Val R²: 0.7831 | [Boundary loss] 0.000403 | [Heaters loss] 0.000219 | [Physics loss] 1.541685 | Val Accuracy: 42.57% | LR: 0.000050000
# Epoch 54 - Train Loss: 0.004577 | Val MSE: 0.000298 | Val MAE: 0.013800 | Val R²: 0.6985 | [Boundary loss] 0.000155 | [Heaters loss] 0.000294 | [Physics loss] 1.514876 | Val Accuracy: 36.81% | LR: 0.000050000
# Epoch 55 - Train Loss: 0.004588 | Val MSE: 0.000314 | Val MAE: 0.014405 | Val R²: 0.6814 | [Boundary loss] 0.000777 | [Heaters loss] 0.000325 | [Physics loss] 1.544169 | Val Accuracy: 33.98% | LR: 0.000050000
# Epoch 56 - Train Loss: 0.004497 | Val MSE: 0.000274 | Val MAE: 0.013361 | Val R²: 0.7227 | [Boundary loss] 0.001179 | [Heaters loss] 0.000295 | [Physics loss] 1.534095 | Val Accuracy: 36.51% | LR: 0.000050000
# Epoch 57 - Train Loss: 0.004447 | Val MSE: 0.000223 | Val MAE: 0.011903 | Val R²: 0.7750 | [Boundary loss] 0.000052 | [Heaters loss] 0.000219 | [Physics loss] 1.547844 | Val Accuracy: 42.11% | LR: 0.000050000
# Epoch 58 - Train Loss: 0.004402 | Val MSE: 0.000206 | Val MAE: 0.011447 | Val R²: 0.7917 | [Boundary loss] 0.000118 | [Heaters loss] 0.000204 | [Physics loss] 1.511596 | Val Accuracy: 43.43% | LR: 0.000050000
# Epoch 59 - Train Loss: 0.004369 | Val MSE: 0.000323 | Val MAE: 0.014493 | Val R²: 0.6744 | [Boundary loss] 0.000017 | [Heaters loss] 0.000316 | [Physics loss] 1.515430 | Val Accuracy: 34.18% | LR: 0.000050000
# Epoch 60 - Train Loss: 0.004389 | Val MSE: 0.000387 | Val MAE: 0.016083 | Val R²: 0.6078 | [Boundary loss] 0.001397 | [Heaters loss] 0.000411 | [Physics loss] 1.515567 | Val Accuracy: 29.95% | LR: 0.000050000
# Epoch 61 - Train Loss: 0.004344 | Val MSE: 0.000233 | Val MAE: 0.012333 | Val R²: 0.7644 | [Boundary loss] 0.000898 | [Heaters loss] 0.000248 | [Physics loss] 1.532517 | Val Accuracy: 39.40% | LR: 0.000050000
# Epoch 62 - Train Loss: 0.004321 | Val MSE: 0.000220 | Val MAE: 0.011926 | Val R²: 0.7771 | [Boundary loss] 0.001317 | [Heaters loss] 0.000246 | [Physics loss] 1.530330 | Val Accuracy: 40.72% | LR: 0.000050000
# Epoch 63 - Train Loss: 0.004270 | Val MSE: 0.000253 | Val MAE: 0.012701 | Val R²: 0.7444 | [Boundary loss] 0.000014 | [Heaters loss] 0.000247 | [Physics loss] 1.512653 | Val Accuracy: 39.11% | LR: 0.000050000
# Epoch 64 - Train Loss: 0.004217 | Val MSE: 0.000206 | Val MAE: 0.011334 | Val R²: 0.7914 | [Boundary loss] 0.000075 | [Heaters loss] 0.000203 | [Physics loss] 1.505340 | Val Accuracy: 44.57% | LR: 0.000050000
# Epoch 65 - Train Loss: 0.004198 | Val MSE: 0.000274 | Val MAE: 0.013360 | Val R²: 0.7231 | [Boundary loss] 0.005851 | [Heaters loss] 0.000406 | [Physics loss] 1.618514 | Val Accuracy: 37.32% | LR: 0.000050000
# Epoch 66 - Train Loss: 0.004134 | Val MSE: 0.000220 | Val MAE: 0.011766 | Val R²: 0.7775 | [Boundary loss] 0.000391 | [Heaters loss] 0.000224 | [Physics loss] 1.528659 | Val Accuracy: 42.89% | LR: 0.000050000
# Epoch 67 - Train Loss: 0.004084 | Val MSE: 0.000231 | Val MAE: 0.012137 | Val R²: 0.7656 | [Boundary loss] 0.000033 | [Heaters loss] 0.000227 | [Physics loss] 1.531727 | Val Accuracy: 41.16% | LR: 0.000050000
# Epoch 68 - Train Loss: 0.004110 | Val MSE: 0.000273 | Val MAE: 0.013261 | Val R²: 0.7229 | [Boundary loss] 0.000166 | [Heaters loss] 0.000270 | [Physics loss] 1.504390 | Val Accuracy: 37.06% | LR: 0.000050000
# Epoch 69 - Train Loss: 0.004017 | Val MSE: 0.000228 | Val MAE: 0.012090 | Val R²: 0.7690 | [Boundary loss] 0.000327 | [Heaters loss] 0.000230 | [Physics loss] 1.506096 | Val Accuracy: 40.58% | LR: 0.000025000
# Epoch 70 - Train Loss: 0.003994 | Val MSE: 0.000239 | Val MAE: 0.012497 | Val R²: 0.7581 | [Boundary loss] 0.001044 | [Heaters loss] 0.000258 | [Physics loss] 1.530694 | Val Accuracy: 38.85% | LR: 0.000025000
# Epoch 71 - Train Loss: 0.003926 | Val MSE: 0.000248 | Val MAE: 0.012721 | Val R²: 0.7487 | [Boundary loss] 0.000629 | [Heaters loss] 0.000257 | [Physics loss] 1.519616 | Val Accuracy: 38.29% | LR: 0.000025000
# Epoch 72 - Train Loss: 0.003936 | Val MSE: 0.000252 | Val MAE: 0.012837 | Val R²: 0.7441 | [Boundary loss] 0.000565 | [Heaters loss] 0.000260 | [Physics loss] 1.528940 | Val Accuracy: 37.91% | LR: 0.000025000
# Epoch 73 - Train Loss: 0.003894 | Val MSE: 0.000207 | Val MAE: 0.011435 | Val R²: 0.7907 | [Boundary loss] 0.000384 | [Heaters loss] 0.000211 | [Physics loss] 1.511687 | Val Accuracy: 43.50% | LR: 0.000025000
# Epoch 74 - Train Loss: 0.003887 | Val MSE: 0.000224 | Val MAE: 0.011885 | Val R²: 0.7719 | [Boundary loss] 0.000008 | [Heaters loss] 0.000219 | [Physics loss] 1.508292 | Val Accuracy: 42.40% | LR: 0.000025000
# Epoch 75 - Train Loss: 0.003882 | Val MSE: 0.000228 | Val MAE: 0.012150 | Val R²: 0.7689 | [Boundary loss] 0.000332 | [Heaters loss] 0.000230 | [Physics loss] 1.518250 | Val Accuracy: 40.25% | LR: 0.000025000
# Epoch 76 - Train Loss: 0.003864 | Val MSE: 0.000223 | Val MAE: 0.011817 | Val R²: 0.7743 | [Boundary loss] 0.000017 | [Heaters loss] 0.000218 | [Physics loss] 1.500443 | Val Accuracy: 42.68% | LR: 0.000025000
# Epoch 77 - Train Loss: 0.003834 | Val MSE: 0.000213 | Val MAE: 0.011683 | Val R²: 0.7842 | [Boundary loss] 0.000192 | [Heaters loss] 0.000213 | [Physics loss] 1.509958 | Val Accuracy: 42.35% | LR: 0.000025000
# Epoch 78 - Train Loss: 0.003862 | Val MSE: 0.000204 | Val MAE: 0.011309 | Val R²: 0.7939 | [Boundary loss] 0.000011 | [Heaters loss] 0.000199 | [Physics loss] 1.507095 | Val Accuracy: 44.51% | LR: 0.000025000
# Epoch 79 - Train Loss: 0.003829 | Val MSE: 0.000232 | Val MAE: 0.012129 | Val R²: 0.7649 | [Boundary loss] 0.000280 | [Heaters loss] 0.000233 | [Physics loss] 1.505176 | Val Accuracy: 40.90% | LR: 0.000025000
# Epoch 80 - Train Loss: 0.003851 | Val MSE: 0.000214 | Val MAE: 0.011708 | Val R²: 0.7839 | [Boundary loss] 0.000752 | [Heaters loss] 0.000226 | [Physics loss] 1.504885 | Val Accuracy: 41.81% | LR: 0.000025000
# Epoch 81 - Train Loss: 0.003832 | Val MSE: 0.000210 | Val MAE: 0.011547 | Val R²: 0.7879 | [Boundary loss] 0.000054 | [Heaters loss] 0.000207 | [Physics loss] 1.523178 | Val Accuracy: 43.24% | LR: 0.000025000
# Epoch 82 - Train Loss: 0.003802 | Val MSE: 0.000226 | Val MAE: 0.012075 | Val R²: 0.7717 | [Boundary loss] 0.000514 | [Heaters loss] 0.000232 | [Physics loss] 1.523504 | Val Accuracy: 40.70% | LR: 0.000025000
# Epoch 83 - Train Loss: 0.003781 | Val MSE: 0.000285 | Val MAE: 0.013565 | Val R²: 0.7107 | [Boundary loss] 0.000097 | [Heaters loss] 0.000281 | [Physics loss] 1.500010 | Val Accuracy: 36.40% | LR: 0.000025000
# Epoch 84 - Train Loss: 0.003790 | Val MSE: 0.000216 | Val MAE: 0.011634 | Val R²: 0.7816 | [Boundary loss] 0.000054 | [Heaters loss] 0.000212 | [Physics loss] 1.509263 | Val Accuracy: 43.55% | LR: 0.000025000
# Epoch 85 - Train Loss: 0.003753 | Val MSE: 0.000225 | Val MAE: 0.012086 | Val R²: 0.7719 | [Boundary loss] 0.000453 | [Heaters loss] 0.000231 | [Physics loss] 1.518342 | Val Accuracy: 40.43% | LR: 0.000025000
# Epoch 86 - Train Loss: 0.003772 | Val MSE: 0.000264 | Val MAE: 0.012767 | Val R²: 0.7318 | [Boundary loss] 0.000205 | [Heaters loss] 0.000263 | [Physics loss] 1.500558 | Val Accuracy: 40.62% | LR: 0.000025000
# Epoch 87 - Train Loss: 0.003756 | Val MSE: 0.000256 | Val MAE: 0.012909 | Val R²: 0.7403 | [Boundary loss] 0.001232 | [Heaters loss] 0.000279 | [Physics loss] 1.518039 | Val Accuracy: 37.95% | LR: 0.000025000
# Epoch 88 - Train Loss: 0.003735 | Val MSE: 0.000217 | Val MAE: 0.011706 | Val R²: 0.7797 | [Boundary loss] 0.000066 | [Heaters loss] 0.000214 | [Physics loss] 1.508017 | Val Accuracy: 42.98% | LR: 0.000025000
# Epoch 89 - Train Loss: 0.003761 | Val MSE: 0.000282 | Val MAE: 0.013569 | Val R²: 0.7141 | [Boundary loss] 0.001290 | [Heaters loss] 0.000306 | [Physics loss] 1.521326 | Val Accuracy: 36.29% | LR: 0.000012500
# Epoch 90 - Train Loss: 0.003680 | Val MSE: 0.000238 | Val MAE: 0.012376 | Val R²: 0.7586 | [Boundary loss] 0.000214 | [Heaters loss] 0.000238 | [Physics loss] 1.507605 | Val Accuracy: 39.80% | LR: 0.000012500
# Epoch 91 - Train Loss: 0.003673 | Val MSE: 0.000223 | Val MAE: 0.011853 | Val R²: 0.7738 | [Boundary loss] 0.000030 | [Heaters loss] 0.000219 | [Physics loss] 1.506575 | Val Accuracy: 42.49% | LR: 0.000012500
# Epoch 92 - Train Loss: 0.003679 | Val MSE: 0.000250 | Val MAE: 0.012714 | Val R²: 0.7471 | [Boundary loss] 0.000404 | [Heaters loss] 0.000253 | [Physics loss] 1.511742 | Val Accuracy: 38.37% | LR: 0.000012500
# Epoch 93 - Train Loss: 0.003656 | Val MSE: 0.000237 | Val MAE: 0.012159 | Val R²: 0.7596 | [Boundary loss] 0.000090 | [Heaters loss] 0.000233 | [Physics loss] 1.509754 | Val Accuracy: 42.13% | LR: 0.000012500
# Epoch 94 - Train Loss: 0.003662 | Val MSE: 0.000223 | Val MAE: 0.011827 | Val R²: 0.7741 | [Boundary loss] 0.000005 | [Heaters loss] 0.000218 | [Physics loss] 1.511408 | Val Accuracy: 42.82% | LR: 0.000012500
# Epoch 95 - Train Loss: 0.003642 | Val MSE: 0.000290 | Val MAE: 0.013752 | Val R²: 0.7059 | [Boundary loss] 0.000224 | [Heaters loss] 0.000288 | [Physics loss] 1.516726 | Val Accuracy: 35.38% | LR: 0.000012500
# Epoch 96 - Train Loss: 0.003654 | Val MSE: 0.000271 | Val MAE: 0.013283 | Val R²: 0.7249 | [Boundary loss] 0.000380 | [Heaters loss] 0.000274 | [Physics loss] 1.519893 | Val Accuracy: 36.71% | LR: 0.000012500
# Epoch 97 - Train Loss: 0.003632 | Val MSE: 0.000263 | Val MAE: 0.013057 | Val R²: 0.7330 | [Boundary loss] 0.000343 | [Heaters loss] 0.000265 | [Physics loss] 1.515252 | Val Accuracy: 37.45% | LR: 0.000012500
# Epoch 98 - Train Loss: 0.003634 | Val MSE: 0.000233 | Val MAE: 0.012277 | Val R²: 0.7637 | [Boundary loss] 0.000260 | [Heaters loss] 0.000234 | [Physics loss] 1.526988 | Val Accuracy: 40.08% | LR: 0.000012500
# Epoch 99 - Train Loss: 0.003611 | Val MSE: 0.000252 | Val MAE: 0.012738 | Val R²: 0.7451 | [Boundary loss] 0.000271 | [Heaters loss] 0.000252 | [Physics loss] 1.523333 | Val Accuracy: 38.63% | LR: 0.000012500
# Epoch 100 - Train Loss: 0.003638 | Val MSE: 0.000263 | Val MAE: 0.013047 | Val R²: 0.7334 | [Boundary loss] 0.000426 | [Heaters loss] 0.000267 | [Physics loss] 1.511675 | Val Accuracy: 37.44% | LR: 0.000006250
# Epoch 101 - Train Loss: 0.003590 | Val MSE: 0.000241 | Val MAE: 0.012354 | Val R²: 0.7560 | [Boundary loss] 0.000061 | [Heaters loss] 0.000237 | [Physics loss] 1.511212 | Val Accuracy: 40.64% | LR: 0.000006250
# Epoch 102 - Train Loss: 0.003588 | Val MSE: 0.000271 | Val MAE: 0.013234 | Val R²: 0.7254 | [Boundary loss] 0.000251 | [Heaters loss] 0.000270 | [Physics loss] 1.520295 | Val Accuracy: 37.12% | LR: 0.000006250
# Epoch 103 - Train Loss: 0.003587 | Val MSE: 0.000224 | Val MAE: 0.011888 | Val R²: 0.7733 | [Boundary loss] 0.000014 | [Heaters loss] 0.000219 | [Physics loss] 1.520297 | Val Accuracy: 42.49% | LR: 0.000006250
# Epoch 104 - Train Loss: 0.003578 | Val MSE: 0.000234 | Val MAE: 0.012151 | Val R²: 0.7628 | [Boundary loss] 0.000051 | [Heaters loss] 0.000230 | [Physics loss] 1.513373 | Val Accuracy: 41.44% | LR: 0.000006250
# Epoch 105 - Train Loss: 0.003592 | Val MSE: 0.000257 | Val MAE: 0.012802 | Val R²: 0.7395 | [Boundary loss] 0.000090 | [Heaters loss] 0.000253 | [Physics loss] 1.514919 | Val Accuracy: 39.08% | LR: 0.000006250
# Epoch 106 - Train Loss: 0.003604 | Val MSE: 0.000242 | Val MAE: 0.012292 | Val R²: 0.7550 | [Boundary loss] 0.000003 | [Heaters loss] 0.000236 | [Physics loss] 1.515329 | Val Accuracy: 41.54% | LR: 0.000006250
# Epoch 107 - Train Loss: 0.003567 | Val MSE: 0.000247 | Val MAE: 0.012573 | Val R²: 0.7494 | [Boundary loss] 0.000101 | [Heaters loss] 0.000244 | [Physics loss] 1.520756 | Val Accuracy: 39.65% | LR: 0.000006250
# Epoch 108 - Train Loss: 0.003560 | Val MSE: 0.000257 | Val MAE: 0.012820 | Val R²: 0.7400 | [Boundary loss] 0.000147 | [Heaters loss] 0.000254 | [Physics loss] 1.520581 | Val Accuracy: 38.82% | LR: 0.000006250
# Epoch 109 - Train Loss: 0.003568 | Val MSE: 0.000236 | Val MAE: 0.012162 | Val R²: 0.7608 | [Boundary loss] 0.000011 | [Heaters loss] 0.000231 | [Physics loss] 1.514324 | Val Accuracy: 41.73% | LR: 0.000006250
# Epoch 110 - Train Loss: 0.003587 | Val MSE: 0.000240 | Val MAE: 0.012335 | Val R²: 0.7566 | [Boundary loss] 0.000055 | [Heaters loss] 0.000236 | [Physics loss] 1.516612 | Val Accuracy: 40.85% | LR: 0.000006250
# Epoch 111 - Train Loss: 0.003573 | Val MSE: 0.000242 | Val MAE: 0.012363 | Val R²: 0.7543 | [Boundary loss] 0.000020 | [Heaters loss] 0.000237 | [Physics loss] 1.518076 | Val Accuracy: 40.95% | LR: 0.000003125
# Epoch 112 - Train Loss: 0.003564 | Val MSE: 0.000228 | Val MAE: 0.012001 | Val R²: 0.7687 | [Boundary loss] 0.000008 | [Heaters loss] 0.000223 | [Physics loss] 1.518483 | Val Accuracy: 42.12% | LR: 0.000003125
# Epoch 113 - Train Loss: 0.003538 | Val MSE: 0.000254 | Val MAE: 0.012714 | Val R²: 0.7422 | [Boundary loss] 0.000075 | [Heaters loss] 0.000250 | [Physics loss] 1.518114 | Val Accuracy: 39.56% | LR: 0.000003125
# Epoch 114 - Train Loss: 0.003538 | Val MSE: 0.000247 | Val MAE: 0.012559 | Val R²: 0.7493 | [Boundary loss] 0.000113 | [Heaters loss] 0.000244 | [Physics loss] 1.520594 | Val Accuracy: 39.77% | LR: 0.000003125
# Epoch 115 - Train Loss: 0.003534 | Val MSE: 0.000236 | Val MAE: 0.012310 | Val R²: 0.7606 | [Boundary loss] 0.000189 | [Heaters loss] 0.000235 | [Physics loss] 1.523643 | Val Accuracy: 40.33% | LR: 0.000003125
# Epoch 116 - Train Loss: 0.003534 | Val MSE: 0.000233 | Val MAE: 0.012149 | Val R²: 0.7641 | [Boundary loss] 0.000043 | [Heaters loss] 0.000229 | [Physics loss] 1.516789 | Val Accuracy: 41.40% | LR: 0.000003125
# Epoch 117 - Train Loss: 0.003557 | Val MSE: 0.000238 | Val MAE: 0.012271 | Val R²: 0.7586 | [Boundary loss] 0.000021 | [Heaters loss] 0.000233 | [Physics loss] 1.517307 | Val Accuracy: 41.07% | LR: 0.000003125
# Epoch 118 - Train Loss: 0.003536 | Val MSE: 0.000253 | Val MAE: 0.012708 | Val R²: 0.7434 | [Boundary loss] 0.000132 | [Heaters loss] 0.000250 | [Physics loss] 1.520850 | Val Accuracy: 39.32% | LR: 0.000003125
# Epoch 119 - Train Loss: 0.003529 | Val MSE: 0.000245 | Val MAE: 0.012398 | Val R²: 0.7514 | [Boundary loss] 0.000002 | [Heaters loss] 0.000239 | [Physics loss] 1.519724 | Val Accuracy: 41.21% | LR: 0.000003125
# Epoch 120 - Train Loss: 0.003569 | Val MSE: 0.000248 | Val MAE: 0.012592 | Val R²: 0.7485 | [Boundary loss] 0.000134 | [Heaters loss] 0.000245 | [Physics loss] 1.521136 | Val Accuracy: 39.64% | LR: 0.000003125
# Epoch 121 - Train Loss: 0.003570 | Val MSE: 0.000244 | Val MAE: 0.012394 | Val R²: 0.7532 | [Boundary loss] 0.000030 | [Heaters loss] 0.000238 | [Physics loss] 1.520381 | Val Accuracy: 40.82% | LR: 0.000003125
# Epoch 122 - Train Loss: 0.003552 | Val MSE: 0.000242 | Val MAE: 0.012470 | Val R²: 0.7544 | [Boundary loss] 0.000207 | [Heaters loss] 0.000241 | [Physics loss] 1.525918 | Val Accuracy: 39.79% | LR: 0.000001563
# Epoch 123 - Train Loss: 0.003563 | Val MSE: 0.000240 | Val MAE: 0.012358 | Val R²: 0.7563 | [Boundary loss] 0.000075 | [Heaters loss] 0.000236 | [Physics loss] 1.521068 | Val Accuracy: 40.61% | LR: 0.000001563
# Epoch 124 - Train Loss: 0.003555 | Val MSE: 0.000238 | Val MAE: 0.012290 | Val R²: 0.7592 | [Boundary loss] 0.000094 | [Heaters loss] 0.000234 | [Physics loss] 1.519892 | Val Accuracy: 40.76% | LR: 0.000001563
# Epoch 125 - Train Loss: 0.003521 | Val MSE: 0.000244 | Val MAE: 0.012447 | Val R²: 0.7529 | [Boundary loss] 0.000068 | [Heaters loss] 0.000240 | [Physics loss] 1.520928 | Val Accuracy: 40.36% | LR: 0.000001563
# Epoch 126 - Train Loss: 0.003518 | Val MSE: 0.000241 | Val MAE: 0.012411 | Val R²: 0.7554 | [Boundary loss] 0.000134 | [Heaters loss] 0.000239 | [Physics loss] 1.522126 | Val Accuracy: 40.22% | LR: 0.000001563
# Epoch 127 - Train Loss: 0.003520 | Val MSE: 0.000245 | Val MAE: 0.012486 | Val R²: 0.7518 | [Boundary loss] 0.000100 | [Heaters loss] 0.000241 | [Physics loss] 1.519958 | Val Accuracy: 40.17% | LR: 0.000001563
# Epoch 128 - Train Loss: 0.003558 | Val MSE: 0.000238 | Val MAE: 0.012313 | Val R²: 0.7594 | [Boundary loss] 0.000099 | [Heaters loss] 0.000234 | [Physics loss] 1.521547 | Val Accuracy: 40.60% | LR: 0.000001563
# Epoch 129 - Train Loss: 0.003522 | Val MSE: 0.000244 | Val MAE: 0.012452 | Val R²: 0.7524 | [Boundary loss] 0.000073 | [Heaters loss] 0.000240 | [Physics loss] 1.519375 | Val Accuracy: 40.43% | LR: 0.000001563
# Epoch 130 - Train Loss: 0.003534 | Val MSE: 0.000248 | Val MAE: 0.012625 | Val R²: 0.7483 | [Boundary loss] 0.000196 | [Heaters loss] 0.000247 | [Physics loss] 1.524137 | Val Accuracy: 39.22% | LR: 0.000001563
# Epoch 131 - Train Loss: 0.003502 | Val MSE: 0.000238 | Val MAE: 0.012285 | Val R²: 0.7590 | [Boundary loss] 0.000058 | [Heaters loss] 0.000234 | [Physics loss] 1.518548 | Val Accuracy: 40.92% | LR: 0.000001563
# Epoch 132 - Train Loss: 0.003507 | Val MSE: 0.000245 | Val MAE: 0.012494 | Val R²: 0.7513 | [Boundary loss] 0.000076 | [Heaters loss] 0.000241 | [Physics loss] 1.519731 | Val Accuracy: 40.17% | LR: 0.000001563
# Epoch 133 - Train Loss: 0.003547 | Val MSE: 0.000254 | Val MAE: 0.012720 | Val R²: 0.7428 | [Boundary loss] 0.000092 | [Heaters loss] 0.000250 | [Physics loss] 1.522044 | Val Accuracy: 39.39% | LR: 0.000000781
# Epoch 134 - Train Loss: 0.003535 | Val MSE: 0.000246 | Val MAE: 0.012531 | Val R²: 0.7503 | [Boundary loss] 0.000102 | [Heaters loss] 0.000243 | [Physics loss] 1.521203 | Val Accuracy: 39.96% | LR: 0.000000781
# Epoch 135 - Train Loss: 0.003534 | Val MSE: 0.000246 | Val MAE: 0.012493 | Val R²: 0.7510 | [Boundary loss] 0.000074 | [Heaters loss] 0.000242 | [Physics loss] 1.521408 | Val Accuracy: 40.21% | LR: 0.000000781
# Epoch 136 - Train Loss: 0.003511 | Val MSE: 0.000241 | Val MAE: 0.012417 | Val R²: 0.7556 | [Boundary loss] 0.000111 | [Heaters loss] 0.000238 | [Physics loss] 1.521321 | Val Accuracy: 40.18% | LR: 0.000000781
# Epoch 137 - Train Loss: 0.003558 | Val MSE: 0.000230 | Val MAE: 0.012099 | Val R²: 0.7668 | [Boundary loss] 0.000094 | [Heaters loss] 0.000227 | [Physics loss] 1.521638 | Val Accuracy: 41.45% | LR: 0.000000781
# Epoch 138 - Train Loss: 0.003496 | Val MSE: 0.000241 | Val MAE: 0.012401 | Val R²: 0.7553 | [Boundary loss] 0.000115 | [Heaters loss] 0.000238 | [Physics loss] 1.521780 | Val Accuracy: 40.33% | LR: 0.000000781
# Epoch 139 - Train Loss: 0.003550 | Val MSE: 0.000272 | Val MAE: 0.013179 | Val R²: 0.7241 | [Boundary loss] 0.000088 | [Heaters loss] 0.000267 | [Physics loss] 1.522737 | Val Accuracy: 37.97% | LR: 0.000000781
# Epoch 140 - Train Loss: 0.003509 | Val MSE: 0.000257 | Val MAE: 0.012805 | Val R²: 0.7396 | [Boundary loss] 0.000112 | [Heaters loss] 0.000253 | [Physics loss] 1.521413 | Val Accuracy: 39.12% | LR: 0.000000781
# Epoch 141 - Train Loss: 0.003505 | Val MSE: 0.000236 | Val MAE: 0.012243 | Val R²: 0.7605 | [Boundary loss] 0.000059 | [Heaters loss] 0.000232 | [Physics loss] 1.519147 | Val Accuracy: 41.06% | LR: 0.000000781
# Epoch 142 - Train Loss: 0.003514 | Val MSE: 0.000256 | Val MAE: 0.012777 | Val R²: 0.7403 | [Boundary loss] 0.000080 | [Heaters loss] 0.000252 | [Physics loss] 1.520368 | Val Accuracy: 39.31% | LR: 0.000000781
# Epoch 143 - Train Loss: 0.003528 | Val MSE: 0.000243 | Val MAE: 0.012426 | Val R²: 0.7538 | [Boundary loss] 0.000078 | [Heaters loss] 0.000239 | [Physics loss] 1.519418 | Val Accuracy: 40.38% | LR: 0.000000781
# Epoch 144 - Train Loss: 0.003516 | Val MSE: 0.000242 | Val MAE: 0.012406 | Val R²: 0.7546 | [Boundary loss] 0.000085 | [Heaters loss] 0.000238 | [Physics loss] 1.522878 | Val Accuracy: 40.47% | LR: 0.000000391
# Epoch 145 - Train Loss: 0.003517 | Val MSE: 0.000237 | Val MAE: 0.012283 | Val R²: 0.7602 | [Boundary loss] 0.000093 | [Heaters loss] 0.000233 | [Physics loss] 1.523554 | Val Accuracy: 40.75% | LR: 0.000000391
# Epoch 146 - Train Loss: 0.003528 | Val MSE: 0.000236 | Val MAE: 0.012271 | Val R²: 0.7608 | [Boundary loss] 0.000106 | [Heaters loss] 0.000233 | [Physics loss] 1.520324 | Val Accuracy: 40.75% | LR: 0.000000391
# Epoch 147 - Train Loss: 0.003508 | Val MSE: 0.000238 | Val MAE: 0.012316 | Val R²: 0.7590 | [Boundary loss] 0.000097 | [Heaters loss] 0.000235 | [Physics loss] 1.522494 | Val Accuracy: 40.63% | LR: 0.000000391
# Epoch 148 - Train Loss: 0.003522 | Val MSE: 0.000263 | Val MAE: 0.012953 | Val R²: 0.7333 | [Boundary loss] 0.000084 | [Heaters loss] 0.000259 | [Physics loss] 1.521757 | Val Accuracy: 38.65% | LR: 0.000000391
# Epoch 149 - Train Loss: 0.003542 | Val MSE: 0.000240 | Val MAE: 0.012372 | Val R²: 0.7564 | [Boundary loss] 0.000104 | [Heaters loss] 0.000237 | [Physics loss] 1.520849 | Val Accuracy: 40.46% | LR: 0.000000391
# Epoch 150 - Train Loss: 0.003520 | Val MSE: 0.000270 | Val MAE: 0.013125 | Val R²: 0.7261 | [Boundary loss] 0.000090 | [Heaters loss] 0.000266 | [Physics loss] 1.520269 | Val Accuracy: 38.24% | LR: 0.000000391
# Epoch 151 - Train Loss: 0.003511 | Val MSE: 0.000247 | Val MAE: 0.012540 | Val R²: 0.7500 | [Boundary loss] 0.000098 | [Heaters loss] 0.000243 | [Physics loss] 1.523148 | Val Accuracy: 39.93% | LR: 0.000000391
# Epoch 152 - Train Loss: 0.003512 | Val MSE: 0.000264 | Val MAE: 0.013001 | Val R²: 0.7317 | [Boundary loss] 0.000122 | [Heaters loss] 0.000261 | [Physics loss] 1.521202 | Val Accuracy: 38.45% | LR: 0.000000391
# Epoch 153 - Train Loss: 0.003537 | Val MSE: 0.000259 | Val MAE: 0.012852 | Val R²: 0.7367 | [Boundary loss] 0.000079 | [Heaters loss] 0.000255 | [Physics loss] 1.520851 | Val Accuracy: 39.10% | LR: 0.000000391
# Epoch 154 - Train Loss: 0.003520 | Val MSE: 0.000293 | Val MAE: 0.013700 | Val R²: 0.7028 | [Boundary loss] 0.000065 | [Heaters loss] 0.000287 | [Physics loss] 1.519328 | Val Accuracy: 36.52% | LR: 0.000000391
# Epoch 155 - Train Loss: 0.003521 | Val MSE: 0.000242 | Val MAE: 0.012421 | Val R²: 0.7547 | [Boundary loss] 0.000110 | [Heaters loss] 0.000239 | [Physics loss] 1.522230 | Val Accuracy: 40.25% | LR: 0.000000195
# Epoch 156 - Train Loss: 0.003525 | Val MSE: 0.000235 | Val MAE: 0.012230 | Val R²: 0.7620 | [Boundary loss] 0.000088 | [Heaters loss] 0.000231 | [Physics loss] 1.522714 | Val Accuracy: 40.95% | LR: 0.000000195
# Epoch 157 - Train Loss: 0.003521 | Val MSE: 0.000235 | Val MAE: 0.012224 | Val R²: 0.7620 | [Boundary loss] 0.000094 | [Heaters loss] 0.000232 | [Physics loss] 1.521947 | Val Accuracy: 41.03% | LR: 0.000000195
# Epoch 158 - Train Loss: 0.003513 | Val MSE: 0.000239 | Val MAE: 0.012335 | Val R²: 0.7579 | [Boundary loss] 0.000091 | [Heaters loss] 0.000235 | [Physics loss] 1.523271 | Val Accuracy: 40.58% | LR: 0.000000195
# Epoch 159 - Train Loss: 0.003516 | Val MSE: 0.000233 | Val MAE: 0.012182 | Val R²: 0.7637 | [Boundary loss] 0.000078 | [Heaters loss] 0.000230 | [Physics loss] 1.523611 | Val Accuracy: 41.10% | LR: 0.000000195
# Epoch 160 - Train Loss: 0.003524 | Val MSE: 0.000274 | Val MAE: 0.013224 | Val R²: 0.7222 | [Boundary loss] 0.000090 | [Heaters loss] 0.000269 | [Physics loss] 1.522344 | Val Accuracy: 37.85% | LR: 0.000000195
# Epoch 161 - Train Loss: 0.003525 | Val MSE: 0.000234 | Val MAE: 0.012207 | Val R²: 0.7630 | [Boundary loss] 0.000106 | [Heaters loss] 0.000231 | [Physics loss] 1.521086 | Val Accuracy: 40.98% | LR: 0.000000195
# Epoch 162 - Train Loss: 0.003528 | Val MSE: 0.000249 | Val MAE: 0.012587 | Val R²: 0.7474 | [Boundary loss] 0.000072 | [Heaters loss] 0.000245 | [Physics loss] 1.520904 | Val Accuracy: 39.89% | LR: 0.000000195
# Epoch 163 - Train Loss: 0.003540 | Val MSE: 0.000249 | Val MAE: 0.012581 | Val R²: 0.7480 | [Boundary loss] 0.000078 | [Heaters loss] 0.000244 | [Physics loss] 1.523267 | Val Accuracy: 39.88% | LR: 0.000000195
# Epoch 164 - Train Loss: 0.003527 | Val MSE: 0.000241 | Val MAE: 0.012382 | Val R²: 0.7560 | [Boundary loss] 0.000090 | [Heaters loss] 0.000237 | [Physics loss] 1.523225 | Val Accuracy: 40.44% | LR: 0.000000195
# Epoch 165 - Train Loss: 0.003530 | Val MSE: 0.000250 | Val MAE: 0.012606 | Val R²: 0.7469 | [Boundary loss] 0.000083 | [Heaters loss] 0.000246 | [Physics loss] 1.521010 | Val Accuracy: 39.78% | LR: 0.000000195
# Epoch 166 - Train Loss: 0.003501 | Val MSE: 0.000252 | Val MAE: 0.012680 | Val R²: 0.7444 | [Boundary loss] 0.000086 | [Heaters loss] 0.000248 | [Physics loss] 1.524541 | Val Accuracy: 39.48% | LR: 0.000000098
# Epoch 167 - Train Loss: 0.003544 | Val MSE: 0.000245 | Val MAE: 0.012492 | Val R²: 0.7517 | [Boundary loss] 0.000081 | [Heaters loss] 0.000241 | [Physics loss] 1.520446 | Val Accuracy: 40.10% | LR: 0.000000098
# Epoch 168 - Train Loss: 0.003517 | Val MSE: 0.000252 | Val MAE: 0.012658 | Val R²: 0.7447 | [Boundary loss] 0.000076 | [Heaters loss] 0.000248 | [Physics loss] 1.520387 | Val Accuracy: 39.65% | LR: 0.000000098
# Epoch 169 - Train Loss: 0.003502 | Val MSE: 0.000234 | Val MAE: 0.012208 | Val R²: 0.7630 | [Boundary loss] 0.000097 | [Heaters loss] 0.000231 | [Physics loss] 1.521645 | Val Accuracy: 40.98% | LR: 0.000000098
# Epoch 170 - Train Loss: 0.003514 | Val MSE: 0.000266 | Val MAE: 0.013034 | Val R²: 0.7304 | [Boundary loss] 0.000087 | [Heaters loss] 0.000262 | [Physics loss] 1.520136 | Val Accuracy: 38.32% | LR: 0.000000098
# Epoch 171 - Train Loss: 0.003514 | Val MSE: 0.000240 | Val MAE: 0.012363 | Val R²: 0.7570 | [Boundary loss] 0.000085 | [Heaters loss] 0.000236 | [Physics loss] 1.521394 | Val Accuracy: 40.47% | LR: 0.000000098
# Epoch 172 - Train Loss: 0.003531 | Val MSE: 0.000248 | Val MAE: 0.012565 | Val R²: 0.7489 | [Boundary loss] 0.000100 | [Heaters loss] 0.000244 | [Physics loss] 1.522958 | Val Accuracy: 39.89% | LR: 0.000000098
# Epoch 173 - Train Loss: 0.003535 | Val MSE: 0.000233 | Val MAE: 0.012176 | Val R²: 0.7642 | [Boundary loss] 0.000086 | [Heaters loss] 0.000229 | [Physics loss] 1.521180 | Val Accuracy: 41.11% | LR: 0.000000098
# Epoch 174 - Train Loss: 0.003503 | Val MSE: 0.000265 | Val MAE: 0.013018 | Val R²: 0.7306 | [Boundary loss] 0.000100 | [Heaters loss] 0.000262 | [Physics loss] 1.520456 | Val Accuracy: 38.45% | LR: 0.000000098
# Epoch 175 - Train Loss: 0.003526 | Val MSE: 0.000249 | Val MAE: 0.012572 | Val R²: 0.7475 | [Boundary loss] 0.000079 | [Heaters loss] 0.000245 | [Physics loss] 1.519240 | Val Accuracy: 40.04% | LR: 0.000000098
# Epoch 176 - Train Loss: 0.003525 | Val MSE: 0.000236 | Val MAE: 0.012253 | Val R²: 0.7609 | [Boundary loss] 0.000087 | [Heaters loss] 0.000232 | [Physics loss] 1.520649 | Val Accuracy: 40.87% | LR: 0.000000098
# Epoch 177 - Train Loss: 0.003526 | Val MSE: 0.000237 | Val MAE: 0.012289 | Val R²: 0.7597 | [Boundary loss] 0.000092 | [Heaters loss] 0.000234 | [Physics loss] 1.522858 | Val Accuracy: 40.75% | LR: 0.000000049
# Epoch 178 - Train Loss: 0.003518 | Val MSE: 0.000261 | Val MAE: 0.012905 | Val R²: 0.7355 | [Boundary loss] 0.000103 | [Heaters loss] 0.000257 | [Physics loss] 1.521578 | Val Accuracy: 38.80% | LR: 0.000000049
#  Early stopping triggered at epoch 177

# %%
# Cargar el mejor modelo antes de guardar
if best_model_state is not None:
    model.load_state_dict(best_model_state)
else:
    print("Advertencia: No se ha encontrado un modelo mejor durante el entrenamiento.")

# Crear nombre de archivo con los hiperparámetros clave
model_name = (
    f"GAT_Layers_{config['num_layers']}_"
    f"HDim_{config['hidden_dim']}_"
    f"Epochs_{final_epoch}_"
    f"Heads_{config['heads']}_"
    f"Lr_{best_lr:.9f}_"
    f"B_LOSS_{config['use_boundary_loss']}_"
    f"Lambda_{config['lambda_boundary']}_"
    f"H_LOSS_{config['use_heater_loss']}_"
    f"Lambda_{config['lambda_heater']}_"
    f"PI_{config['use_physics']}_"
    f"Lambda_{config['lambda_physics']}_"
    f"Batch_{config['batch_size']}.pth"
)
print("Nombre del modelo:", model_name)
# Out:
# Nombre del modelo: GAT_Layers_3_HDim_128_Epochs_78_Heads_4_Lr_0.000025000_B_LOSS_True_Lambda_1_H_LOSS_True_Lambda_10_PI_True_Lambda_0.0001_Batch_16.pth

# %%
# GRAFICAR MSE
# Crear carpeta si no existe
os.makedirs("LOSS_IMG", exist_ok=True)
loss_img_filename = model_name.replace(".pth", ".svg")
loss_img_path = os.path.join("LOSS_IMG", loss_img_filename)

plt.figure(figsize=(8, 5))
plt.plot(train_losses, label='Train Loss', linewidth=2)
plt.plot(val_losses, label='Val Loss (MSE)', linewidth=2)

# Escala logarítmica en y (opcional)
plt.yscale("log")

plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Evolución del Loss por Época')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Eje X con enteros
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

plt.savefig(loss_img_path, format="svg") 
plt.show()

# %% [markdown]
# ### Carga de modelos ya entrenados

# %%
if config["load_model"]:
    from dataset_utils import load_model_by_name


    # Definir el modelo a cargar, los modelos guardados no guardan la arquitectura de la red
    model = GAT(
        input_dim=config["input_dim"],
        hidden_dim= 64,
        output_dim=config["output_dim"],
        num_layers= 10,
        heads= 8,
        use_dropout=config["use_dropout"],
        dropout_rate=config["dropout_rate"],
        use_batchnorm=config["use_batchnorm"],
        use_residual=config["use_residual"]
    ).to(device)

    # Nombre exacto del archivo que quieres cargar, cambiar solo los números
    model_filename = "GAT_Layers_10_HDim_64_Epochs_1000_Heads_8_Lr_0.001_Batch_32.pth"

    # Cargar modelo concreto
    model = load_model_by_name(model, model_filename)
    print("Modelo cargado:", model_filename)

# %% [markdown]
# ### Evaluación

# %%
# Evaluar en test y graficar un ejemplo
print("Evaluando en test set con visualización de un ejemplo:")
test_mse, test_mae, test_r2, test_accuracy, test_physics, test_boundary, test_heater, test_total_loss = evaluate(
    model, test_loader, device, norm_info, lambda_physics=config["lambda_physics"],
    use_physics=config["use_physics"], lambda_boundary=config["lambda_boundary"],
    use_boundary_loss=config["use_boundary_loss"], lambda_heater=config["lambda_heater"],
    use_heater_loss=config["use_heater_loss"],
    error_threshold=config["error_threshold_K"],
    percentage_threshold=config["percentage_threshold"] if config["use_percentage_threshold"] else None,
    plot_results=True
)

physics_loss_str = f"{test_physics:.6f}" if test_physics is not None else "N/A"

print("Resultados del test:")
print(f"MSE       : {test_mse:.6f}")
print(f"MAE       : {test_mae:.6f}")
print(f"R²        : {test_r2:.4f}")
print(f"Accuracy  : {test_accuracy:.2f}%")
print(f"Boundary Loss  : {test_boundary:.6f}")
print(f"Heaters Loss  : {test_heater:.6f}")
print(f"Physics Loss  : {physics_loss_str}")
# Out:
# Evaluando en test set con visualización de un ejemplo:
# Resultados del test:
# MSE       : 0.000259
# MAE       : 0.012816
# R²        : 0.7279
# Accuracy  : 39.46%
# Boundary Loss  : 0.000103
# Heaters Loss  : 0.000255
# Physics Loss  : 1.499541

# %% [markdown]
# ### GNNExplainer

# %%
from torch_geometric.explain import Explainer, GNNExplainer, ModelConfig

# Poner el modelo en modo evaluación
model.eval()

# Crear el explainer solo una vez
explainer = Explainer(
    model=model,
    algorithm=GNNExplainer(epochs=200),
    explanation_type='model',
    edge_mask_type='object',
    node_mask_type='attributes',
    model_config=ModelConfig(
        mode='regression',
        task_level='node',
        return_type='raw'
    )
)

# ---------------- CONFIGURACIÓN ----------------
graph_idx = 3      # <- Cambia este valor para elegir el grafo del test set
node_idx = 69     # <- Cambia este valor para elegir el nodo a explicar
# ------------------------------------------------

# Obtener el grafo y pasarlo a GPU si es necesario
graph = test_dataset[graph_idx].to(device)

# Predecir con el modelo
with torch.no_grad():
    pred = model(graph.x, graph.edge_index).squeeze()
true = graph.y.squeeze()
error = torch.abs(pred - true)

# Obtener explicación
explanation = explainer(
    x=graph.x,
    edge_index=graph.edge_index,
    index=node_idx
)

# Obtener importancia del explainer y agrupar por nodo
importance = explanation.node_mask.squeeze().cpu()      # Así obtenemos las features por nodo
importance = importance.view(-1, 3)                     # Cambiamos a un tensor que pueda ser interpretado como [num_nodes, num_features]
importance_per_node = importance.mean(dim=1)            # [num_nodes] Hacemos la media de la importancia de las 3 características en la predicción

# Obtener tamaño cuadrícula real del dataset
num_nodes = graph.y.numel()
print("Número de nodos:", num_nodes)
grid_size = int(num_nodes ** 0.5)
assert grid_size ** 2 == num_nodes, f"El número de nodos ({num_nodes}) no coincide con cuadrícula {grid_size}x{grid_size}"

# Convertir vectores a cuadrícula
importance_grid = importance_per_node.view(grid_size, grid_size)
error_grid = error.view(grid_size, grid_size).cpu()

# Visualización
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

im1 = axs[0].imshow(importance_grid, cmap='hot')
# Coordenadas del nodo que estás explicando
row = node_idx // grid_size
col = node_idx % grid_size

# Dibujar un punto rojo en la celda correspondiente
axs[0].plot(col, row, 'o', markersize=10, markeredgecolor='black', markerfacecolor='cyan', label='Nodo explicado')
axs[0].legend(loc='upper right')

axs[0].set_title(f"Importancia (nodo {node_idx})")
plt.colorbar(im1, ax=axs[0])

im2 = axs[1].imshow(error_grid, cmap='Blues')
# Número de nodos a etiquetar
top_n = 5  # "n" nodos de mayor error a mostrar

# Obtener los índices de los nodos con mayor error
top_error_nodes = torch.topk(error, top_n).indices.cpu()

for idx in top_error_nodes:
    idx = idx.item()
    row = idx // grid_size
    col = idx % grid_size
    axs[1].text(
        col, row, str(idx),
        ha='center', va='center',
        fontsize=8, fontweight='bold',
        color='black', bbox=dict(boxstyle='round,pad=0.2', facecolor='white', edgecolor='none', alpha=0.7)
    )
axs[1].set_title("Error absoluto por nodo")
plt.colorbar(im2, ax=axs[1])

plt.suptitle(f"Grafo {graph_idx} | Nodo {node_idx} explicado")
plt.tight_layout()
plt.show()
# Out:
# Número de nodos: 169

# %% [markdown]
# ### Guardado del modelo ya entrenado

# %%
# Crear carpeta si no existe
save_dir = "saved_models"
os.makedirs(save_dir, exist_ok=True)

# Guardar el modelo
model_path = os.path.join(save_dir, model_name)
if config["save_model"]:
    # Guardar el modelo entrenado
    torch.save(model.state_dict(), model_path)

    print(f" Modelo guardado en: {model_path}")
# Out:
#  Modelo guardado en: saved_models\GAT_Layers_3_HDim_128_Epochs_78_Heads_4_Lr_0.000025000_B_LOSS_True_Lambda_1_H_LOSS_True_Lambda_10_PI_True_Lambda_0.0001_Batch_16.pth

# %% [markdown]
# ### Predicción

# %%
fr train_eval import predict
from dataset_utils import load_latest_model
# Cargar el modelo más reciente
model = GAT(
    input_dim=config["input_dim"],
    hidden_dim=config["hidden_dim"],
    output_dim=config["output_dim"],
    num_layers=config["num_layers"],
    heads=config["heads"],
    use_dropout=config["use_dropout"],
    dropout_rate=config["dropout_rate"],
    use_batchnorm=config["use_batchnorm"],
    use_residual=config["use_residual"]
)

model = load_latest_model(model)

# Predecir sobre test
predicciones = predict(model, test_loader)

print("Predicciones shape:", predicciones.shape)
# Out:
#   Cell In[24], line 1
#     fr train_eval import predict
#        ^
# SyntaxError: invalid syntax

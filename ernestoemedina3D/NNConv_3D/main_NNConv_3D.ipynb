# %% [markdown]
# # Importación de librerías

# %%
import torch
import os
import time
import copy
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from NNConv_model import NNConvNet
from train_eval import train, evaluate, EarlyStopping, predict
from Data_loader import load_dataset
from explainer import run_full_gnnexplainer
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Configuración del modelo

# %%
# Configuración del modelo
config = {
    "input_dim": 2,           # 2 canales: Q_heaters, T_env
    "edge_dim": 2,           # Dimensión de los atributos de las aristas (GL, GR )
    "hidden_dim": 64,
    "output_dim": 1,
    "num_layers": 9,
    "use_dropout": True,
    "dropout_rate": 0.0009819658722265943,
    "use_batchnorm": True,
    "use_residual": True,
    "batch_size": 64,
    "edge_attr_type": "edge_attr_norm",  # o "edge_attr_GLAGRA" / "edge_attr_GLAGRA_norm"
    "lr": 0.0016865039968799972,
    "max_epochs": 10000,
    "early_stop_patience": 100,
    "error_threshold_K": 3.0,
    "save_model":   True,
    "load_model": False, # Cargar un modelo preentrenado
    "factor" : 0.5 , # Factor de reducción del learning rate
    "patience" : 10 , # Épocas sin mejora para reducir el learning rate
    "min_lr" : 1e-9,  # evita que baje infinitamente el learning rate
    "use_physics" : False,
    "lambda_physics" : 0.0001, # Peso de la física en la función de pérdida
    "use_heater_loss" : False,
    "lambda_heater" : 1.0,
    "comb_loss_epoch_start": 100
}

# %%
model = NNConvNet(
    input_dim=config["input_dim"],
    edge_dim=config["edge_dim"],
    hidden_dim=config["hidden_dim"],
    output_dim=config["output_dim"],
    num_layers=config["num_layers"],
    use_dropout=config["use_dropout"],
    dropout_rate=config["dropout_rate"],
    use_batchnorm=config["use_batchnorm"],
    use_residual=config["use_residual"]
).to(device)

num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Número total de parámetros entrenables: {num_params}")

optimizer = torch.optim.Adam(model.parameters(), lr=config["lr"])
scheduler = ReduceLROnPlateau(
    optimizer,
    mode='min',            # queremos minimizar el val_loss
    factor=config["factor"],            # reduce a la mitad el LR
    patience=config["patience"],           # espera 10 épocas sin mejora
    verbose=True,          # imprime info cuando reduce
    min_lr=config["min_lr"]            # evita que baje infinitamente
)
# Out:
# Número total de parámetros entrenables: 2178817
# c:\Users\ramse\anaconda3\Lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %% [markdown]
# ## Cargar Dataset

# %%
dataset_path = os.path.join("Datasets3D", "Dataset3D_Uni_10000_model.pth")

train_loader, val_loader, _, norm_info = load_dataset(
    path=dataset_path,
    batch_size=config["batch_size"]
)
# Sobrescribimos el test_loader con batch=1 para evaluación por grafo
_, _, test_loader, _ = load_dataset(
    path=dataset_path,
    batch_size=1
)


print("Dataset loaded successfully.")
print("Number of training samples:", len(train_loader.dataset))

sample = train_loader.dataset[0]
print("Input shape (x):", sample.x.shape)
print("Target shape (y):", sample.y.shape)
print("Edge index shape:", sample.edge_index.shape)
print("Edge attr shape:", sample.edge_attr.shape)

print(f"Max Qi: {norm_info['max_Qi']}, Max T_env: {norm_info['max_T_env']}, Max T_real: {norm_info['max_T_real']}")

# 1) Escala de edge_attr
print("Edge attr min/max:", sample.edge_attr.min(), sample.edge_attr.max())
print("Edge attr std:", sample.edge_attr.std(dim=0))

# 2) Escala de x
print("Node x min/max:", sample.x.min(), sample.x.max())
# Out:
# c:\Users\ramse\Escritorio\Aero Ordenador\4to Aero\2do Cuatri\ia_thermal\ernestoemedina3D\NNConv_3D\Data_loader.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data_bundle = torch.load(path)
# Dataset loaded successfully.
# Number of training samples: 8000
# Input shape (x): torch.Size([34, 2])
# Target shape (y): torch.Size([34, 1])
# Edge index shape: torch.Size([2, 372])
# Edge attr shape: torch.Size([372, 2])
# Max Qi: 14.0, Max T_env: 309.999, Max T_real: 335.65639370660637
# Edge attr min/max: tensor(0.) tensor(147.)
# Edge attr std: tensor([15.5295,  0.7435])
# Node x min/max: tensor(0.) tensor(0.9797)

# %% [markdown]
# ## Evolución del error vs. Tamaño del Dataset

# %%
""" import random
from torch_geometric.loader import DataLoader
# Obtener la lista de grafos completa para submuestreo

data_bundle = torch.load(dataset_path)

# ===  DEFINIR TAMAÑOS A PROBAR ===
dataset_sizes = np.logspace(2, 4, num=6, dtype=int)  # 100 → 10,000
dataset_sizes = np.unique(dataset_sizes)

all_graphs = data_bundle["dataset"]
norm_info = data_bundle["normalization_info"]

print(f"Tamaño total del dataset completo: {len(all_graphs)}")

# ===  DEFINIR TAMAÑOS A PROBAR ===
dataset_sizes = np.logspace(2, 5, num=10, dtype=int)  # 100 a 100,000
dataset_sizes = np.unique(dataset_sizes)

print("\nExplorando influencia del tamaño del dataset en train_loss y val_loss (log scale)...\n")

# ===  ALMACENAR MÉTRICAS ===
train_losses_vs_size = []
val_losses_vs_size = []
train_rmse_real = []
val_rmse_real = []

max_epochs = 100

# ===  BUCLE PRINCIPAL ===
for size in dataset_sizes:
    if size > len(all_graphs):
        print(f"Saltando tamaño {size}: excede el tamaño total del dataset ({len(all_graphs)} muestras)")
        continue

    print(f"\n=== Entrenando con {size} muestras ===")

    # Submuestreo aleatorio
    subset = random.sample(all_graphs, size)
    split_idx = int(0.9 * len(subset))
    train_dataset = subset[:split_idx]
    val_dataset = subset[split_idx:]

    train_loader = DataLoader(train_dataset, batch_size=config["batch_size"], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config["batch_size"], shuffle=False)

    # === Inicializar modelo ===
    model = NNConvNet(
        input_dim=config["input_dim"],
        edge_dim=config["edge_dim"],
        hidden_dim=config["hidden_dim"],
        output_dim=config["output_dim"],
        num_layers=config["num_layers"],
        use_dropout=config["use_dropout"],
        dropout_rate=config["dropout_rate"],
        use_batchnorm=config["use_batchnorm"],
        use_residual=config["use_residual"]
    ).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=config["lr"])

    # === Entrenamiento ===
    train_losses = []
    val_losses = []

    for epoch in range(max_epochs):
        train_loss = train(
            model, train_loader, optimizer, device, norm_info, config,
            use_physics=config["use_physics"], lambda_physics=config["lambda_physics"],
            use_heater_loss=config["use_heater_loss"], lambda_heater=config["lambda_heater"]
        )
        train_losses.append(train_loss)

        val_mse, _, _, _, _, _, _, _, _, _ = evaluate(
            model, val_loader, device, norm_info, config,
            lambda_physics=config["lambda_physics"],
            use_physics=config["use_physics"],
            lambda_heater=config["lambda_heater"],
            use_heater_loss=config["use_heater_loss"],
            error_threshold_K=3.0,
            plot_results=False
        )
        val_losses.append(val_mse)

    # === Guardar métricas ===
    final_train_loss = train_losses[-1]
    final_val_loss = val_losses[-1]

    train_losses_vs_size.append(final_train_loss)
    val_losses_vs_size.append(final_val_loss)

    rmse_train_real = (final_train_loss ** 0.5) * norm_info["max_T_real"]
    rmse_val_real = (final_val_loss ** 0.5) * norm_info["max_T_real"]

    train_rmse_real.append(rmse_train_real)
    val_rmse_real.append(rmse_val_real)

    print(f"Final Train Loss: {final_train_loss:.6f} | Train RMSE real: {rmse_train_real:.4f} K")
    print(f"Final Val Loss  : {final_val_loss:.6f} | Val RMSE real  : {rmse_val_real:.4f} K")

print("\n=== Exploración completada ===") """
# Out:
# ' import random\nfrom torch_geometric.loader import DataLoader\n# Obtener la lista de grafos completa para submuestreo\n\ndata_bundle = torch.load(dataset_path)\n\n# ===  DEFINIR TAMAÑOS A PROBAR ===\ndataset_sizes = np.logspace(2, 4, num=6, dtype=int)  # 100 → 10,000\ndataset_sizes = np.unique(dataset_sizes)\n\nall_graphs = data_bundle["dataset"]\nnorm_info = data_bundle["normalization_info"]\n\nprint(f"Tamaño total del dataset completo: {len(all_graphs)}")\n\n# ===  DEFINIR TAMAÑOS A PROBAR ===\ndataset_sizes = np.logspace(2, 5, num=10, dtype=int)  # 100 a 100,000\ndataset_sizes = np.unique(dataset_sizes)\n\nprint("\nExplorando influencia del tamaño del dataset en train_loss y val_loss (log scale)...\n")\n\n# ===  ALMACENAR MÉTRICAS ===\ntrain_losses_vs_size = []\nval_losses_vs_size = []\ntrain_rmse_real = []\nval_rmse_real = []\n\nmax_epochs = 100\n\n# ===  BUCLE PRINCIPAL ===\nfor size in dataset_sizes:\n    if size > len(all_graphs):\n        print(f"Saltando tamaño {size}: excede el tamaño total del dataset ({len(all_graphs)} muestras)")\n        continue\n\n    print(f"\n=== Entrenando con {size} muestras ===")\n\n    # Submuestreo aleatorio\n    subset = random.sample(all_graphs, size)\n    split_idx = int(0.9 * len(subset))\n    train_dataset = subset[:split_idx]\n    val_dataset = subset[split_idx:]\n\n    train_loader = DataLoader(train_dataset, batch_size=config["batch_size"], shuffle=True)\n    val_loader = DataLoader(val_dataset, batch_size=config["batch_size"], shuffle=False)\n\n    # === Inicializar modelo ===\n    model = NNConvNet(\n        input_dim=config["input_dim"],\n        edge_dim=config["edge_dim"],\n        hidden_dim=config["hidden_dim"],\n        output_dim=config["output_dim"],\n        num_layers=config["num_layers"],\n        use_dropout=config["use_dropout"],\n        dropout_rate=config["dropout_rate"],\n        use_batchnorm=config["use_batchnorm"],\n        use_residual=config["use_residual"]\n    ).to(device)\n\n    optimizer = torch.optim.Adam(model.parameters(), lr=config["lr"])\n\n    # === Entrenamiento ===\n    train_losses = []\n    val_losses = []\n\n    for epoch in range(max_epochs):\n        train_loss = train(\n            model, train_loader, optimizer, device, norm_info, config,\n            use_physics=config["use_physics"], lambda_physics=config["lambda_physics"],\n            use_heater_loss=config["use_heater_loss"], lambda_heater=config["lambda_heater"]\n        )\n        train_losses.append(train_loss)\n\n        val_mse, _, _, _, _, _, _, _ = evaluate(\n            model, val_loader, device, norm_info, config,\n            lambda_physics=config["lambda_physics"],\n            use_physics=config["use_physics"],\n            lambda_heater=config["lambda_heater"],\n            use_heater_loss=config["use_heater_loss"],\n            error_threshold_K=3.0,\n            plot_results=False\n        )\n        val_losses.append(val_mse)\n\n    # === Guardar métricas ===\n    final_train_loss = train_losses[-1]\n    final_val_loss = val_losses[-1]\n\n    train_losses_vs_size.append(final_train_loss)\n    val_losses_vs_size.append(final_val_loss)\n\n    rmse_train_real = (final_train_loss ** 0.5) * norm_info["max_T_real"]\n    rmse_val_real = (final_val_loss ** 0.5) * norm_info["max_T_real"]\n\n    train_rmse_real.append(rmse_train_real)\n    val_rmse_real.append(rmse_val_real)\n\n    print(f"Final Train Loss: {final_train_loss:.6f} | Train RMSE real: {rmse_train_real:.4f} K")\n    print(f"Final Val Loss  : {final_val_loss:.6f} | Val RMSE real  : {rmse_val_real:.4f} K")\n\nprint("\n=== Exploración completada ===") '

# %%
""" 
# === Configuración global ===
plt.style.use('default')
plt.rcParams["figure.figsize"] = (6, 4)
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = 12
plt.rcParams["text.usetex"] = False  # mientras MiKTeX no funcione bien
plt.rcParams["axes.titlesize"] = 17

# === Gráfica 1: Train Loss (MSE, normalizado) ===
fig1, ax1 = plt.subplots(figsize=(8, 5))  # Más ancho localmente
ax1.plot(dataset_sizes[:len(train_losses_vs_size)],
         train_losses_vs_size,
         marker='o', linestyle='-', label="Train Loss (MSE)")
ax1.plot(dataset_sizes[:len(val_losses_vs_size)], val_losses_vs_size, marker='s', linestyle='--', label="Val Loss (MSE)")

ax1.set_xscale('log')
ax1.set_xlabel('Dataset size for training (log scale)')
ax1.set_ylabel('Training loss (MSE, normalized)')
ax1.set_title('Influence of dataset size on training loss (normalized)')
ax1.grid(True, which="both", ls="--")
ax1.legend()
fig1.tight_layout()
plt.show()

# === Gráfica 2: Train RMSE real en Kelvin ===
fig2, ax2 = plt.subplots(figsize=(8, 5))  # Igual de ancho localmente
ax2.plot(dataset_sizes[:len(train_rmse_real)],
         train_rmse_real,
         marker='o', linestyle='-', label="Train RMSE (K)")
ax2.plot(dataset_sizes[:len(val_rmse_real)], val_rmse_real, marker='s', linestyle='--', label="Val RMSE (K)")

ax2.set_xscale('log')
ax2.set_xlabel('Dataset size for training (log scale)')
ax2.set_ylabel('RMSE Error (K)')
ax2.set_title('Training Error in real scale (RMSE in Kelvin)')
ax2.grid(True, which="both", ls="--")
ax2.legend()
fig2.tight_layout()
plt.show()
 """
# Out:
# ' \n# === Configuración global ===\nplt.style.use(\'default\')\nplt.rcParams["figure.figsize"] = (6, 4)\nplt.rcParams["font.family"] = "Times New Roman"\nplt.rcParams["font.size"] = 12\nplt.rcParams["text.usetex"] = False  # mientras MiKTeX no funcione bien\nplt.rcParams["axes.titlesize"] = 17\n\n# === Gráfica 1: Train Loss (MSE, normalizado) ===\nfig1, ax1 = plt.subplots(figsize=(8, 5))  # Más ancho localmente\nax1.plot(dataset_sizes[:len(train_losses_vs_size)],\n         train_losses_vs_size,\n         marker=\'o\', linestyle=\'-\', label="Train Loss (MSE)")\nax1.plot(dataset_sizes[:len(val_losses_vs_size)], val_losses_vs_size, marker=\'s\', linestyle=\'--\', label="Val Loss (MSE)")\n\nax1.set_xscale(\'log\')\nax1.set_xlabel(\'Dataset size for training (log scale)\')\nax1.set_ylabel(\'Training loss (MSE, normalized)\')\nax1.set_title(\'Influence of dataset size on training loss (normalized)\')\nax1.grid(True, which="both", ls="--")\nax1.legend()\nfig1.tight_layout()\nplt.show()\n\n# === Gráfica 2: Train RMSE real en Kelvin ===\nfig2, ax2 = plt.subplots(figsize=(8, 5))  # Igual de ancho localmente\nax2.plot(dataset_sizes[:len(train_rmse_real)],\n         train_rmse_real,\n         marker=\'o\', linestyle=\'-\', label="Train RMSE (K)")\nax2.plot(dataset_sizes[:len(val_rmse_real)], val_rmse_real, marker=\'s\', linestyle=\'--\', label="Val RMSE (K)")\n\nax2.set_xscale(\'log\')\nax2.set_xlabel(\'Dataset size for training (log scale)\')\nax2.set_ylabel(\'RMSE Error (K)\')\nax2.set_title(\'Training Error in real scale (RMSE in Kelvin)\')\nax2.grid(True, which="both", ls="--")\nax2.legend()\nfig2.tight_layout()\nplt.show()\n '

# %% [markdown]
# ## Entrenamiento

# %%
# Entrenamiento
train_losses = []
val_losses = []
epoch_times = []

early_stopper = EarlyStopping(patience=config["early_stop_patience"])
max_epochs = config["max_epochs"]
best_lr=config["lr"]
EPOCH_START = config["comb_loss_epoch_start"] # Época a partir de la cual se aplica la física y heater loss

print("Iniciando entrenamiento...")
for epoch in range(config["max_epochs"]):
    start_time = time.time()
    
    # use_physics = epoch >= EPOCH_START
    # use_heater_loss = epoch >= EPOCH_START
    
    # Entrenar
    train_loss = train(model, train_loader, optimizer, device, norm_info, config, lambda_physics=config["lambda_physics"],
                       use_physics=config['use_physics'], lambda_heater=config["lambda_heater"],
                       use_heater_loss=config["use_heater_loss"],)
    train_losses.append(train_loss)

    # Evaluar en validación
    val_mse, val_mae, val_r2, val_accuracy, val_physics, val_heaters, val_rmse, val_total_loss, val_max_error_K, val_mean_max_error_per_graph_K = evaluate(
        model, val_loader, device, norm_info, config, lambda_physics=config["lambda_physics"],
        use_physics=config["use_physics"], lambda_heater=config["lambda_heater"],
        use_heater_loss=config["use_heater_loss"],
        error_threshold_K=config["error_threshold_K"],
        plot_results=False
    )
    val_losses.append(val_mse)

    scheduler.step(val_mse)
    
    # Medir tiempo transcurrido
    epoch_duration = time.time() - start_time
    epoch_times.append(epoch_duration)

    # Formatear bien los losses opcionales
    physics_loss_str = f"{val_physics:.6f}" if config["use_physics"] else "N/A"
    heaters_loss_str = f"{val_heaters:.6f}" if config["use_heater_loss"] else "N/A"

    # Imprimir métricas
    print(f"Epoch {epoch + 1} - "
          f"Train Loss: {train_loss:.6f} | "
          f"Val MSE: {val_mse:.6f} | "
          f"Val MAE: {val_mae:.6f} | "
          f"Val R²: {val_r2:.4f} | "
          f"[Heaters loss] {heaters_loss_str} | "
          f"[Physics loss] {physics_loss_str} | "
          f"Val Accuracy: {val_accuracy:.2f}% | "
          f"LR: {optimizer.param_groups[0]['lr']:.9f} | "
          f"Time: {epoch_duration:.2f}s")

    # Guardar el mejor modelo en memoria
    if val_total_loss < early_stopper.best_loss:
        best_model_state = copy.deepcopy(model.state_dict())
        final_epoch = epoch + 1
        best_lr = optimizer.param_groups[0]['lr']  # guardar lr actual

    early_stopper(val_total_loss, epoch)
    if early_stopper.early_stop:
        print(f" Early stopping triggered at epoch {epoch}")
        avg_epoch_time = np.mean(epoch_times)
        print(f"Tiempo por época        : {avg_epoch_time:.2f}")
        break
# Out:
# Iniciando entrenamiento...
# Epoch 1 - Train Loss: 0.014051 | Val MSE: 0.003484 | Val MAE: 0.050274 | Val R²: -0.4823 | [Heaters loss] 0.002045 | [Physics loss] N/A | Val Accuracy: 8.80% | LR: 0.001686504 | Time: 22.12s
# Epoch 2 - Train Loss: 0.000289 | Val MSE: 0.000052 | Val MAE: 0.005764 | Val R²: 0.9776 | [Heaters loss] 0.000033 | [Physics loss] N/A | Val Accuracy: 80.57% | LR: 0.001686504 | Time: 19.53s
# Epoch 3 - Train Loss: 0.000196 | Val MSE: 0.000047 | Val MAE: 0.005845 | Val R²: 0.9797 | [Heaters loss] 0.000064 | [Physics loss] N/A | Val Accuracy: 78.83% | LR: 0.001686504 | Time: 19.73s
# Epoch 4 - Train Loss: 0.000178 | Val MSE: 0.000728 | Val MAE: 0.023478 | Val R²: 0.6885 | [Heaters loss] 0.001177 | [Physics loss] N/A | Val Accuracy: 18.50% | LR: 0.001686504 | Time: 19.81s
# Epoch 5 - Train Loss: 0.000198 | Val MSE: 0.000146 | Val MAE: 0.007495 | Val R²: 0.9376 | [Heaters loss] 0.000037 | [Physics loss] N/A | Val Accuracy: 78.55% | LR: 0.001686504 | Time: 19.81s
# Epoch 6 - Train Loss: 0.000167 | Val MSE: 0.000093 | Val MAE: 0.007798 | Val R²: 0.9601 | [Heaters loss] 0.000081 | [Physics loss] N/A | Val Accuracy: 65.85% | LR: 0.001686504 | Time: 19.88s
# Epoch 7 - Train Loss: 0.000150 | Val MSE: 0.000050 | Val MAE: 0.005994 | Val R²: 0.9787 | [Heaters loss] 0.000019 | [Physics loss] N/A | Val Accuracy: 79.33% | LR: 0.001686504 | Time: 19.93s
# Epoch 8 - Train Loss: 0.000177 | Val MSE: 0.000169 | Val MAE: 0.008761 | Val R²: 0.9279 | [Heaters loss] 0.000042 | [Physics loss] N/A | Val Accuracy: 67.11% | LR: 0.001686504 | Time: 19.93s
| Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.97% | LR: 0.000052703 | Time: 20.28s
# Epoch 84 - Train Loss: 0.000024 | Val MSE: 0.000001 | Val MAE: 0.000945 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000052703 | Time: 20.26s
# Epoch 85 - Train Loss: 0.000021 | Val MSE: 0.000001 | Val MAE: 0.000954 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000052703 | Time: 20.23s
# Epoch 86 - Train Loss: 0.000024 | Val MSE: 0.000001 | Val MAE: 0.000784 | Val R²: 0.9995 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000052703 | Time: 20.21s
# Epoch 87 - Train Loss: 0.000022 | Val MSE: 0.000003 | Val MAE: 0.001302 | Val R²: 0.9989 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000052703 | Time: 20.18s
# Epoch 88 - Train Loss: 0.000024 | Val MSE: 0.000001 | Val MAE: 0.000858 | Val R²: 0.9994 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000052703 | Time: 20.15s
# Epoch 89 - Train Loss: 0.000019 | Val MSE: 0.000004 | Val MAE: 0.001811 | Val R²: 0.9983 | [Heaters loss] 0.000003 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000052703 | Time: 20.16s
# Epoch 90 - Train Loss: 0.000026 | Val MSE: 0.000001 | Val MAE: 0.000912 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000052703 | Time: 20.13s
# Epoch 91 - Train Loss: 0.000022 | Val MSE: 0.000004 | Val MAE: 0.001703 | Val R²: 0.9982 | [Heaters loss] 0.000004 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000052703 | Time: 20.11s
# Epoch 92 - Train Loss: 0.000020 | Val MSE: 0.000002 | Val MAE: 0.001120 | Val R²: 0.9992 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000052703 | Time: 20.11s
# Epoch 93 - Train Loss: 0.000024 | Val MSE: 0.000005 | Val MAE: 0.001890 | Val R²: 0.9979 | [Heaters loss] 0.000005 | [Physics loss] N/A | Val Accuracy: 99.89% | LR: 0.000052703 | Time: 20.10s
# Epoch 94 - Train Loss: 0.000022 | Val MSE: 0.000002 | Val MAE: 0.001056 | Val R²: 0.9993 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 99.96% | LR: 0.000052703 | Time: 20.11s
# Epoch 95 - Train Loss: 0.000019 | Val MSE: 0.000002 | Val MAE: 0.001102 | Val R²: 0.9991 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000052703 | Time: 20.10s
# Epoch 96 - Train Loss: 0.000023 | Val MSE: 0.000002 | Val MAE: 0.001079 | Val R²: 0.9992 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000052703 | Time: 20.09s
# Epoch 97 - Train Loss: 0.000022 | Val MSE: 0.000002 | Val MAE: 0.001015 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000026352 | Time: 20.11s
# Epoch 98 - Train Loss: 0.000019 | Val MSE: 0.000001 | Val MAE: 0.000702 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000026352 | Time: 20.10s
# Epoch 99 - Train Loss: 0.000019 | Val MSE: 0.000003 | Val MAE: 0.001336 | Val R²: 0.9988 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000026352 | Time: 20.09s
# Epoch 100 - Train Loss: 0.000017 | Val MSE: 0.000002 | Val MAE: 0.000968 | Val R²: 0.9993 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000026352 | Time: 20.08s
# Epoch 101 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000758 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000026352 | Time: 20.06s
# Epoch 102 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000764 | Val R²: 0.9996 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000026352 | Time: 20.08s
# Epoch 103 - Train Loss: 0.000018 | Val MSE: 0.000001 | Val MAE: 0.000905 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000026352 | Time: 20.05s
# Epoch 104 - Train Loss: 0.000019 | Val MSE: 0.000002 | Val MAE: 0.001115 | Val R²: 0.9991 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000026352 | Time: 20.09s
# Epoch 105 - Train Loss: 0.000020 | Val MSE: 0.000002 | Val MAE: 0.001000 | Val R²: 0.9992 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.94% | LR: 0.000026352 | Time: 20.10s
# Epoch 106 - Train Loss: 0.000021 | Val MSE: 0.000002 | Val MAE: 0.001118 | Val R²: 0.9991 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000026352 | Time: 20.08s
# Epoch 107 - Train Loss: 0.000019 | Val MSE: 0.000001 | Val MAE: 0.000607 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000026352 | Time: 20.08s
# Epoch 108 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000991 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000026352 | Time: 20.08s
# Epoch 109 - Train Loss: 0.000019 | Val MSE: 0.000001 | Val MAE: 0.000725 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.97% | LR: 0.000026352 | Time: 20.11s
# Epoch 110 - Train Loss: 0.000018 | Val MSE: 0.000002 | Val MAE: 0.001116 | Val R²: 0.9992 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000026352 | Time: 20.12s
# Epoch 111 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000725 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000026352 | Time: 20.09s
# Epoch 112 - Train Loss: 0.000018 | Val MSE: 0.000006 | Val MAE: 0.002297 | Val R²: 0.9974 | [Heaters loss] 0.000005 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000026352 | Time: 20.11s
# Epoch 113 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000759 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000026352 | Time: 20.08s
# Epoch 114 - Train Loss: 0.000020 | Val MSE: 0.000001 | Val MAE: 0.000923 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000026352 | Time: 20.09s
# Epoch 115 - Train Loss: 0.000022 | Val MSE: 0.000001 | Val MAE: 0.000868 | Val R²: 0.9995 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000026352 | Time: 20.11s
# Epoch 116 - Train Loss: 0.000018 | Val MSE: 0.000001 | Val MAE: 0.000780 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000026352 | Time: 20.12s
# Epoch 117 - Train Loss: 0.000019 | Val MSE: 0.000003 | Val MAE: 0.001383 | Val R²: 0.9989 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000026352 | Time: 20.13s
# Epoch 118 - Train Loss: 0.000022 | Val MSE: 0.000001 | Val MAE: 0.000722 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000013176 | Time: 20.11s
# Epoch 119 - Train Loss: 0.000018 | Val MSE: 0.000001 | Val MAE: 0.000721 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000013176 | Time: 20.13s
# Epoch 120 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000748 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000013176 | Time: 20.14s
# Epoch 121 - Train Loss: 0.000019 | Val MSE: 0.000001 | Val MAE: 0.000849 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000013176 | Time: 20.10s
# Epoch 122 - Train Loss: 0.000016 | Val MSE: 0.000002 | Val MAE: 0.001019 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000013176 | Time: 20.10s
# Epoch 123 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000643 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000013176 | Time: 20.08s
# Epoch 124 - Train Loss: 0.000018 | Val MSE: 0.000003 | Val MAE: 0.001515 | Val R²: 0.9987 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000013176 | Time: 20.08s
# Epoch 125 - Train Loss: 0.000017 | Val MSE: 0.000002 | Val MAE: 0.001078 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000013176 | Time: 20.10s
# Epoch 126 - Train Loss: 0.000018 | Val MSE: 0.000002 | Val MAE: 0.000999 | Val R²: 0.9993 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000013176 | Time: 20.11s
# Epoch 127 - Train Loss: 0.000015 | Val MSE: 0.000003 | Val MAE: 0.001449 | Val R²: 0.9989 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000013176 | Time: 20.08s
# Epoch 128 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000708 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000013176 | Time: 20.10s
# Epoch 129 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000967 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000006588 | Time: 20.11s
# Epoch 130 - Train Loss: 0.000017 | Val MSE: 0.000002 | Val MAE: 0.000969 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000006588 | Time: 20.13s
# Epoch 131 - Train Loss: 0.000018 | Val MSE: 0.000001 | Val MAE: 0.000737 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000006588 | Time: 20.13s
# Epoch 132 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000687 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000006588 | Time: 20.15s
# Epoch 133 - Train Loss: 0.000015 | Val MSE: 0.000003 | Val MAE: 0.001443 | Val R²: 0.9988 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000006588 | Time: 20.11s
# Epoch 134 - Train Loss: 0.000018 | Val MSE: 0.000001 | Val MAE: 0.000761 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000006588 | Time: 20.13s
# Epoch 135 - Train Loss: 0.000018 | Val MSE: 0.000002 | Val MAE: 0.001047 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000006588 | Time: 20.11s
# Epoch 136 - Train Loss: 0.000014 | Val MSE: 0.000001 | Val MAE: 0.000658 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000006588 | Time: 20.11s
# Epoch 137 - Train Loss: 0.000018 | Val MSE: 0.000001 | Val MAE: 0.000648 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000006588 | Time: 20.13s
# Epoch 138 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000824 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000006588 | Time: 20.11s
# Epoch 139 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000881 | Val R²: 0.9995 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000006588 | Time: 20.12s
# Epoch 140 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000784 | Val R²: 0.9996 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000003294 | Time: 20.12s
# Epoch 141 - Train Loss: 0.000018 | Val MSE: 0.000002 | Val MAE: 0.001065 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000003294 | Time: 20.13s
# Epoch 142 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000708 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000003294 | Time: 20.12s
# Epoch 143 - Train Loss: 0.000015 | Val MSE: 0.000003 | Val MAE: 0.001517 | Val R²: 0.9988 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000003294 | Time: 20.12s
# Epoch 144 - Train Loss: 0.000017 | Val MSE: 0.000002 | Val MAE: 0.001096 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000003294 | Time: 20.10s
# Epoch 145 - Train Loss: 0.000016 | Val MSE: 0.000002 | Val MAE: 0.001110 | Val R²: 0.9992 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000003294 | Time: 20.10s
# Epoch 146 - Train Loss: 0.000016 | Val MSE: 0.000002 | Val MAE: 0.001059 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000003294 | Time: 20.12s
# Epoch 147 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000632 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000003294 | Time: 20.09s
# Epoch 148 - Train Loss: 0.000019 | Val MSE: 0.000001 | Val MAE: 0.000744 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000003294 | Time: 20.06s
# Epoch 149 - Train Loss: 0.000015 | Val MSE: 0.000003 | Val MAE: 0.001457 | Val R²: 0.9988 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000003294 | Time: 20.09s
# Epoch 150 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000709 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000003294 | Time: 20.11s
# Epoch 151 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000716 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000001647 | Time: 20.08s
# Epoch 152 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000982 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000001647 | Time: 20.10s
# Epoch 153 - Train Loss: 0.000020 | Val MSE: 0.000002 | Val MAE: 0.001183 | Val R²: 0.9992 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000001647 | Time: 20.08s
# Epoch 154 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000866 | Val R²: 0.9995 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000001647 | Time: 20.10s
# Epoch 155 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000610 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.97% | LR: 0.000001647 | Time: 20.09s
# Epoch 156 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000817 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000001647 | Time: 20.08s
# Epoch 157 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000757 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000001647 | Time: 20.09s
# Epoch 158 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000956 | Val R²: 0.9994 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000001647 | Time: 20.11s
# Epoch 159 - Train Loss: 0.000014 | Val MSE: 0.000003 | Val MAE: 0.001474 | Val R²: 0.9989 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000001647 | Time: 20.15s
# Epoch 160 - Train Loss: 0.000014 | Val MSE: 0.000001 | Val MAE: 0.001022 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000001647 | Time: 20.13s
# Epoch 161 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000826 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000001647 | Time: 20.08s
# Epoch 162 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000963 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000823 | Time: 20.10s
# Epoch 163 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000585 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000000823 | Time: 20.08s
# Epoch 164 - Train Loss: 0.000017 | Val MSE: 0.000003 | Val MAE: 0.001448 | Val R²: 0.9989 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000823 | Time: 20.08s
# Epoch 165 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000727 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000000823 | Time: 20.08s
# Epoch 166 - Train Loss: 0.000015 | Val MSE: 0.000002 | Val MAE: 0.001301 | Val R²: 0.9991 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000823 | Time: 20.08s
# Epoch 167 - Train Loss: 0.000014 | Val MSE: 0.000001 | Val MAE: 0.000744 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000823 | Time: 20.08s
# Epoch 168 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000595 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000823 | Time: 20.07s
# Epoch 169 - Train Loss: 0.000018 | Val MSE: 0.000001 | Val MAE: 0.000551 | Val R²: 0.9998 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000823 | Time: 20.08s
# Epoch 170 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000739 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000823 | Time: 20.10s
# Epoch 171 - Train Loss: 0.000013 | Val MSE: 0.000001 | Val MAE: 0.000960 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000823 | Time: 20.13s
# Epoch 172 - Train Loss: 0.000017 | Val MSE: 0.000003 | Val MAE: 0.001693 | Val R²: 0.9986 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000823 | Time: 20.11s
# Epoch 173 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000734 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000823 | Time: 20.08s
# Epoch 174 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000607 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000823 | Time: 20.08s
# Epoch 175 - Train Loss: 0.000017 | Val MSE: 0.000002 | Val MAE: 0.001116 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000823 | Time: 20.12s
# Epoch 176 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000968 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000823 | Time: 20.09s
# Epoch 177 - Train Loss: 0.000017 | Val MSE: 0.000004 | Val MAE: 0.001913 | Val R²: 0.9981 | [Heaters loss] 0.000003 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000823 | Time: 20.10s
# Epoch 178 - Train Loss: 0.000019 | Val MSE: 0.000001 | Val MAE: 0.000601 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000000823 | Time: 20.10s
# Epoch 179 - Train Loss: 0.000016 | Val MSE: 0.000002 | Val MAE: 0.001240 | Val R²: 0.9991 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000823 | Time: 20.13s
# Epoch 180 - Train Loss: 0.000016 | Val MSE: 0.000004 | Val MAE: 0.001688 | Val R²: 0.9985 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000412 | Time: 20.11s
# Epoch 181 - Train Loss: 0.000018 | Val MSE: 0.000001 | Val MAE: 0.000891 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000412 | Time: 20.11s
# Epoch 182 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000619 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000412 | Time: 20.08s
# Epoch 183 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000797 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000412 | Time: 20.11s
# Epoch 184 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000957 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000412 | Time: 20.09s
# Epoch 185 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000945 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000412 | Time: 20.06s
# Epoch 186 - Train Loss: 0.000018 | Val MSE: 0.000003 | Val MAE: 0.001417 | Val R²: 0.9989 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000412 | Time: 20.08s
# Epoch 187 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000822 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000412 | Time: 20.10s
# Epoch 188 - Train Loss: 0.000014 | Val MSE: 0.000002 | Val MAE: 0.001112 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000412 | Time: 20.04s
# Epoch 189 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000852 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000412 | Time: 20.06s
# Epoch 190 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000885 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000412 | Time: 20.06s
# Epoch 191 - Train Loss: 0.000014 | Val MSE: 0.000001 | Val MAE: 0.001007 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000206 | Time: 20.03s
# Epoch 192 - Train Loss: 0.000018 | Val MSE: 0.000001 | Val MAE: 0.000752 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000206 | Time: 20.05s
# Epoch 193 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.001024 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000206 | Time: 20.01s
# Epoch 194 - Train Loss: 0.000014 | Val MSE: 0.000001 | Val MAE: 0.000897 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000206 | Time: 20.05s
# Epoch 195 - Train Loss: 0.000016 | Val MSE: 0.000003 | Val MAE: 0.001509 | Val R²: 0.9988 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000206 | Time: 20.05s
# Epoch 196 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000757 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000206 | Time: 20.03s
# Epoch 197 - Train Loss: 0.000014 | Val MSE: 0.000002 | Val MAE: 0.001023 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000206 | Time: 20.05s
# Epoch 198 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000586 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000206 | Time: 20.06s
# Epoch 199 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000637 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000206 | Time: 20.05s
# Epoch 200 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000594 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000000206 | Time: 20.06s
# Epoch 201 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000860 | Val R²: 0.9995 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000206 | Time: 20.08s
# Epoch 202 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000642 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000103 | Time: 20.09s
# Epoch 203 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000895 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000103 | Time: 20.05s
# Epoch 204 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000862 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000103 | Time: 20.06s
# Epoch 205 - Train Loss: 0.000017 | Val MSE: 0.000002 | Val MAE: 0.001054 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000103 | Time: 20.06s
# Epoch 206 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000945 | Val R²: 0.9994 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000103 | Time: 20.06s
# Epoch 207 - Train Loss: 0.000016 | Val MSE: 0.000002 | Val MAE: 0.001350 | Val R²: 0.9990 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000103 | Time: 20.06s
# Epoch 208 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000735 | Val R²: 0.9996 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.97% | LR: 0.000000103 | Time: 20.05s
# Epoch 209 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000654 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000103 | Time: 20.04s
# Epoch 210 - Train Loss: 0.000014 | Val MSE: 0.000001 | Val MAE: 0.000670 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000103 | Time: 20.06s
# Epoch 211 - Train Loss: 0.000019 | Val MSE: 0.000001 | Val MAE: 0.000694 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000000103 | Time: 20.06s
# Epoch 212 - Train Loss: 0.000015 | Val MSE: 0.000002 | Val MAE: 0.001036 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000103 | Time: 20.09s
# Epoch 213 - Train Loss: 0.000017 | Val MSE: 0.000002 | Val MAE: 0.001287 | Val R²: 0.9991 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000051 | Time: 20.10s
# Epoch 214 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000849 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000051 | Time: 20.08s
# Epoch 215 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000602 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000000051 | Time: 20.08s
# Epoch 216 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000634 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000000051 | Time: 20.08s
# Epoch 217 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000871 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000051 | Time: 20.07s
# Epoch 218 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000618 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000051 | Time: 20.06s
# Epoch 219 - Train Loss: 0.000014 | Val MSE: 0.000002 | Val MAE: 0.001063 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000051 | Time: 20.11s
# Epoch 220 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000578 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000051 | Time: 20.13s
# Epoch 221 - Train Loss: 0.000014 | Val MSE: 0.000002 | Val MAE: 0.001336 | Val R²: 0.9990 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000051 | Time: 20.15s
# Epoch 222 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000824 | Val R²: 0.9995 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000051 | Time: 20.09s
# Epoch 223 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000882 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000051 | Time: 20.06s
# Epoch 224 - Train Loss: 0.000015 | Val MSE: 0.000002 | Val MAE: 0.001171 | Val R²: 0.9992 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000026 | Time: 20.08s
# Epoch 225 - Train Loss: 0.000015 | Val MSE: 0.000002 | Val MAE: 0.001172 | Val R²: 0.9992 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000026 | Time: 20.09s
# Epoch 226 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000648 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000026 | Time: 20.10s
# Epoch 227 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000586 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000000026 | Time: 20.06s
# Epoch 228 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000841 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000026 | Time: 20.06s
# Epoch 229 - Train Loss: 0.000014 | Val MSE: 0.000002 | Val MAE: 0.001079 | Val R²: 0.9992 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000026 | Time: 20.06s
# Epoch 230 - Train Loss: 0.000015 | Val MSE: 0.000002 | Val MAE: 0.001129 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000026 | Time: 20.06s
# Epoch 231 - Train Loss: 0.000016 | Val MSE: 0.000002 | Val MAE: 0.001154 | Val R²: 0.9992 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000026 | Time: 20.09s
# Epoch 232 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000806 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000026 | Time: 20.13s
# Epoch 233 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000622 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000026 | Time: 20.13s
# Epoch 234 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000869 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000026 | Time: 20.11s
# Epoch 235 - Train Loss: 0.000018 | Val MSE: 0.000001 | Val MAE: 0.000754 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.16s
# Epoch 236 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000800 | Val R²: 0.9996 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.16s
# Epoch 237 - Train Loss: 0.000018 | Val MSE: 0.000001 | Val MAE: 0.000720 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.11s
# Epoch 238 - Train Loss: 0.000014 | Val MSE: 0.000002 | Val MAE: 0.001248 | Val R²: 0.9991 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.13s
# Epoch 239 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000893 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.13s
# Epoch 240 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000984 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.10s
# Epoch 241 - Train Loss: 0.000014 | Val MSE: 0.000002 | Val MAE: 0.001177 | Val R²: 0.9992 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.08s
# Epoch 242 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000665 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000000013 | Time: 20.08s
# Epoch 243 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000798 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.10s
# Epoch 244 - Train Loss: 0.000017 | Val MSE: 0.000002 | Val MAE: 0.001234 | Val R²: 0.9991 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.09s
# Epoch 245 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000994 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.06s
# Epoch 246 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000617 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.06s
# Epoch 247 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000776 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.11s
# Epoch 248 - Train Loss: 0.000014 | Val MSE: 0.000002 | Val MAE: 0.001292 | Val R²: 0.9990 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.11s
# Epoch 249 - Train Loss: 0.000016 | Val MSE: 0.000002 | Val MAE: 0.001021 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.09s
# Epoch 250 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000868 | Val R²: 0.9995 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.10s
# Epoch 251 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000680 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.10s
# Epoch 252 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000730 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.08s
# Epoch 253 - Train Loss: 0.000015 | Val MSE: 0.000001 | Val MAE: 0.000674 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.10s
# Epoch 254 - Train Loss: 0.000015 | Val MSE: 0.000002 | Val MAE: 0.001078 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.11s
# Epoch 255 - Train Loss: 0.000016 | Val MSE: 0.000003 | Val MAE: 0.001504 | Val R²: 0.9988 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.09s
# Epoch 256 - Train Loss: 0.000017 | Val MSE: 0.000002 | Val MAE: 0.001270 | Val R²: 0.9991 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.11s
# Epoch 257 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000632 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.13s
# Epoch 258 - Train Loss: 0.000015 | Val MSE: 0.000003 | Val MAE: 0.001542 | Val R²: 0.9988 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.14s
# Epoch 259 - Train Loss: 0.000014 | Val MSE: 0.000001 | Val MAE: 0.000822 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.16s
# Epoch 260 - Train Loss: 0.000014 | Val MSE: 0.000001 | Val MAE: 0.000921 | Val R²: 0.9994 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.14s
# Epoch 261 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000636 | Val R²: 0.9997 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.98% | LR: 0.000000013 | Time: 20.15s
# Epoch 262 - Train Loss: 0.000017 | Val MSE: 0.000001 | Val MAE: 0.000835 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.16s
# Epoch 263 - Train Loss: 0.000016 | Val MSE: 0.000001 | Val MAE: 0.000812 | Val R²: 0.9996 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.15s
# Epoch 264 - Train Loss: 0.000019 | Val MSE: 0.000002 | Val MAE: 0.001053 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.14s
# Epoch 265 - Train Loss: 0.000016 | Val MSE: 0.000002 | Val MAE: 0.001168 | Val R²: 0.9992 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.10s
# Epoch 266 - Train Loss: 0.000017 | Val MSE: 0.000002 | Val MAE: 0.001124 | Val R²: 0.9993 | [Heaters loss] 0.000001 | [Physics loss] N/A | Val Accuracy: 99.99% | LR: 0.000000013 | Time: 20.13s
# Epoch 267 - Train Loss: 0.000014 | Val MSE: 0.000001 | Val MAE: 0.000813 | Val R²: 0.9995 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.11s
# Epoch 268 - Train Loss: 0.000018 | Val MSE: 0.000001 | Val MAE: 0.000784 | Val R²: 0.9996 | [Heaters loss] 0.000000 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.10s
# Epoch 269 - Train Loss: 0.000017 | Val MSE: 0.000002 | Val MAE: 0.001373 | Val R²: 0.9990 | [Heaters loss] 0.000002 | [Physics loss] N/A | Val Accuracy: 100.00% | LR: 0.000000013 | Time: 20.06s
#  Early stopping triggered at epoch 268
# Tiempo por época        : 20.13

# %% [markdown]
# ### Revisión del output por nodo:

# %%
# x = sample.x.to(device)
# edge_index = sample.edge_index.to(device)
# edge_attr = sample.edge_attr.to(device)
# print("Out example:", model(x, edge_index, edge_attr).detach())

# %%
# Cargar el mejor modelo antes de guardar
if best_model_state is not None:
    model.load_state_dict(best_model_state)
else:
    print("Advertencia: No se ha encontrado un modelo mejor durante el entrenamiento.")

# Crear nombre de archivo con los hiperparámetros clave
model_name = (
    f"3D_NNConv_Layers_{config['num_layers']}_"
    f"HDim_{config['hidden_dim']}_"
    f"Epochs_{final_epoch}_"
    f"Lr_{best_lr:.9f}_"
    f"H_LOSS_{config['use_heater_loss']}_"
    f"Lambda_{config['lambda_heater']}_"
    f"PI_{config['use_physics']}_"
    f"Lambda_{config['lambda_physics']}_"
    f"Batch_{config['batch_size']}.pth"
)
print("Nombre del modelo:", model_name)
# Out:
# Nombre del modelo: 3D_NNConv_Layers_9_HDim_64_Epochs_169_Lr_0.000000823_H_LOSS_True_Lambda_1.0_PI_False_Lambda_0.0001_Batch_64.pth

# %%
# === Configuración de estilo LaTeX ===
plt.style.use('default')
plt.rcParams.update({
    "figure.figsize": (6, 4),
    "font.family": "serif",
    "font.size": 12,
    "text.usetex": True,
    "axes.titlesize": 11
})

# === Crear carpeta para guardar ===
os.makedirs("LOSS_IMG", exist_ok=True)
loss_img_filename = model_name.replace(".pth", ".svg")
loss_img_path = os.path.join("LOSS_IMG", loss_img_filename)

# === Gráfico ===
plt.figure()
plt.plot(train_losses, label=r'\textbf{Train Loss}', linewidth=2)
plt.plot(val_losses, label=r'\textbf{Validation Loss}', linewidth=2)

plt.yscale("log")
plt.xlabel(r'\textbf{Epoch}')
plt.ylabel(r'\textbf{MSE Loss}')
plt.title(r'\textbf{Loss evolution over epochs}')
plt.legend()
plt.grid(True)
plt.tight_layout()

ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

plt.savefig(loss_img_path, format="svg")
plt.show()

# %% [markdown]
# ## Carga de un modelo

# %%
if config["load_model"]:
    from Data_loader import load_model_by_name
    
    model_filename = "3D_NNConv_Layers_9_HDim_64_Epochs_194_Lr_0.000000206_H_LOSS_False_Lambda_1.0_PI_False_Lambda_0.0001_Batch_64.pth"
    model = load_model_by_name(model, model_filename)
    print("Modelo cargado:", model_filename)
# Out:
# Modelo cargado desde: saved_models\3D_NNConv_Layers_9_HDim_64_Epochs_194_Lr_0.000000206_H_LOSS_False_Lambda_1.0_PI_False_Lambda_0.0001_Batch_64.pth
# Modelo cargado: 3D_NNConv_Layers_9_HDim_64_Epochs_194_Lr_0.000000206_H_LOSS_False_Lambda_1.0_PI_False_Lambda_0.0001_Batch_64.pth
# c:\Users\ramse\Escritorio\Aero Ordenador\4to Aero\2do Cuatri\ia_thermal\ernestoemedina3D\NNConv_3D\Data_loader.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))

# %% [markdown]
# ## Evaluación

# %%
# Evaluar en test y graficar un ejemplo
print("Evaluando en test set con visualización de un ejemplo:")
test_mse, test_mae, test_r2, test_accuracy, test_physics, test_heater, test_rmse, test_total_loss, max_error_K, mean_max_error_per_graph_K = evaluate(
    model, test_loader, device, norm_info, config, lambda_physics=config["lambda_physics"],
    use_physics=config["use_physics"], lambda_heater=config["lambda_heater"],
    use_heater_loss=config["use_heater_loss"],
    error_threshold_K=config["error_threshold_K"],
    plot_results=True
)

preds, targets = predict(model, test_loader, device, norm_info, config)
plt.figure()
plt.scatter(targets.numpy(), preds.numpy(), alpha=0.4)
plt.plot([0, 1], [0, 1], 'r--')
plt.xlabel("Target (normalized)")
plt.ylabel("Prediction (normalized)")
plt.grid(True)


physics_loss_str = f"{test_physics:.6f}" if test_physics is not None else "N/A"

max_T_real = norm_info["max_T_real"]
mae_K = test_mae * max_T_real
rmse_K = test_rmse * (max_T_real)
mse_K = test_mse * (max_T_real ** 2)
print(f"MAE en Kelvin     : {mae_K:.3f} K")
print(f"RMSE en Kelvin    : {rmse_K:.3f} K")
print(f"MSE en Kelvin²    : {mse_K:.3f} K²")
print(f"Error máximo absoluto     : {max_error_K:.3f} K")
print(f"Promedio de errores máximos por grafo: {mean_max_error_per_graph_K:.3f} K")

h_loss = test_heater * (max_T_real**2)

print("Resultados del test:")
print(f"MSE       : {test_mse:.6f}")
print(f"MAE       : {test_mae:.6f}")
print(f"R²        : {test_r2:.4f}")
print(f"Accuracy  : {test_accuracy:.2f}%")
print(f"Heaters Loss  : {h_loss:.6f}K²")
print(f"Physics Loss  : {physics_loss_str}W²")
# Out:
# Evaluando en test set con visualización de un ejemplo:
# Grafo 0: Data(x=[34, 2], edge_index=[2, 372], edge_attr=[372, 2], y=[34, 1], edge_attr_GLAGRA=[372, 2], edge_attr_norm=[372, 2], edge_attr_GLAGRA_norm=[372, 2], external_ids=[34], area=[34])
# MAE en Kelvin     : 0.179 K
# RMSE en Kelvin    : 0.226 K
# MSE en Kelvin²    : 0.056 K²
# Error máximo absoluto     : 2.127 K
# Promedio de errores máximos por grafo: 0.579 K
# Resultados del test:
# MSE       : 0.000000
# MAE       : 0.000533
# R²        : 0.9994
# Accuracy  : 100.00%
# Heaters Loss  : 0.000000K²
# Physics Loss  : 0.000000W²

# %% [markdown]
# ## Guardado del mejor modelo

# %%
# Crear carpeta si no existe
save_dir = "saved_models"
os.makedirs(save_dir, exist_ok=True)

# Guardar el modelo
model_path = os.path.join(save_dir, model_name)
if config["save_model"]:
    # Guardar el modelo entrenado
    torch.save(model.state_dict(), model_path)

    print(f" Modelo guardado en: {model_path}")
# Out:
#  Modelo guardado en: saved_models\3D_NNConv_Layers_9_HDim_64_Epochs_169_Lr_0.000000823_H_LOSS_True_Lambda_1.0_PI_False_Lambda_0.0001_Batch_64.pth

# %% [markdown]
# ## GNNExplainer

# %%
run_full_gnnexplainer(model, test_loader.dataset, graph_idx=0, target_node_idx=30, norm_info=norm_info, device=device)
# Out:
# data.x.shape = torch.Size([34, 2])
# data.edge_index.max() = 33
# data.num_nodes = 34

# %% [markdown]
# # Importación de librerías

# %%
import torch
import os
import time
import copy
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from GAT_model import GAT
from train_eval import train, evaluate, EarlyStopping, predict
from Data_loader import load_dataset
from explainer import run_full_gnnexplainer
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Configuración del modelo

# %%
# Configuración del modelo
config = {
    "input_dim": 2,           # 2 canales: Q_heaters, T_env
    "hidden_dim": 32,
    "output_dim": 1,
    "num_layers": 4,
    "heads": 2,          # Número de cabezas de atención
    "use_dropout": True,
    "dropout_rate": 0.00484428949335922,
    "use_batchnorm": True,
    "use_residual": True,
    "batch_size": 16,
    "lr": 0.0014692511249977897,
    "max_epochs": 10000,
    "early_stop_patience": 100,
    "error_threshold_K": 3.0,
    "save_model": True,
    "load_model": False, # Cargar un modelo preentrenado
    "factor" : 0.5 , # Factor de reducción del learning rate
    "patience" : 10 , # Épocas sin mejora para reducir el learning rate
    "min_lr" : 1e-9,  # evita que baje infinitamente el learning rate
    "use_physics" : False, # No usar por ahora, hay un error en la implementación
    "lambda_physics" : 0.0001, # Peso de la física en la función de pérdida
    "use_heater_loss" : False,
    "lambda_heater" : 1.0,
    "comb_loss_epoch_start" : 50 # Épocas a partir de las cuales se combina la pérdida física y de los heaters con la de error
}

# %%
model = GAT(
    input_dim=config["input_dim"],
    hidden_dim=config["hidden_dim"],
    output_dim=config["output_dim"],
    num_layers=config["num_layers"],
    heads=config["heads"],
    use_dropout=config["use_dropout"],
    dropout_rate=config["dropout_rate"],
    use_batchnorm=config["use_batchnorm"],
    use_residual=config["use_residual"]
).to(device)

num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Número total de parámetros entrenables: {num_params}")

optimizer = torch.optim.Adam(model.parameters(), lr=config["lr"])
scheduler = ReduceLROnPlateau(
    optimizer,
    mode='min',            # queremos minimizar el val_loss
    factor=config["factor"],            # reduce a la mitad el LR
    patience=config["patience"],           # espera 10 épocas sin mejora
    verbose=True,          # imprime info cuando reduce
    min_lr=config["min_lr"]            # evita que baje infinitamente
)
# Out:
# Número total de parámetros entrenables: 9347
# c:\Users\ramse\anaconda3\Lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %% [markdown]
# ## Cargar Dataset

# %%
dataset_path = os.path.join("Datasets3D", "Dataset3D_Uni_10000_model.pth")

train_loader, val_loader, _, norm_info = load_dataset(
    path=dataset_path,
    batch_size=config["batch_size"]
)
# Sobrescribimos el test_loader con batch=1 para evaluación por grafo
_, _, test_loader, _ = load_dataset(
    path=dataset_path,
    batch_size=1
)

print("Dataset loaded successfully.")
print("Number of training samples:", len(train_loader.dataset))

sample = train_loader.dataset[0]
print("Input shape (x):", sample.x.shape)
print("Target shape (y):", sample.y.shape)
print("Edge index shape:", sample.edge_index.shape)
print("Edge attr shape:", sample.edge_attr.shape)

print(f"Max Qi: {norm_info['max_Qi']}, Max T_env: {norm_info['max_T_env']}, Max T_real: {norm_info['max_T_real']}")



# 1) Escala de x
print("Node x min/max:", sample.x.min(), sample.x.max())

# 2) Activación final
# x = sample.x.to(device)
# edge_index = sample.edge_index.to(device)
# print("Out example:", model(x, edge_index).detach())
# Out:
# c:\Users\ramse\Escritorio\Aero Ordenador\4to Aero\2do Cuatri\ia_thermal\ernestoemedina3D\GAT_3D\Data_loader.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data_bundle = torch.load(path)
# Dataset loaded successfully.
# Number of training samples: 8000
# Input shape (x): torch.Size([34, 2])
# Target shape (y): torch.Size([34, 1])
# Edge index shape: torch.Size([2, 372])
# Edge attr shape: torch.Size([372, 2])
# Max Qi: 14.0, Max T_env: 309.999, Max T_real: 335.65639370660637
# Node x min/max: tensor(0.) tensor(0.9797)

# %% [markdown]
# ## Evolución del error vs. Tamaño del Dataset

# %%
""" import random
from torch_geometric.loader import DataLoader
# Obtener la lista de grafos completa para submuestreo

data_bundle = torch.load(dataset_path)

# ===  DEFINIR TAMAÑOS A PROBAR ===
dataset_sizes = np.logspace(2, 4, num=6, dtype=int)  # 100 → 10,000
dataset_sizes = np.unique(dataset_sizes)

all_graphs = data_bundle["dataset"]
norm_info = data_bundle["normalization_info"]

print(f"Tamaño total del dataset completo: {len(all_graphs)}")

# ===  DEFINIR TAMAÑOS A PROBAR ===
dataset_sizes = np.logspace(2, 5, num=10, dtype=int)  # 100 a 100,000
dataset_sizes = np.unique(dataset_sizes)

print("\nExplorando influencia del tamaño del dataset en train_loss y val_loss (log scale)...\n")

# ===  ALMACENAR MÉTRICAS ===
train_losses_vs_size = []
val_losses_vs_size = []
train_rmse_real = []
val_rmse_real = []

max_epochs = 100

# ===  BUCLE PRINCIPAL ===
for size in dataset_sizes:
    if size > len(all_graphs):
        print(f"Saltando tamaño {size}: excede el tamaño total del dataset ({len(all_graphs)} muestras)")
        continue

    print(f"\n=== Entrenando con {size} muestras ===")

    # Submuestreo aleatorio
    subset = random.sample(all_graphs, size)
    split_idx = int(0.9 * len(subset))
    train_dataset = subset[:split_idx]
    val_dataset = subset[split_idx:]

    train_loader = DataLoader(train_dataset, batch_size=config["batch_size"], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config["batch_size"], shuffle=False)

    # === Inicializar modelo ===
    model = GAT(
        input_dim=config["input_dim"],
        hidden_dim=config["hidden_dim"],
        output_dim=config["output_dim"],
        num_layers=config["num_layers"],
        heads=config["heads"],
        use_dropout=config["use_dropout"],
        dropout_rate=config["dropout_rate"],
        use_batchnorm=config["use_batchnorm"],
        use_residual=config["use_residual"]
    ).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=config["lr"])

    # === Entrenamiento ===
    train_losses = []
    val_losses = []

    for epoch in range(max_epochs):
        train_loss = train(
            model, train_loader, optimizer, device, norm_info,
            use_physics=config["use_physics"], lambda_physics=config["lambda_physics"],
            use_heater_loss=config["use_heater_loss"], lambda_heater=config["lambda_heater"]
        )
        train_losses.append(train_loss)

        val_mse, _, _, _, _, _, _, _, _, _ = evaluate(
            model, val_loader, device, norm_info,
            lambda_physics=config["lambda_physics"],
            use_physics=config["use_physics"],
            lambda_heater=config["lambda_heater"],
            use_heater_loss=config["use_heater_loss"],
            error_threshold_K=3.0,
            plot_results=False
        )
        val_losses.append(val_mse)

    # === Guardar métricas ===
    final_train_loss = train_losses[-1]
    final_val_loss = val_losses[-1]

    train_losses_vs_size.append(final_train_loss)
    val_losses_vs_size.append(final_val_loss)

    rmse_train_real = (final_train_loss ** 0.5) * norm_info["max_T_real"]
    rmse_val_real = (final_val_loss ** 0.5) * norm_info["max_T_real"]

    train_rmse_real.append(rmse_train_real)
    val_rmse_real.append(rmse_val_real)

    print(f"Final Train Loss: {final_train_loss:.6f} | Train RMSE real: {rmse_train_real:.4f} K")
    print(f"Final Val Loss  : {final_val_loss:.6f} | Val RMSE real  : {rmse_val_real:.4f} K")

print("\n=== Exploración completada ===") """
# Out:
# ' import random\nfrom torch_geometric.loader import DataLoader\n# Obtener la lista de grafos completa para submuestreo\n\ndata_bundle = torch.load(dataset_path)\n\n# ===  DEFINIR TAMAÑOS A PROBAR ===\ndataset_sizes = np.logspace(2, 4, num=6, dtype=int)  # 100 → 10,000\ndataset_sizes = np.unique(dataset_sizes)\n\nall_graphs = data_bundle["dataset"]\nnorm_info = data_bundle["normalization_info"]\n\nprint(f"Tamaño total del dataset completo: {len(all_graphs)}")\n\n# ===  DEFINIR TAMAÑOS A PROBAR ===\ndataset_sizes = np.logspace(2, 5, num=10, dtype=int)  # 100 a 100,000\ndataset_sizes = np.unique(dataset_sizes)\n\nprint("\nExplorando influencia del tamaño del dataset en train_loss y val_loss (log scale)...\n")\n\n# ===  ALMACENAR MÉTRICAS ===\ntrain_losses_vs_size = []\nval_losses_vs_size = []\ntrain_rmse_real = []\nval_rmse_real = []\n\nmax_epochs = 100\n\n# ===  BUCLE PRINCIPAL ===\nfor size in dataset_sizes:\n    if size > len(all_graphs):\n        print(f"Saltando tamaño {size}: excede el tamaño total del dataset ({len(all_graphs)} muestras)")\n        continue\n\n    print(f"\n=== Entrenando con {size} muestras ===")\n\n    # Submuestreo aleatorio\n    subset = random.sample(all_graphs, size)\n    split_idx = int(0.9 * len(subset))\n    train_dataset = subset[:split_idx]\n    val_dataset = subset[split_idx:]\n\n    train_loader = DataLoader(train_dataset, batch_size=config["batch_size"], shuffle=True)\n    val_loader = DataLoader(val_dataset, batch_size=config["batch_size"], shuffle=False)\n\n    # === Inicializar modelo ===\n    model = GAT(\n        input_dim=config["input_dim"],\n        hidden_dim=config["hidden_dim"],\n        output_dim=config["output_dim"],\n        num_layers=config["num_layers"],\n        heads=config["heads"],\n        use_dropout=config["use_dropout"],\n        dropout_rate=config["dropout_rate"],\n        use_batchnorm=config["use_batchnorm"],\n        use_residual=config["use_residual"]\n    ).to(device)\n\n    optimizer = torch.optim.Adam(model.parameters(), lr=config["lr"])\n\n    # === Entrenamiento ===\n    train_losses = []\n    val_losses = []\n\n    for epoch in range(max_epochs):\n        train_loss = train(\n            model, train_loader, optimizer, device, norm_info,\n            use_physics=config["use_physics"], lambda_physics=config["lambda_physics"],\n            use_heater_loss=config["use_heater_loss"], lambda_heater=config["lambda_heater"]\n        )\n        train_losses.append(train_loss)\n\n        val_mse, _, _, _, _, _, _, _, _, _ = evaluate(\n            model, val_loader, device, norm_info,\n            lambda_physics=config["lambda_physics"],\n            use_physics=config["use_physics"],\n            lambda_heater=config["lambda_heater"],\n            use_heater_loss=config["use_heater_loss"],\n            error_threshold_K=3.0,\n            plot_results=False\n        )\n        val_losses.append(val_mse)\n\n    # === Guardar métricas ===\n    final_train_loss = train_losses[-1]\n    final_val_loss = val_losses[-1]\n\n    train_losses_vs_size.append(final_train_loss)\n    val_losses_vs_size.append(final_val_loss)\n\n    rmse_train_real = (final_train_loss ** 0.5) * norm_info["max_T_real"]\n    rmse_val_real = (final_val_loss ** 0.5) * norm_info["max_T_real"]\n\n    train_rmse_real.append(rmse_train_real)\n    val_rmse_real.append(rmse_val_real)\n\n    print(f"Final Train Loss: {final_train_loss:.6f} | Train RMSE real: {rmse_train_real:.4f} K")\n    print(f"Final Val Loss  : {final_val_loss:.6f} | Val RMSE real  : {rmse_val_real:.4f} K")\n\nprint("\n=== Exploración completada ===") '

# %%
""" 
# === Configuración global ===
plt.style.use('default')
plt.rcParams["figure.figsize"] = (6, 4)
plt.rcParams["font.family"] = "Serif"
plt.rcParams["font.size"] = 12
plt.rcParams["text.usetex"] = False  # mientras MiKTeX no funcione bien
plt.rcParams["axes.titlesize"] = 17

# === Gráfica 1: Train Loss (MSE, normalizado) ===
fig1, ax1 = plt.subplots(figsize=(8, 5))  # Más ancho localmente
ax1.plot(dataset_sizes[:len(train_losses_vs_size)],
         train_losses_vs_size,
         marker='o', linestyle='-', label="Train Loss (MSE)")
ax1.plot(dataset_sizes[:len(val_losses_vs_size)], val_losses_vs_size, marker='s', linestyle='--', label="Val Loss (MSE)")

ax1.set_xscale('log')
ax1.set_xlabel('Dataset size for training (log scale)')
ax1.set_ylabel('Training loss (MSE, normalized)')
ax1.set_title('Influence of dataset size on training loss (normalized)')
ax1.grid(True, which="both", ls="--")
ax1.legend()
fig1.tight_layout()
plt.show()

# === Gráfica 2: Train RMSE real en Kelvin ===
fig2, ax2 = plt.subplots(figsize=(8, 5))  # Igual de ancho localmente
ax2.plot(dataset_sizes[:len(train_rmse_real)],
         train_rmse_real,
         marker='o', linestyle='-', label="Train RMSE (K)")
ax2.plot(dataset_sizes[:len(val_rmse_real)], val_rmse_real, marker='s', linestyle='--', label="Val RMSE (K)")

ax2.set_xscale('log')
ax2.set_xlabel('Dataset size for training (log scale)')
ax2.set_ylabel('RMSE Error (K)')
ax2.set_title('Training Error in real scale (RMSE in Kelvin)')
ax2.grid(True, which="both", ls="--")
ax2.legend()
fig2.tight_layout()
plt.show()
 """
# Out:
# ' \n# === Configuración global ===\nplt.style.use(\'default\')\nplt.rcParams["figure.figsize"] = (6, 4)\nplt.rcParams["font.family"] = "Serif"\nplt.rcParams["font.size"] = 12\nplt.rcParams["text.usetex"] = False  # mientras MiKTeX no funcione bien\nplt.rcParams["axes.titlesize"] = 17\n\n# === Gráfica 1: Train Loss (MSE, normalizado) ===\nfig1, ax1 = plt.subplots(figsize=(8, 5))  # Más ancho localmente\nax1.plot(dataset_sizes[:len(train_losses_vs_size)],\n         train_losses_vs_size,\n         marker=\'o\', linestyle=\'-\', label="Train Loss (MSE)")\nax1.plot(dataset_sizes[:len(val_losses_vs_size)], val_losses_vs_size, marker=\'s\', linestyle=\'--\', label="Val Loss (MSE)")\n\nax1.set_xscale(\'log\')\nax1.set_xlabel(\'Dataset size for training (log scale)\')\nax1.set_ylabel(\'Training loss (MSE, normalized)\')\nax1.set_title(\'Influence of dataset size on training loss (normalized)\')\nax1.grid(True, which="both", ls="--")\nax1.legend()\nfig1.tight_layout()\nplt.show()\n\n# === Gráfica 2: Train RMSE real en Kelvin ===\nfig2, ax2 = plt.subplots(figsize=(8, 5))  # Igual de ancho localmente\nax2.plot(dataset_sizes[:len(train_rmse_real)],\n         train_rmse_real,\n         marker=\'o\', linestyle=\'-\', label="Train RMSE (K)")\nax2.plot(dataset_sizes[:len(val_rmse_real)], val_rmse_real, marker=\'s\', linestyle=\'--\', label="Val RMSE (K)")\n\nax2.set_xscale(\'log\')\nax2.set_xlabel(\'Dataset size for training (log scale)\')\nax2.set_ylabel(\'RMSE Error (K)\')\nax2.set_title(\'Training Error in real scale (RMSE in Kelvin)\')\nax2.grid(True, which="both", ls="--")\nax2.legend()\nfig2.tight_layout()\nplt.show()\n '

# %% [markdown]
# ## Entrenamiento

# %%
# Entrenamiento
train_losses = []
val_losses = []
epoch_times = []

early_stopper = EarlyStopping(patience=config["early_stop_patience"])
max_epochs = config["max_epochs"]
best_lr=config["lr"]

# EPOCH_START = config["comb_loss_epoch_start"] # Época a partir de la cual se aplica la física y heater loss

print("Iniciando entrenamiento...")
for epoch in range(config["max_epochs"]):
    start_time = time.time()
    
    # use_physics = epoch >= EPOCH_START
    # use_heater_loss = epoch >= EPOCH_START
    
    # Entrenar
    train_loss = train(model, train_loader, optimizer, device, norm_info, lambda_physics=config["lambda_physics"],
                       use_physics=config['use_physics'], lambda_heater=config["lambda_heater"],
                       use_heater_loss=config['use_heater_loss'],)
    train_losses.append(train_loss)

    # Evaluar en validación
    val_mse, val_mae, val_r2, val_accuracy, val_physics, val_heaters, val_rmse, val_total_loss, val_max_error_K, val_mean_max_error_per_graph_K = evaluate(
        model, val_loader, device, norm_info, lambda_physics=config["lambda_physics"],
        use_physics=config["use_physics"], lambda_heater=config["lambda_heater"],
        use_heater_loss=config["use_heater_loss"],
        error_threshold_K=config["error_threshold_K"],
        plot_results=False
    )
    val_losses.append(val_mse)

    scheduler.step(val_mse)
    
    # Medir tiempo transcurrido
    epoch_duration = time.time() - start_time
    epoch_times.append(epoch_duration)

    # Formatear bien los losses opcionales
    physics_loss_str = f"{val_physics:.6f}" if config["use_physics"] else "N/A"
    heaters_loss_str = f"{val_heaters:.6f}" if config["use_heater_loss"] else "N/A"

    # Imprimir métricas
    print(f"Epoch {epoch + 1} - "
          f"Train Loss: {train_loss:.6f} | "
          f"Val MSE: {val_mse:.6f} | "
          f"Val MAE: {val_mae:.6f} | "
          f"Val R²: {val_r2:.4f} | "
          f"[Heaters loss] {heaters_loss_str} | "
          f"[Physics loss] {physics_loss_str} | "
          f"Val Accuracy: {val_accuracy:.2f}% | "
          f"LR: {optimizer.param_groups[0]['lr']:.9f} | "
          f"Time: {epoch_duration:.2f}s")

    # Guardar el mejor modelo en memoria
    if val_total_loss < early_stopper.best_loss:
        best_model_state = copy.deepcopy(model.state_dict())
        final_epoch = epoch + 1
        best_lr = optimizer.param_groups[0]['lr']  # guardar lr actual

    early_stopper(val_total_loss, epoch)
    if early_stopper.early_stop:
        print(f" Early stopping triggered at epoch {epoch}")
        avg_epoch_time = np.mean(epoch_times)
        print(f"Tiempo por época        : {avg_epoch_time:.2f}")
        break
# Out:
# Iniciando entrenamiento...
# Epoch 1 - Train Loss: 0.056317 | Val MSE: 0.000939 | Val MAE: 0.025447 | Val R²: 0.5803 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 20.63% | LR: 0.001469251 | Time: 17.53s
# Epoch 2 - Train Loss: 0.006601 | Val MSE: 0.006732 | Val MAE: 0.043559 | Val R²: -2.0033 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 38.60% | LR: 0.001469251 | Time: 20.57s
# Epoch 3 - Train Loss: 0.004507 | Val MSE: 0.006268 | Val MAE: 0.064030 | Val R²: -1.7973 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 1.04% | LR: 0.001469251 | Time: 16.19s
# Epoch 4 - Train Loss: 0.002894 | Val MSE: 0.000823 | Val MAE: 0.016124 | Val R²: 0.6330 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 52.76% | LR: 0.001469251 | Time: 15.85s
# Epoch 5 - Train Loss: 0.002493 | Val MSE: 0.000217 | Val MAE: 0.012027 | Val R²: 0.9037 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 43.71% | LR: 0.001469251 | Time: 17.13s
# Epoch 6 - Train Loss: 0.002119 | Val MSE: 0.001193 | Val MAE: 0.027140 | Val R²: 0.4671 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 23.57% | LR: 0.001469251 | Time: 18.04s
# Epoch 7 - Train Loss: 0.001893 | Val MSE: 0.001235 | Val MAE: 0.030732 | Val R²: 0.4493 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 4.71% | LR: 0.001469251 | Time: 14.90s
# Epoch 8 - Train Loss: 0.001622 | Val MSE: 0.000648 | Val MAE: 0.023253 | Val R²: 0.7112 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 2.07% | LR: 0.001469251 | Time: 16.16s
# Epoch 9 - Train Loss: 0.001498 | Val MSE: 0.004107 | Val MAE: 0.053075 | Val R²: -0.8344 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 1.54% | LR: 0.001469251 | Time: 15.77s
# Epoch 10 - Train Loss: 0.001092 | Val MSE: 0.001569 | Val MAE: 0.034213 | Val R²: 0.2990 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 2.11% | LR: 0.001469251 | Time: 15.62s
# Epoch 11 - Train Loss: 0.001046 | Val MSE: 0.000277 | Val MAE: 0.013815 | Val R²: 0.8766 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 36.27% | LR: 0.001469251 | Time: 15.45s
# Epoch 12 - Train Loss: 0.000909 | Val MSE: 0.000571 | Val MAE: 0.020689 | Val R²: 0.7448 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 19.51% | LR: 0.001469251 | Time: 16.79s
# Epoch 13 - Train Loss: 0.000801 | Val MSE: 0.000289 | Val MAE: 0.014275 | Val R²: 0.8709 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 36.24% | LR: 0.001469251 | Time: 14.56s
# Epoch 14 - Train Loss: 0.000699 | Val MSE: 0.001667 | Val MAE: 0.033689 | Val R²: 0.2566 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 15.96% | LR: 0.001469251 | Time: 14.55s
# Epoch 15 - Train Loss: 0.000700 | Val MSE: 0.001907 | Val MAE: 0.037267 | Val R²: 0.1490 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 18.48% | LR: 0.001469251 | Time: 17.71s
# Epoch 16 - Train Loss: 0.000549 | Val MSE: 0.000549 | Val MAE: 0.022307 | Val R²: 0.7545 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 3.13% | LR: 0.000734626 | Time: 18.82s
# Epoch 17 - Train Loss: 0.000401 | Val MSE: 0.000038 | Val MAE: 0.005034 | Val R²: 0.9831 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 83.94% | LR: 0.000734626 | Time: 15.74s
# Epoch 18 - Train Loss: 0.000416 | Val MSE: 0.000146 | Val MAE: 0.010446 | Val R²: 0.9347 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 42.80% | LR: 0.000734626 | Time: 14.10s
# Epoch 19 - Train Loss: 0.000424 | Val MSE: 0.000217 | Val MAE: 0.012727 | Val R²: 0.9033 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 32.78% | LR: 0.000734626 | Time: 16.75s
# Epoch 20 - Train Loss: 0.000363 | Val MSE: 0.000095 | Val MAE: 0.007547 | Val R²: 0.9577 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 68.65% | LR: 0.000734626 | Time: 17.10s
# Epoch 21 - Train Loss: 0.000373 | Val MSE: 0.000182 | Val MAE: 0.012336 | Val R²: 0.9183 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 27.21% | LR: 0.000734626 | Time: 16.25s
# Epoch 22 - Train Loss: 0.000368 | Val MSE: 0.000082 | Val MAE: 0.007985 | Val R²: 0.9635 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 64.74% | LR: 0.000734626 | Time: 17.02s
# Epoch 23 - Train Loss: 0.000353 | Val MSE: 0.000104 | Val MAE: 0.009020 | Val R²: 0.9533 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 55.65% | LR: 0.000734626 | Time: 21.20s
# Epoch 24 - Train Loss: 0.000320 | Val MSE: 0.000095 | Val MAE: 0.007377 | Val R²: 0.9576 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 72.18% | LR: 0.000734626 | Time: 27.93s
# Epoch 25 - Train Loss: 0.000347 | Val MSE: 0.000094 | Val MAE: 0.007854 | Val R²: 0.9582 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 59.78% | LR: 0.000734626 | Time: 25.26s
# Epoch 26 - Train Loss: 0.000305 | Val MSE: 0.000305 | Val MAE: 0.014960 | Val R²: 0.8638 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 29.10% | LR: 0.000734626 | Time: 17.15s
# Epoch 27 - Train Loss: 0.000308 | Val MSE: 0.000061 | Val MAE: 0.006652 | Val R²: 0.9725 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 71.42% | LR: 0.000734626 | Time: 14.70s
# Epoch 28 - Train Loss: 0.000286 | Val MSE: 0.000992 | Val MAE: 0.029984 | Val R²: 0.5564 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 1.73% | LR: 0.000367313 | Time: 16.82s
# Epoch 29 - Train Loss: 0.000223 | Val MSE: 0.000027 | Val MAE: 0.004251 | Val R²: 0.9879 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 93.96% | LR: 0.000367313 | Time: 20.87s
# Epoch 30 - Train Loss: 0.000207 | Val MSE: 0.000024 | Val MAE: 0.003878 | Val R²: 0.9893 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 93.15% | LR: 0.000367313 | Time: 16.11s
# Epoch 31 - Train Loss: 0.000218 | Val MSE: 0.000027 | Val MAE: 0.004274 | Val R²: 0.9880 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 92.53% | LR: 0.000367313 | Time: 14.60s
# Epoch 32 - Train Loss: 0.000201 | Val MSE: 0.000054 | Val MAE: 0.006654 | Val R²: 0.9757 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 75.55% | LR: 0.000367313 | Time: 15.72s
# Epoch 33 - Train Loss: 0.000202 | Val MSE: 0.000066 | Val MAE: 0.006226 | Val R²: 0.9707 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 74.12% | LR: 0.000367313 | Time: 13.66s
# Epoch 34 - Train Loss: 0.000204 | Val MSE: 0.000042 | Val MAE: 0.005264 | Val R²: 0.9811 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 81.49% | LR: 0.000367313 | Time: 13.62s
# Epoch 35 - Train Loss: 0.000182 | Val MSE: 0.000057 | Val MAE: 0.006058 | Val R²: 0.9748 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 72.52% | LR: 0.000367313 | Time: 13.68s
# Epoch 36 - Train Loss: 0.000191 | Val MSE: 0.000246 | Val MAE: 0.014936 | Val R²: 0.8901 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 10.55% | LR: 0.000367313 | Time: 16.76s
# Epoch 37 - Train Loss: 0.000182 | Val MSE: 0.000135 | Val MAE: 0.010734 | Val R²: 0.9397 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 34.20% | LR: 0.000367313 | Time: 16.19s
# Epoch 38 - Train Loss: 0.000194 | Val MSE: 0.000031 | Val MAE: 0.004457 | Val R²: 0.9861 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 86.83% | LR: 0.000367313 | Time: 15.31s
# Epoch 39 - Train Loss: 0.000165 | Val MSE: 0.000092 | Val MAE: 0.008182 | Val R²: 0.9591 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 61.22% | LR: 0.000367313 | Time: 16.68s
# Epoch 40 - Train Loss: 0.000181 | Val MSE: 0.000033 | Val MAE: 0.004413 | Val R²: 0.9853 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 88.59% | LR: 0.000367313 | Time: 14.71s
# Epoch 41 - Train Loss: 0.000166 | Val MSE: 0.000026 | Val MAE: 0.004253 | Val R²: 0.9886 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 95.00% | LR: 0.000183656 | Time: 18.51s
# Epoch 42 - Train Loss: 0.000140 | Val MSE: 0.000014 | Val MAE: 0.002798 | Val R²: 0.9940 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 96.87% | LR: 0.000183656 | Time: 18.81s
# Epoch 43 - Train Loss: 0.000144 | Val MSE: 0.000013 | Val MAE: 0.002655 | Val R²: 0.9943 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.01% | LR: 0.000183656 | Time: 17.91s
# Epoch 44 - Train Loss: 0.000138 | Val MSE: 0.000015 | Val MAE: 0.003121 | Val R²: 0.9933 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.18% | LR: 0.000183656 | Time: 16.77s
# Epoch 45 - Train Loss: 0.000139 | Val MSE: 0.000020 | Val MAE: 0.003532 | Val R²: 0.9911 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 95.82% | LR: 0.000183656 | Time: 21.18s
# Epoch 46 - Train Loss: 0.000135 | Val MSE: 0.000016 | Val MAE: 0.003214 | Val R²: 0.9930 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.94% | LR: 0.000183656 | Time: 20.44s
# Epoch 47 - Train Loss: 0.000127 | Val MSE: 0.000100 | Val MAE: 0.008692 | Val R²: 0.9552 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 49.36% | LR: 0.000183656 | Time: 19.11s
# Epoch 48 - Train Loss: 0.000130 | Val MSE: 0.000021 | Val MAE: 0.003714 | Val R²: 0.9905 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 95.61% | LR: 0.000183656 | Time: 22.87s
# Epoch 49 - Train Loss: 0.000135 | Val MSE: 0.000014 | Val MAE: 0.002866 | Val R²: 0.9937 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.14% | LR: 0.000183656 | Time: 18.75s
# Epoch 50 - Train Loss: 0.000125 | Val MSE: 0.000035 | Val MAE: 0.004995 | Val R²: 0.9844 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 87.38% | LR: 0.000183656 | Time: 21.21s
# Epoch 51 - Train Loss: 0.000128 | Val MSE: 0.000019 | Val MAE: 0.003486 | Val R²: 0.9915 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 96.44% | LR: 0.000183656 | Time: 20.28s
# Epoch 52 - Train Loss: 0.000120 | Val MSE: 0.000074 | Val MAE: 0.007616 | Val R²: 0.9672 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 63.33% | LR: 0.000183656 | Time: 14.54s
# Epoch 53 - Train Loss: 0.000118 | Val MSE: 0.000076 | Val MAE: 0.007603 | Val R²: 0.9659 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 57.87% | LR: 0.000183656 | Time: 13.16s
# Epoch 54 - Train Loss: 0.000122 | Val MSE: 0.000012 | Val MAE: 0.002616 | Val R²: 0.9945 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.48% | LR: 0.000183656 | Time: 14.68s
# Epoch 55 - Train Loss: 0.000114 | Val MSE: 0.000116 | Val MAE: 0.009680 | Val R²: 0.9480 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 46.00% | LR: 0.000183656 | Time: 14.37s
# Epoch 56 - Train Loss: 0.000117 | Val MSE: 0.000074 | Val MAE: 0.007764 | Val R²: 0.9669 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 64.97% | LR: 0.000183656 | Time: 13.03s
# Epoch 57 - Train Loss: 0.000115 | Val MSE: 0.000037 | Val MAE: 0.005379 | Val R²: 0.9834 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 89.21% | LR: 0.000183656 | Time: 13.08s
# Epoch 58 - Train Loss: 0.000111 | Val MSE: 0.000020 | Val MAE: 0.003856 | Val R²: 0.9910 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.42% | LR: 0.000183656 | Time: 13.31s
# Epoch 59 - Train Loss: 0.000115 | Val MSE: 0.000047 | Val MAE: 0.005498 | Val R²: 0.9791 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 74.91% | LR: 0.000183656 | Time: 18.84s
# Epoch 60 - Train Loss: 0.000113 | Val MSE: 0.000037 | Val MAE: 0.005328 | Val R²: 0.9835 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 87.92% | LR: 0.000183656 | Time: 15.94s
# Epoch 61 - Train Loss: 0.000109 | Val MSE: 0.000081 | Val MAE: 0.007165 | Val R²: 0.9640 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 64.38% | LR: 0.000183656 | Time: 15.76s
# Epoch 62 - Train Loss: 0.000106 | Val MSE: 0.000013 | Val MAE: 0.002782 | Val R²: 0.9944 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.39% | LR: 0.000183656 | Time: 20.85s
# Epoch 63 - Train Loss: 0.000106 | Val MSE: 0.000022 | Val MAE: 0.003979 | Val R²: 0.9903 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 96.99% | LR: 0.000183656 | Time: 17.33s
# Epoch 64 - Train Loss: 0.000106 | Val MSE: 0.000020 | Val MAE: 0.003600 | Val R²: 0.9912 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 96.71% | LR: 0.000183656 | Time: 18.39s
# Epoch 65 - Train Loss: 0.000110 | Val MSE: 0.000057 | Val MAE: 0.006633 | Val R²: 0.9746 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 73.11% | LR: 0.000091828 | Time: 18.84s
# Epoch 66 - Train Loss: 0.000093 | Val MSE: 0.000034 | Val MAE: 0.005185 | Val R²: 0.9849 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 92.82% | LR: 0.000091828 | Time: 15.44s
# Epoch 67 - Train Loss: 0.000094 | Val MSE: 0.000020 | Val MAE: 0.003829 | Val R²: 0.9910 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.29% | LR: 0.000091828 | Time: 13.97s
# Epoch 68 - Train Loss: 0.000094 | Val MSE: 0.000040 | Val MAE: 0.005527 | Val R²: 0.9822 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 85.27% | LR: 0.000091828 | Time: 13.26s
# Epoch 69 - Train Loss: 0.000091 | Val MSE: 0.000029 | Val MAE: 0.004714 | Val R²: 0.9868 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 93.48% | LR: 0.000091828 | Time: 16.81s
# Epoch 70 - Train Loss: 0.000095 | Val MSE: 0.000015 | Val MAE: 0.002970 | Val R²: 0.9934 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.21% | LR: 0.000091828 | Time: 16.84s
# Epoch 71 - Train Loss: 0.000093 | Val MSE: 0.000071 | Val MAE: 0.007733 | Val R²: 0.9684 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 56.80% | LR: 0.000091828 | Time: 15.50s
# Epoch 72 - Train Loss: 0.000097 | Val MSE: 0.000054 | Val MAE: 0.006747 | Val R²: 0.9761 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 77.91% | LR: 0.000091828 | Time: 16.50s
# Epoch 73 - Train Loss: 0.000089 | Val MSE: 0.000014 | Val MAE: 0.002941 | Val R²: 0.9938 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.00% | LR: 0.000091828 | Time: 15.97s
# Epoch 74 - Train Loss: 0.000088 | Val MSE: 0.000011 | Val MAE: 0.002610 | Val R²: 0.9949 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.77% | LR: 0.000091828 | Time: 17.71s
# Epoch 75 - Train Loss: 0.000090 | Val MSE: 0.000028 | Val MAE: 0.004535 | Val R²: 0.9874 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 94.24% | LR: 0.000091828 | Time: 18.00s
# Epoch 76 - Train Loss: 0.000088 | Val MSE: 0.000013 | Val MAE: 0.002716 | Val R²: 0.9944 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.67% | LR: 0.000091828 | Time: 22.21s
# Epoch 77 - Train Loss: 0.000086 | Val MSE: 0.000064 | Val MAE: 0.007242 | Val R²: 0.9714 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 67.45% | LR: 0.000091828 | Time: 19.20s
# Epoch 78 - Train Loss: 0.000089 | Val MSE: 0.000043 | Val MAE: 0.005763 | Val R²: 0.9809 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 79.48% | LR: 0.000091828 | Time: 14.31s
# Epoch 79 - Train Loss: 0.000086 | Val MSE: 0.000038 | Val MAE: 0.005571 | Val R²: 0.9828 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 89.66% | LR: 0.000091828 | Time: 13.86s
# Epoch 80 - Train Loss: 0.000089 | Val MSE: 0.000019 | Val MAE: 0.003612 | Val R²: 0.9915 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.27% | LR: 0.000091828 | Time: 1132.33s
# Epoch 81 - Train Loss: 0.000083 | Val MSE: 0.000028 | Val MAE: 0.004317 | Val R²: 0.9875 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 93.10% | LR: 0.000091828 | Time: 35.17s
# Epoch 82 - Train Loss: 0.000086 | Val MSE: 0.000060 | Val MAE: 0.006330 | Val R²: 0.9732 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 67.80% | LR: 0.000091828 | Time: 22.47s
# Epoch 83 - Train Loss: 0.000090 | Val MSE: 0.000042 | Val MAE: 0.005793 | Val R²: 0.9814 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 85.81% | LR: 0.000091828 | Time: 22.05s
# Epoch 84 - Train Loss: 0.000084 | Val MSE: 0.000021 | Val MAE: 0.003967 | Val R²: 0.9905 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.80% | LR: 0.000091828 | Time: 21.34s
# Epoch 85 - Train Loss: 0.000083 | Val MSE: 0.000060 | Val MAE: 0.006767 | Val R²: 0.9732 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 74.10% | LR: 0.000045914 | Time: 20.77s
# Epoch 86 - Train Loss: 0.000080 | Val MSE: 0.000033 | Val MAE: 0.005015 | Val R²: 0.9853 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 91.79% | LR: 0.000045914 | Time: 20.75s
# Epoch 87 - Train Loss: 0.000078 | Val MSE: 0.000038 | Val MAE: 0.005451 | Val R²: 0.9831 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 91.47% | LR: 0.000045914 | Time: 19.04s
# Epoch 88 - Train Loss: 0.000080 | Val MSE: 0.000035 | Val MAE: 0.005217 | Val R²: 0.9845 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 91.00% | LR: 0.000045914 | Time: 23.85s
# Epoch 89 - Train Loss: 0.000078 | Val MSE: 0.000013 | Val MAE: 0.002805 | Val R²: 0.9943 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.60% | LR: 0.000045914 | Time: 36.06s
# Epoch 90 - Train Loss: 0.000077 | Val MSE: 0.000024 | Val MAE: 0.004315 | Val R²: 0.9892 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.49% | LR: 0.000045914 | Time: 15.96s
# Epoch 91 - Train Loss: 0.000075 | Val MSE: 0.000011 | Val MAE: 0.002602 | Val R²: 0.9950 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.58% | LR: 0.000045914 | Time: 12.45s
# Epoch 92 - Train Loss: 0.000079 | Val MSE: 0.000029 | Val MAE: 0.004780 | Val R²: 0.9871 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 96.57% | LR: 0.000045914 | Time: 12.31s
# Epoch 93 - Train Loss: 0.000075 | Val MSE: 0.000019 | Val MAE: 0.003834 | Val R²: 0.9913 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.28% | LR: 0.000045914 | Time: 11.42s
# Epoch 94 - Train Loss: 0.000076 | Val MSE: 0.000020 | Val MAE: 0.003764 | Val R²: 0.9912 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.24% | LR: 0.000045914 | Time: 11.68s
# Epoch 95 - Train Loss: 0.000077 | Val MSE: 0.000016 | Val MAE: 0.003423 | Val R²: 0.9927 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.96% | LR: 0.000045914 | Time: 11.08s
# Epoch 96 - Train Loss: 0.000079 | Val MSE: 0.000012 | Val MAE: 0.002652 | Val R²: 0.9948 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.66% | LR: 0.000045914 | Time: 10.90s
# Epoch 97 - Train Loss: 0.000076 | Val MSE: 0.000025 | Val MAE: 0.004401 | Val R²: 0.9890 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.33% | LR: 0.000045914 | Time: 11.82s
# Epoch 98 - Train Loss: 0.000076 | Val MSE: 0.000024 | Val MAE: 0.004283 | Val R²: 0.9893 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.58% | LR: 0.000045914 | Time: 10.99s
# Epoch 99 - Train Loss: 0.000077 | Val MSE: 0.000039 | Val MAE: 0.005634 | Val R²: 0.9824 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 86.33% | LR: 0.000045914 | Time: 10.96s
# Epoch 100 - Train Loss: 0.000075 | Val MSE: 0.000016 | Val MAE: 0.003353 | Val R²: 0.9927 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.46% | LR: 0.000045914 | Time: 11.65s
# Epoch 101 - Train Loss: 0.000073 | Val MSE: 0.000015 | Val MAE: 0.003197 | Val R²: 0.9935 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.79% | LR: 0.000045914 | Time: 10.73s
# Epoch 102 - Train Loss: 0.000073 | Val MSE: 0.000012 | Val MAE: 0.002728 | Val R²: 0.9946 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.01% | LR: 0.000022957 | Time: 11.25s
# Epoch 103 - Train Loss: 0.000073 | Val MSE: 0.000025 | Val MAE: 0.004479 | Val R²: 0.9887 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.42% | LR: 0.000022957 | Time: 12.04s
# Epoch 104 - Train Loss: 0.000072 | Val MSE: 0.000013 | Val MAE: 0.002944 | Val R²: 0.9940 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.63% | LR: 0.000022957 | Time: 11.99s
# Epoch 105 - Train Loss: 0.000072 | Val MSE: 0.000035 | Val MAE: 0.005383 | Val R²: 0.9845 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 93.57% | LR: 0.000022957 | Time: 10.76s
# Epoch 106 - Train Loss: 0.000072 | Val MSE: 0.000018 | Val MAE: 0.003624 | Val R²: 0.9920 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.09% | LR: 0.000022957 | Time: 10.53s
# Epoch 107 - Train Loss: 0.000072 | Val MSE: 0.000020 | Val MAE: 0.003751 | Val R²: 0.9911 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.29% | LR: 0.000022957 | Time: 11.10s
# Epoch 108 - Train Loss: 0.000072 | Val MSE: 0.000020 | Val MAE: 0.003836 | Val R²: 0.9913 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.65% | LR: 0.000022957 | Time: 11.52s
# Epoch 109 - Train Loss: 0.000072 | Val MSE: 0.000023 | Val MAE: 0.004197 | Val R²: 0.9898 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.31% | LR: 0.000022957 | Time: 11.86s
# Epoch 110 - Train Loss: 0.000072 | Val MSE: 0.000016 | Val MAE: 0.003362 | Val R²: 0.9928 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.61% | LR: 0.000022957 | Time: 11.40s
# Epoch 111 - Train Loss: 0.000072 | Val MSE: 0.000034 | Val MAE: 0.005114 | Val R²: 0.9849 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 91.26% | LR: 0.000022957 | Time: 10.38s
# Epoch 112 - Train Loss: 0.000072 | Val MSE: 0.000024 | Val MAE: 0.004386 | Val R²: 0.9891 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.83% | LR: 0.000022957 | Time: 10.33s
# Epoch 113 - Train Loss: 0.000072 | Val MSE: 0.000025 | Val MAE: 0.004345 | Val R²: 0.9891 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.40% | LR: 0.000011479 | Time: 10.39s
# Epoch 114 - Train Loss: 0.000069 | Val MSE: 0.000029 | Val MAE: 0.004807 | Val R²: 0.9869 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 96.20% | LR: 0.000011479 | Time: 10.14s
# Epoch 115 - Train Loss: 0.000070 | Val MSE: 0.000014 | Val MAE: 0.003060 | Val R²: 0.9939 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.14% | LR: 0.000011479 | Time: 10.47s
# Epoch 116 - Train Loss: 0.000071 | Val MSE: 0.000020 | Val MAE: 0.003938 | Val R²: 0.9909 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.36% | LR: 0.000011479 | Time: 10.35s
# Epoch 117 - Train Loss: 0.000072 | Val MSE: 0.000016 | Val MAE: 0.003435 | Val R²: 0.9927 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.20% | LR: 0.000011479 | Time: 10.21s
# Epoch 118 - Train Loss: 0.000071 | Val MSE: 0.000017 | Val MAE: 0.003527 | Val R²: 0.9924 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.44% | LR: 0.000011479 | Time: 10.25s
# Epoch 119 - Train Loss: 0.000069 | Val MSE: 0.000023 | Val MAE: 0.004207 | Val R²: 0.9895 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.13% | LR: 0.000011479 | Time: 10.46s
# Epoch 120 - Train Loss: 0.000069 | Val MSE: 0.000023 | Val MAE: 0.004274 | Val R²: 0.9896 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.25% | LR: 0.000011479 | Time: 11.34s
# Epoch 121 - Train Loss: 0.000069 | Val MSE: 0.000019 | Val MAE: 0.003801 | Val R²: 0.9913 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.12% | LR: 0.000011479 | Time: 11.28s
# Epoch 122 - Train Loss: 0.000070 | Val MSE: 0.000018 | Val MAE: 0.003688 | Val R²: 0.9919 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.72% | LR: 0.000011479 | Time: 11.14s
# Epoch 123 - Train Loss: 0.000071 | Val MSE: 0.000023 | Val MAE: 0.004255 | Val R²: 0.9896 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.81% | LR: 0.000011479 | Time: 11.49s
# Epoch 124 - Train Loss: 0.000070 | Val MSE: 0.000017 | Val MAE: 0.003463 | Val R²: 0.9925 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.35% | LR: 0.000005739 | Time: 12.24s
# Epoch 125 - Train Loss: 0.000070 | Val MSE: 0.000017 | Val MAE: 0.003521 | Val R²: 0.9923 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.73% | LR: 0.000005739 | Time: 11.72s
# Epoch 126 - Train Loss: 0.000067 | Val MSE: 0.000019 | Val MAE: 0.003751 | Val R²: 0.9917 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.38% | LR: 0.000005739 | Time: 11.53s
# Epoch 127 - Train Loss: 0.000069 | Val MSE: 0.000017 | Val MAE: 0.003479 | Val R²: 0.9925 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.44% | LR: 0.000005739 | Time: 10.53s
# Epoch 128 - Train Loss: 0.000068 | Val MSE: 0.000014 | Val MAE: 0.003034 | Val R²: 0.9939 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.42% | LR: 0.000005739 | Time: 10.56s
# Epoch 129 - Train Loss: 0.000069 | Val MSE: 0.000024 | Val MAE: 0.004261 | Val R²: 0.9892 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 96.78% | LR: 0.000005739 | Time: 10.46s
# Epoch 130 - Train Loss: 0.000070 | Val MSE: 0.000011 | Val MAE: 0.002580 | Val R²: 0.9950 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.52% | LR: 0.000005739 | Time: 10.33s
# Epoch 131 - Train Loss: 0.000069 | Val MSE: 0.000019 | Val MAE: 0.003790 | Val R²: 0.9914 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.05% | LR: 0.000005739 | Time: 10.46s
# Epoch 132 - Train Loss: 0.000068 | Val MSE: 0.000017 | Val MAE: 0.003562 | Val R²: 0.9924 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.83% | LR: 0.000005739 | Time: 10.46s
# Epoch 133 - Train Loss: 0.000066 | Val MSE: 0.000017 | Val MAE: 0.003531 | Val R²: 0.9923 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.30% | LR: 0.000005739 | Time: 10.49s
# Epoch 134 - Train Loss: 0.000071 | Val MSE: 0.000018 | Val MAE: 0.003555 | Val R²: 0.9922 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.05% | LR: 0.000005739 | Time: 10.57s
# Epoch 135 - Train Loss: 0.000070 | Val MSE: 0.000016 | Val MAE: 0.003389 | Val R²: 0.9927 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.55% | LR: 0.000005739 | Time: 10.54s
# Epoch 136 - Train Loss: 0.000068 | Val MSE: 0.000016 | Val MAE: 0.003345 | Val R²: 0.9929 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.05% | LR: 0.000005739 | Time: 10.56s
# Epoch 137 - Train Loss: 0.000067 | Val MSE: 0.000022 | Val MAE: 0.004129 | Val R²: 0.9901 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.60% | LR: 0.000005739 | Time: 10.53s
# Epoch 138 - Train Loss: 0.000068 | Val MSE: 0.000013 | Val MAE: 0.002964 | Val R²: 0.9943 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.51% | LR: 0.000005739 | Time: 10.47s
# Epoch 139 - Train Loss: 0.000069 | Val MSE: 0.000024 | Val MAE: 0.004304 | Val R²: 0.9894 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.58% | LR: 0.000005739 | Time: 10.52s
# Epoch 140 - Train Loss: 0.000069 | Val MSE: 0.000012 | Val MAE: 0.002673 | Val R²: 0.9946 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.89% | LR: 0.000005739 | Time: 10.56s
# Epoch 141 - Train Loss: 0.000070 | Val MSE: 0.000019 | Val MAE: 0.003789 | Val R²: 0.9915 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.70% | LR: 0.000002870 | Time: 11.81s
# Epoch 142 - Train Loss: 0.000067 | Val MSE: 0.000023 | Val MAE: 0.004174 | Val R²: 0.9898 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.17% | LR: 0.000002870 | Time: 11.17s
# Epoch 143 - Train Loss: 0.000068 | Val MSE: 0.000020 | Val MAE: 0.003955 | Val R²: 0.9909 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.40% | LR: 0.000002870 | Time: 11.68s
# Epoch 144 - Train Loss: 0.000069 | Val MSE: 0.000014 | Val MAE: 0.003040 | Val R²: 0.9940 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.49% | LR: 0.000002870 | Time: 12.88s
# Epoch 145 - Train Loss: 0.000069 | Val MSE: 0.000015 | Val MAE: 0.003322 | Val R²: 0.9931 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.98% | LR: 0.000002870 | Time: 12.37s
# Epoch 146 - Train Loss: 0.000067 | Val MSE: 0.000015 | Val MAE: 0.003297 | Val R²: 0.9931 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.99% | LR: 0.000002870 | Time: 12.46s
# Epoch 147 - Train Loss: 0.000069 | Val MSE: 0.000014 | Val MAE: 0.003034 | Val R²: 0.9938 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.01% | LR: 0.000002870 | Time: 11.64s
# Epoch 148 - Train Loss: 0.000069 | Val MSE: 0.000017 | Val MAE: 0.003591 | Val R²: 0.9922 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.34% | LR: 0.000002870 | Time: 11.21s
# Epoch 149 - Train Loss: 0.000068 | Val MSE: 0.000018 | Val MAE: 0.003709 | Val R²: 0.9918 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.57% | LR: 0.000002870 | Time: 11.74s
# Epoch 150 - Train Loss: 0.000068 | Val MSE: 0.000015 | Val MAE: 0.003243 | Val R²: 0.9933 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.92% | LR: 0.000002870 | Time: 12.27s
# Epoch 151 - Train Loss: 0.000067 | Val MSE: 0.000020 | Val MAE: 0.003932 | Val R²: 0.9910 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.48% | LR: 0.000002870 | Time: 10.98s
# Epoch 152 - Train Loss: 0.000067 | Val MSE: 0.000017 | Val MAE: 0.003422 | Val R²: 0.9926 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.84% | LR: 0.000001435 | Time: 10.19s
# Epoch 153 - Train Loss: 0.000067 | Val MSE: 0.000015 | Val MAE: 0.003335 | Val R²: 0.9932 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.65% | LR: 0.000001435 | Time: 10.79s
# Epoch 154 - Train Loss: 0.000066 | Val MSE: 0.000014 | Val MAE: 0.003079 | Val R²: 0.9937 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.47% | LR: 0.000001435 | Time: 10.16s
# Epoch 155 - Train Loss: 0.000067 | Val MSE: 0.000016 | Val MAE: 0.003406 | Val R²: 0.9927 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 99.01% | LR: 0.000001435 | Time: 10.20s
# Epoch 156 - Train Loss: 0.000068 | Val MSE: 0.000017 | Val MAE: 0.003458 | Val R²: 0.9926 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.79% | LR: 0.000001435 | Time: 10.12s
# Epoch 157 - Train Loss: 0.000067 | Val MSE: 0.000015 | Val MAE: 0.003277 | Val R²: 0.9933 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.74% | LR: 0.000001435 | Time: 10.66s
# Epoch 158 - Train Loss: 0.000065 | Val MSE: 0.000016 | Val MAE: 0.003359 | Val R²: 0.9931 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.46% | LR: 0.000001435 | Time: 10.06s
# Epoch 159 - Train Loss: 0.000069 | Val MSE: 0.000014 | Val MAE: 0.002907 | Val R²: 0.9940 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.59% | LR: 0.000001435 | Time: 10.43s
# Epoch 160 - Train Loss: 0.000067 | Val MSE: 0.000015 | Val MAE: 0.003285 | Val R²: 0.9933 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.75% | LR: 0.000001435 | Time: 10.39s
# Epoch 161 - Train Loss: 0.000066 | Val MSE: 0.000017 | Val MAE: 0.003463 | Val R²: 0.9925 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.74% | LR: 0.000001435 | Time: 10.35s
# Epoch 162 - Train Loss: 0.000068 | Val MSE: 0.000019 | Val MAE: 0.003706 | Val R²: 0.9917 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.60% | LR: 0.000001435 | Time: 10.16s
# Epoch 163 - Train Loss: 0.000067 | Val MSE: 0.000013 | Val MAE: 0.002958 | Val R²: 0.9943 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.42% | LR: 0.000000717 | Time: 10.23s
# Epoch 164 - Train Loss: 0.000067 | Val MSE: 0.000014 | Val MAE: 0.003144 | Val R²: 0.9937 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.56% | LR: 0.000000717 | Time: 10.44s
# Epoch 165 - Train Loss: 0.000069 | Val MSE: 0.000013 | Val MAE: 0.002987 | Val R²: 0.9941 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.38% | LR: 0.000000717 | Time: 11.04s
# Epoch 166 - Train Loss: 0.000066 | Val MSE: 0.000017 | Val MAE: 0.003566 | Val R²: 0.9924 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.76% | LR: 0.000000717 | Time: 12.35s
# Epoch 167 - Train Loss: 0.000067 | Val MSE: 0.000019 | Val MAE: 0.003708 | Val R²: 0.9916 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.49% | LR: 0.000000717 | Time: 11.10s
# Epoch 168 - Train Loss: 0.000068 | Val MSE: 0.000016 | Val MAE: 0.003346 | Val R²: 0.9930 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.29% | LR: 0.000000717 | Time: 10.43s
# Epoch 169 - Train Loss: 0.000067 | Val MSE: 0.000015 | Val MAE: 0.003306 | Val R²: 0.9932 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.44% | LR: 0.000000717 | Time: 10.60s
# Epoch 170 - Train Loss: 0.000066 | Val MSE: 0.000019 | Val MAE: 0.003837 | Val R²: 0.9914 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.20% | LR: 0.000000717 | Time: 11.37s
# Epoch 171 - Train Loss: 0.000066 | Val MSE: 0.000016 | Val MAE: 0.003397 | Val R²: 0.9929 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.85% | LR: 0.000000717 | Time: 12.73s
# Epoch 172 - Train Loss: 0.000066 | Val MSE: 0.000019 | Val MAE: 0.003733 | Val R²: 0.9917 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.42% | LR: 0.000000717 | Time: 11.96s
# Epoch 173 - Train Loss: 0.000067 | Val MSE: 0.000013 | Val MAE: 0.002949 | Val R²: 0.9942 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.18% | LR: 0.000000717 | Time: 11.18s
# Epoch 174 - Train Loss: 0.000068 | Val MSE: 0.000019 | Val MAE: 0.003695 | Val R²: 0.9917 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.70% | LR: 0.000000359 | Time: 10.14s
# Epoch 175 - Train Loss: 0.000066 | Val MSE: 0.000019 | Val MAE: 0.003713 | Val R²: 0.9917 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.55% | LR: 0.000000359 | Time: 10.29s
# Epoch 176 - Train Loss: 0.000066 | Val MSE: 0.000014 | Val MAE: 0.003110 | Val R²: 0.9938 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.56% | LR: 0.000000359 | Time: 11.65s
# Epoch 177 - Train Loss: 0.000068 | Val MSE: 0.000019 | Val MAE: 0.003737 | Val R²: 0.9916 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.50% | LR: 0.000000359 | Time: 10.74s
# Epoch 178 - Train Loss: 0.000068 | Val MSE: 0.000018 | Val MAE: 0.003688 | Val R²: 0.9919 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.78% | LR: 0.000000359 | Time: 11.30s
# Epoch 179 - Train Loss: 0.000066 | Val MSE: 0.000019 | Val MAE: 0.003790 | Val R²: 0.9914 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.80% | LR: 0.000000359 | Time: 10.83s
# Epoch 180 - Train Loss: 0.000067 | Val MSE: 0.000021 | Val MAE: 0.003981 | Val R²: 0.9907 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.17% | LR: 0.000000359 | Time: 10.37s
# Epoch 181 - Train Loss: 0.000066 | Val MSE: 0.000016 | Val MAE: 0.003426 | Val R²: 0.9928 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.46% | LR: 0.000000359 | Time: 10.72s
# Epoch 182 - Train Loss: 0.000068 | Val MSE: 0.000014 | Val MAE: 0.003051 | Val R²: 0.9940 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.00% | LR: 0.000000359 | Time: 10.36s
# Epoch 183 - Train Loss: 0.000067 | Val MSE: 0.000023 | Val MAE: 0.004204 | Val R²: 0.9897 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.32% | LR: 0.000000359 | Time: 11.91s
# Epoch 184 - Train Loss: 0.000069 | Val MSE: 0.000017 | Val MAE: 0.003564 | Val R²: 0.9923 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.53% | LR: 0.000000359 | Time: 11.84s
# Epoch 185 - Train Loss: 0.000068 | Val MSE: 0.000017 | Val MAE: 0.003566 | Val R²: 0.9923 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.53% | LR: 0.000000179 | Time: 10.62s
# Epoch 186 - Train Loss: 0.000068 | Val MSE: 0.000032 | Val MAE: 0.005034 | Val R²: 0.9859 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 93.36% | LR: 0.000000179 | Time: 12.23s
# Epoch 187 - Train Loss: 0.000069 | Val MSE: 0.000015 | Val MAE: 0.003223 | Val R²: 0.9935 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.40% | LR: 0.000000179 | Time: 10.62s
# Epoch 188 - Train Loss: 0.000068 | Val MSE: 0.000019 | Val MAE: 0.003770 | Val R²: 0.9915 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.59% | LR: 0.000000179 | Time: 11.40s
# Epoch 189 - Train Loss: 0.000067 | Val MSE: 0.000021 | Val MAE: 0.003982 | Val R²: 0.9908 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.35% | LR: 0.000000179 | Time: 11.00s
# Epoch 190 - Train Loss: 0.000067 | Val MSE: 0.000028 | Val MAE: 0.004695 | Val R²: 0.9874 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 94.63% | LR: 0.000000179 | Time: 10.96s
# Epoch 191 - Train Loss: 0.000067 | Val MSE: 0.000016 | Val MAE: 0.003342 | Val R²: 0.9930 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.98% | LR: 0.000000179 | Time: 10.56s
# Epoch 192 - Train Loss: 0.000067 | Val MSE: 0.000019 | Val MAE: 0.003727 | Val R²: 0.9916 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.79% | LR: 0.000000179 | Time: 10.47s
# Epoch 193 - Train Loss: 0.000067 | Val MSE: 0.000018 | Val MAE: 0.003668 | Val R²: 0.9919 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.64% | LR: 0.000000179 | Time: 10.35s
# Epoch 194 - Train Loss: 0.000067 | Val MSE: 0.000015 | Val MAE: 0.003327 | Val R²: 0.9931 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.66% | LR: 0.000000179 | Time: 10.13s
# Epoch 195 - Train Loss: 0.000067 | Val MSE: 0.000015 | Val MAE: 0.003220 | Val R²: 0.9934 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.62% | LR: 0.000000179 | Time: 10.14s
# Epoch 196 - Train Loss: 0.000069 | Val MSE: 0.000017 | Val MAE: 0.003478 | Val R²: 0.9926 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.47% | LR: 0.000000090 | Time: 10.24s
# Epoch 197 - Train Loss: 0.000067 | Val MSE: 0.000014 | Val MAE: 0.003176 | Val R²: 0.9936 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.55% | LR: 0.000000090 | Time: 10.33s
# Epoch 198 - Train Loss: 0.000067 | Val MSE: 0.000013 | Val MAE: 0.003022 | Val R²: 0.9940 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.40% | LR: 0.000000090 | Time: 10.40s
# Epoch 199 - Train Loss: 0.000067 | Val MSE: 0.000014 | Val MAE: 0.003058 | Val R²: 0.9937 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.62% | LR: 0.000000090 | Time: 10.34s
# Epoch 200 - Train Loss: 0.000067 | Val MSE: 0.000017 | Val MAE: 0.003583 | Val R²: 0.9923 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.60% | LR: 0.000000090 | Time: 10.49s
# Epoch 201 - Train Loss: 0.000067 | Val MSE: 0.000015 | Val MAE: 0.003254 | Val R²: 0.9934 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.42% | LR: 0.000000090 | Time: 10.17s
# Epoch 202 - Train Loss: 0.000067 | Val MSE: 0.000017 | Val MAE: 0.003497 | Val R²: 0.9926 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.53% | LR: 0.000000090 | Time: 10.27s
# Epoch 203 - Train Loss: 0.000069 | Val MSE: 0.000018 | Val MAE: 0.003672 | Val R²: 0.9919 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.48% | LR: 0.000000090 | Time: 10.60s
# Epoch 204 - Train Loss: 0.000067 | Val MSE: 0.000027 | Val MAE: 0.004547 | Val R²: 0.9880 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 95.29% | LR: 0.000000090 | Time: 10.42s
# Epoch 205 - Train Loss: 0.000067 | Val MSE: 0.000015 | Val MAE: 0.003192 | Val R²: 0.9935 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.89% | LR: 0.000000090 | Time: 10.54s
# Epoch 206 - Train Loss: 0.000067 | Val MSE: 0.000027 | Val MAE: 0.004580 | Val R²: 0.9881 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 95.34% | LR: 0.000000090 | Time: 10.48s
# Epoch 207 - Train Loss: 0.000066 | Val MSE: 0.000025 | Val MAE: 0.004377 | Val R²: 0.9890 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 96.97% | LR: 0.000000045 | Time: 10.88s
# Epoch 208 - Train Loss: 0.000068 | Val MSE: 0.000019 | Val MAE: 0.003761 | Val R²: 0.9914 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.55% | LR: 0.000000045 | Time: 11.88s
# Epoch 209 - Train Loss: 0.000067 | Val MSE: 0.000022 | Val MAE: 0.004128 | Val R²: 0.9901 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.08% | LR: 0.000000045 | Time: 12.50s
# Epoch 210 - Train Loss: 0.000067 | Val MSE: 0.000020 | Val MAE: 0.003901 | Val R²: 0.9910 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.58% | LR: 0.000000045 | Time: 12.28s
# Epoch 211 - Train Loss: 0.000068 | Val MSE: 0.000016 | Val MAE: 0.003464 | Val R²: 0.9927 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.79% | LR: 0.000000045 | Time: 12.46s
# Epoch 212 - Train Loss: 0.000067 | Val MSE: 0.000022 | Val MAE: 0.004117 | Val R²: 0.9902 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.09% | LR: 0.000000045 | Time: 11.01s
# Epoch 213 - Train Loss: 0.000067 | Val MSE: 0.000015 | Val MAE: 0.003233 | Val R²: 0.9934 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.68% | LR: 0.000000045 | Time: 11.71s
# Epoch 214 - Train Loss: 0.000067 | Val MSE: 0.000017 | Val MAE: 0.003487 | Val R²: 0.9925 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.92% | LR: 0.000000045 | Time: 10.21s
# Epoch 215 - Train Loss: 0.000067 | Val MSE: 0.000018 | Val MAE: 0.003643 | Val R²: 0.9919 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.61% | LR: 0.000000045 | Time: 10.57s
# Epoch 216 - Train Loss: 0.000067 | Val MSE: 0.000018 | Val MAE: 0.003648 | Val R²: 0.9920 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.77% | LR: 0.000000045 | Time: 10.21s
# Epoch 217 - Train Loss: 0.000068 | Val MSE: 0.000024 | Val MAE: 0.004357 | Val R²: 0.9892 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.42% | LR: 0.000000045 | Time: 10.37s
# Epoch 218 - Train Loss: 0.000067 | Val MSE: 0.000018 | Val MAE: 0.003608 | Val R²: 0.9922 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.49% | LR: 0.000000022 | Time: 11.28s
# Epoch 219 - Train Loss: 0.000068 | Val MSE: 0.000013 | Val MAE: 0.002894 | Val R²: 0.9944 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.34% | LR: 0.000000022 | Time: 12.98s
# Epoch 220 - Train Loss: 0.000068 | Val MSE: 0.000023 | Val MAE: 0.004125 | Val R²: 0.9899 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 97.16% | LR: 0.000000022 | Time: 12.13s
# Epoch 221 - Train Loss: 0.000067 | Val MSE: 0.000018 | Val MAE: 0.003581 | Val R²: 0.9922 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 99.01% | LR: 0.000000022 | Time: 12.45s
# Epoch 222 - Train Loss: 0.000067 | Val MSE: 0.000017 | Val MAE: 0.003473 | Val R²: 0.9926 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.32% | LR: 0.000000022 | Time: 12.42s
# Epoch 223 - Train Loss: 0.000068 | Val MSE: 0.000015 | Val MAE: 0.003295 | Val R²: 0.9932 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.47% | LR: 0.000000022 | Time: 12.43s
# Epoch 224 - Train Loss: 0.000068 | Val MSE: 0.000013 | Val MAE: 0.002913 | Val R²: 0.9943 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.39% | LR: 0.000000022 | Time: 12.56s
# Epoch 225 - Train Loss: 0.000067 | Val MSE: 0.000019 | Val MAE: 0.003783 | Val R²: 0.9915 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.48% | LR: 0.000000022 | Time: 12.45s
# Epoch 226 - Train Loss: 0.000067 | Val MSE: 0.000019 | Val MAE: 0.003833 | Val R²: 0.9914 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.18% | LR: 0.000000022 | Time: 12.72s
# Epoch 227 - Train Loss: 0.000068 | Val MSE: 0.000015 | Val MAE: 0.003250 | Val R²: 0.9934 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.59% | LR: 0.000000022 | Time: 12.88s
# Epoch 228 - Train Loss: 0.000067 | Val MSE: 0.000018 | Val MAE: 0.003682 | Val R²: 0.9918 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.49% | LR: 0.000000022 | Time: 13.46s
# Epoch 229 - Train Loss: 0.000067 | Val MSE: 0.000023 | Val MAE: 0.004113 | Val R²: 0.9898 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 96.25% | LR: 0.000000011 | Time: 12.70s
# Epoch 230 - Train Loss: 0.000069 | Val MSE: 0.000017 | Val MAE: 0.003534 | Val R²: 0.9924 | [Heaters loss] N/A | [Physics loss] N/A | Val Accuracy: 98.77% | LR: 0.000000011 | Time: 12.70s
#  Early stopping triggered at epoch 229
# Tiempo por época        : 18.55

# %% [markdown]
# ### Revisión del output por nodo:

# %%
# x = sample.x.to(device)
# edge_index = sample.edge_index.to(device)
# print("Out example:", model(x, edge_index).detach())

# %%
# Cargar el mejor modelo antes de guardar
if best_model_state is not None:
    model.load_state_dict(best_model_state)
else:
    print("Advertencia: No se ha encontrado un modelo mejor durante el entrenamiento.")

# Crear nombre de archivo con los hiperparámetros clave
model_name = (
    f"3D_GAT_Layers_{config['num_layers']}_"
    f"HDim_{config['hidden_dim']}_"
    f"Epochs_{final_epoch}_"
    f"Heads_{config['heads']}_"
    f"Lr_{best_lr:.9f}_"    
    f"H_LOSS_{config['use_heater_loss']}_"
    f"Lambda_{config['lambda_heater']}_"
    f"PI_{config['use_physics']}_"
    f"Lambda_{config['lambda_physics']}_"
    f"Batch_{config['batch_size']}.pth"
)
print("Nombre del modelo:", model_name)
# Out:
# Nombre del modelo: 3D_GAT_Layers_4_HDim_32_Epochs_130_Heads_2_Lr_0.000005739_H_LOSS_False_Lambda_1.0_PI_False_Lambda_0.0001_Batch_16.pth

# %%
# === Configuración de estilo LaTeX ===
plt.style.use('default')
plt.rcParams.update({
    "figure.figsize": (6, 4),
    "font.family": "serif",
    "font.size": 12,
    "text.usetex": True,
    "axes.titlesize": 11
})

# === Crear carpeta para guardar ===
os.makedirs("LOSS_IMG", exist_ok=True)
loss_img_filename = model_name.replace(".pth", ".svg")
loss_img_path = os.path.join("LOSS_IMG", loss_img_filename)

# === Gráfico ===
plt.figure()
plt.plot(train_losses, label=r'\textbf{Train Loss}', linewidth=2)
plt.plot(val_losses, label=r'\textbf{Validation Loss}', linewidth=2)

plt.yscale("log")
plt.xlabel(r'\textbf{Epoch}')
plt.ylabel(r'\textbf{MSE Loss}')
plt.title(r'\textbf{Loss evolution over epochs}')
plt.legend()
plt.grid(True)
plt.tight_layout()

ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

plt.savefig(loss_img_path, format="svg")
plt.show()

# %% [markdown]
# ## Carga de un modelo

# %%
if config["load_model"]:
    from Data_loader import load_model_by_name
    
    model_filename = "GAT_Layers_4_HDim_32_Epochs_219_Heads_2_Lr_0.000000717_H_LOSS_False_Lambda_1.0_PI_False_Lambda_0.0001_Batch_16.pth"
    model = load_model_by_name(model, model_filename)
    print("Modelo cargado:", model_filename)

# %% [markdown]
# ## Evaluación

# %%
# Evaluar en test y graficar un ejemplo
print("Evaluando en test set con visualización de un ejemplo:")
test_mse, test_mae, test_r2, test_accuracy, test_physics, test_heater, test_rmse, test_total_loss, max_error_K, mean_max_error_per_graph_K = evaluate(
    model, test_loader, device, norm_info, lambda_physics=config["lambda_physics"],
    use_physics=config["use_physics"], lambda_heater=config["lambda_heater"],
    use_heater_loss=config["use_heater_loss"],
    error_threshold_K=config["error_threshold_K"],
    plot_results=True
)

preds, targets = predict(model, test_loader, device, norm_info)
plt.figure()
plt.scatter(targets.numpy(), preds.numpy(), alpha=0.4)
plt.plot([0, 1], [0, 1], 'r--')
plt.xlabel("Target (normalized)")
plt.ylabel("Prediction (normalized)")
plt.grid(True)


physics_loss_str = f"{test_physics:.6f}" if test_physics is not None else "N/A"

max_T_real = norm_info["max_T_real"]
mae_K = test_mae * max_T_real
rmse_K = test_rmse * (max_T_real)
mse_K = test_mse * (max_T_real ** 2)
print(f"MAE en Kelvin     : {mae_K:.3f} K")
print(f"RMSE en Kelvin    : {rmse_K:.3f} K")
print(f"MSE en Kelvin²    : {mse_K:.3f} K²")
print(f"Error máximo absoluto     : {max_error_K:.3f} K")
print(f"Promedio de errores máximos por grafo: {mean_max_error_per_graph_K:.3f} K")

h_loss = test_heater * (max_T_real**2)

print("Resultados del test:")
print(f"MSE       : {test_mse:.6f}")
print(f"MAE       : {test_mae:.6f}")
print(f"R²        : {test_r2:.4f}")
print(f"Accuracy  : {test_accuracy:.2f}%")
print(f"Heaters Loss  : {h_loss:.6f}K²")
print(f"Physics Loss  : {physics_loss_str}W²")
# Out:
# Evaluando en test set con visualización de un ejemplo:
# Grafo 0: Data(x=[34, 2], edge_index=[2, 372], edge_attr=[372, 2], y=[34, 1], edge_attr_GLAGRA=[372, 2], edge_attr_norm=[372, 2], edge_attr_GLAGRA_norm=[372, 2], external_ids=[34], area=[34])
# MAE en Kelvin     : 0.865 K
# RMSE en Kelvin    : 1.104 K
# MSE en Kelvin²    : 1.253 K²
# Error máximo absoluto     : 5.702 K
# Promedio de errores máximos por grafo: 2.687 K
# Resultados del test:
# MSE       : 0.000011
# MAE       : 0.002578
# R²        : 0.9886
# Accuracy  : 98.43%
# Heaters Loss  : 0.000000K²
# Physics Loss  : 0.000000W²

# %% [markdown]
# ## Guardado del mejor modelo

# %%
# Crear carpeta si no existe
save_dir = "saved_models"
os.makedirs(save_dir, exist_ok=True)
# Guardar el modelo
model_path = os.path.join(save_dir, model_name)
if config["save_model"]:
    # Guardar el modelo entrenado
    torch.save(model.state_dict(), model_path)

    print(f" Modelo guardado en: {model_path}")
# Out:
#  Modelo guardado en: saved_models\3D_GAT_Layers_4_HDim_32_Epochs_130_Heads_2_Lr_0.000005739_H_LOSS_False_Lambda_1.0_PI_False_Lambda_0.0001_Batch_16.pth

# %% [markdown]
# ## GNNExplainer

# %%
run_full_gnnexplainer(model, test_loader.dataset, graph_idx=0, target_node_idx=30, norm_info=norm_info, device=device)
# Out:
# data.x.shape = torch.Size([34, 2])
# data.edge_index.max() = 33
# data.num_nodes = 34
